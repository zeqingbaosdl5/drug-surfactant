# %% [markdown]
# # import libraries

# %%
import pandas as pd
from ax.service.ax_client import AxClient, ObjectiveProperties
import matplotlib.pyplot as plt
from ax.modelbridge.factory import Models
from ax.modelbridge.generation_strategy import GenerationStep, GenerationStrategy   


import sys
sys.path.append('../')
import helper_functions as hf

# %% [markdown]
# # generate recommendations

# %%
n = hf.get_iteration_number()

for i in range(3):
    print("Very Important: Please Confirm the Iteration Number is Iteration " + str(n))
# Out:
# Very Important: Please Confirm the Iteration Number is Iteration 8
# Very Important: Please Confirm the Iteration Number is Iteration 8
# Very Important: Please Confirm the Iteration Number is Iteration 8

# %%
df_design, ax_client = hf.run_optimizer(current_iteration=n, n_trials=6)
# Out:
# [INFO 06-12 11:52:11] ax.service.ax_client: Starting optimization with verbose logging. To disable logging, set the `verbose_logging` argument to `False`. Note that float values in the logs are rounded to 6 decimal points.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df_design, ax_client = hf.run_optimizer(current_iteration=n, n_trials=6)
#
# File c:\Users\yunhe\OneDrive\Documents\GitHub\drug_surfactant\experiments\20250605\iteration_8\..\helper_functions.py:204, in run_optimizer(current_iteration, n_trials)
#     201 else:
#     202     ax_client = AxClient.load_from_json_file("../iteration_" + str(current_iteration-1) + "/" + optimizer_file_path + str(current_iteration-1) + '_loaded.json')
# --> 204 trials, _ = ax_client.get_next_trials(n_trials)
#     206 # Prepare the trial data for DataFrame
#     207 trials_data = []
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\ax\service\ax_client.py:671, in AxClient.get_next_trials(self, max_trials, ttl_seconds, fixed_features)
#     669 for _ in range(max_trials):
#     670     try:
# --> 671         params, trial_index = self.get_next_trial(
#     672             ttl_seconds=ttl_seconds, fixed_features=fixed_features
#     673         )
#     674         trials_dict[trial_index] = params
#     675     except OptimizationComplete as err:
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\ax\utils\common\executils.py:169, in retry_on_exception.<locals>.func_wrapper.<locals>.actual_wrapper(*args, **kwargs)
#     165             wait_interval = min(
#     166                 MAX_WAIT_SECONDS, initial_wait_seconds * 2 ** (i - 1)
#     167             )
#     168             time.sleep(wait_interval)
# --> 169         return func(*args, **kwargs)
#     171 # If we are here, it means the retries were finished but
#     172 # The error was suppressed. Hence return the default value provided.
#     173 return default_return_on_suppression
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\ax\service\ax_client.py:576, in AxClient.get_next_trial(self, ttl_seconds, force, fixed_features)
#     572         raise OptimizationShouldStop(message=global_stopping_message)
#     574 try:
#     575     trial = self.experiment.new_trial(
# --> 576         generator_run=self._gen_new_generator_run(
#     577             fixed_features=fixed_features
#     578         ),
#     579         ttl_seconds=ttl_seconds,
#     580     )
#     581 except MaxParallelismReachedException as e:
#     582     if self._early_stopping_strategy is not None:
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\ax\service\ax_client.py:1818, in AxClient._gen_new_generator_run(self, n, fixed_features)
#    1810 fixed_feats = (
#    1811     InstantiationBase.make_fixed_observation_features(
#    1812         fixed_features=fixed_features
#    (...)   1815     else None
#    1816 )
#    1817 with with_rng_seed(seed=self._random_seed):
# -> 1818     return none_throws(self.generation_strategy).gen(
#    1819         experiment=self.experiment,
#    1820         n=n,
#    1821         pending_observations=self._get_pending_observation_features(
#    1822             experiment=self.experiment
#    1823         ),
#    1824         fixed_features=fixed_feats,
#    1825     )
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\ax\modelbridge\generation_strategy.py:339, in GenerationStrategy.gen(self, experiment, data, pending_observations, n, fixed_features)
#     304 def gen(
#     305     self,
#     306     experiment: Experiment,
#    (...)    310     fixed_features: ObservationFeatures | None = None,
#     311 ) -> GeneratorRun:
#     312     """Produce the next points in the experiment. Additional kwargs passed to
#     313     this method are propagated directly to the underlying model's `gen`, along
#     314     with the `model_gen_kwargs` set on the current generation node.
#    (...)    337             resuggesting points that are currently being evaluated.
#     338     """
# --> 339     gr = self._gen_with_multiple_nodes(
#     340         experiment=experiment,
#     341         data=data,
#     342         n=n,
#     343         pending_observations=pending_observations,
#     344         fixed_features=fixed_features,
#     345     )
#     346     if len(gr) > 1:
#     347         raise UnsupportedError(
#     348             "By calling into GenerationStrategy.gen(), you are should be "
#     349             "expecting a single `Trial` with only one `GeneratorRun`. However, "
#     350             "the underlying GenerationStrategy produced multiple `GeneratorRuns` "
#     351             f"and returned the following list of `GeneratorRun`-s: {gr}"
#     352         )
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\ax\modelbridge\generation_strategy.py:453, in GenerationStrategy._gen_with_multiple_nodes(self, experiment, data, pending_observations, n, fixed_features, arms_per_node)
#     451 if arms_from_node != 0:
#     452     try:
# --> 453         curr_node_gr = self._curr.gen(
#     454             n=arms_from_node,
#     455             pending_observations=pending_observations,
#     456             arms_by_signature_for_deduplication=(
#     457                 experiment.arms_by_signature_for_deduplication
#     458             ),
#     459             fixed_features=fixed_features_from_node,
#     460         )
#     461     except DataRequiredError as err:
#     462         # Model needs more data, so we log the error and return
#     463         # as many generator runs as we were able to produce, unless
#     464         # no trials were produced at all (in which case its safe to raise).
#     465         if len(grs) == 0:
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\ax\modelbridge\generation_node.py:902, in GenerationStep.gen(self, n, pending_observations, max_gen_draws_for_deduplication, arms_by_signature_for_deduplication, **model_gen_kwargs)
#     894 def gen(
#     895     self,
#     896     n: int | None = None,
#    (...)    900     **model_gen_kwargs: Any,
#     901 ) -> GeneratorRun:
# --> 902     gr = super().gen(
#     903         n=n,
#     904         pending_observations=pending_observations,
#     905         max_gen_draws_for_deduplication=max_gen_draws_for_deduplication,
#     906         arms_by_signature_for_deduplication=arms_by_signature_for_deduplication,
#     907         **model_gen_kwargs,
#     908     )
#     909     gr._generation_step_index = self.index
#     910     return gr
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\ax\modelbridge\generation_node.py:408, in GenerationNode.gen(self, n, pending_observations, max_gen_draws_for_deduplication, arms_by_signature_for_deduplication, **model_gen_kwargs)
#     405 # Keep generating until each of `generator_run.arms` is not a duplicate
#     406 # of a previous arm, if `should_deduplicate is True`
#     407 while should_generate_run:
# --> 408     generator_run = self._gen(
#     409         n=n,
#     410         pending_observations=pending_observations,
#     411         **model_gen_kwargs,
#     412     )
#     413     should_generate_run = (
#     414         self.should_deduplicate
#     415         and arms_by_signature_for_deduplication
#    (...)    419         )
#     420     )
#     421     n_gen_draws += 1
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\ax\modelbridge\generation_node.py:479, in GenerationNode._gen(self, n, pending_observations, **model_gen_kwargs)
#     475 if n is None and model_spec.model_gen_kwargs:
#     476     # If `n` is not specified, ensure that the `None` value does not
#     477     # override the one set in `model_spec.model_gen_kwargs`.
#     478     n = model_spec.model_gen_kwargs.get("n", None)
# --> 479 return model_spec.gen(
#     480     n=n,
#     481     # For `pending_observations`, prefer the input to this function, as
#     482     # `pending_observations` are dynamic throughout the experiment and thus
#     483     # unlikely to be specified in `model_spec.model_gen_kwargs`.
#     484     pending_observations=pending_observations,
#     485     **model_gen_kwargs,
#     486 )
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\ax\modelbridge\model_spec.py:238, in ModelSpec.gen(self, **model_gen_kwargs)
#     236 # copy to ensure there is no in-place modification
#     237 model_gen_kwargs = deepcopy(model_gen_kwargs)
# --> 238 generator_run = fitted_model.gen(**model_gen_kwargs)
#     239 fit_and_std_quality_and_generalization_dict = (
#     240     get_fit_and_std_quality_and_generalization_dict(
#     241         fitted_model_bridge=self.fitted_model,
#     242     )
#     243 )
#     244 generator_run._gen_metadata = (
#     245     {} if generator_run.gen_metadata is None else generator_run.gen_metadata
#     246 )
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\ax\modelbridge\base.py:861, in ModelBridge.gen(self, n, search_space, optimization_config, pending_observations, fixed_features, model_gen_options)
#     854 base_gen_args = self._get_transformed_gen_args(
#     855     search_space=search_space,
#     856     optimization_config=optimization_config,
#     857     pending_observations=pending_observations,
#     858     fixed_features=fixed_features,
#     859 )
#     860 # Apply terminal transform and gen
# --> 861 gen_results = self._gen(
#     862     n=n,
#     863     search_space=base_gen_args.search_space,
#     864     optimization_config=base_gen_args.optimization_config,
#     865     pending_observations=base_gen_args.pending_observations,
#     866     fixed_features=base_gen_args.fixed_features,
#     867     model_gen_options=model_gen_options,
#     868 )
#     870 observation_features = gen_results.observation_features
#     871 best_obsf = gen_results.best_observation_features
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\ax\modelbridge\torch.py:711, in TorchModelBridge._gen(self, n, search_space, pending_observations, fixed_features, model_gen_options, optimization_config)
#     702 search_space_digest, torch_opt_config = self._get_transformed_model_gen_args(
#     703     search_space=search_space,
#     704     pending_observations=pending_observations,
#    (...)    707     optimization_config=optimization_config,
#     708 )
#     710 # Generate the candidates
# --> 711 gen_results = none_throws(self.model).gen(
#     712     n=n,
#     713     search_space_digest=search_space_digest,
#     714     torch_opt_config=torch_opt_config,
#     715 )
#     717 gen_metadata = dict(gen_results.gen_metadata)
#     718 if (
#     719     isinstance(optimization_config, MultiObjectiveOptimizationConfig)
#     720     and gen_metadata.get("objective_thresholds", None) is not None
#    (...)    724     # if using a hypervolume based acquisition function, then
#     725     # the inferred objective thresholds are in gen_metadata.
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\ax\models\torch\botorch_modular\model.py:255, in BoTorchModel.gen(self, n, search_space_digest, torch_opt_config)
#     249 acqf = self._instantiate_acquisition(
#     250     search_space_digest=search_space_digest,
#     251     torch_opt_config=torch_opt_config,
#     252     acq_options=acq_options,
#     253 )
#     254 botorch_rounding_func = get_rounding_func(torch_opt_config.rounding_func)
# --> 255 candidates, expected_acquisition_value, weights = acqf.optimize(
#     256     n=n,
#     257     search_space_digest=search_space_digest,
#     258     inequality_constraints=_to_inequality_constraints(
#     259         linear_constraints=torch_opt_config.linear_constraints
#     260     ),
#     261     fixed_features=torch_opt_config.fixed_features,
#     262     rounding_func=botorch_rounding_func,
#     263     optimizer_options=assert_is_instance(
#     264         opt_options,
#     265         dict,
#     266     ),
#     267 )
#     268 gen_metadata = self._get_gen_metadata_from_acqf(
#     269     acqf=acqf,
#     270     torch_opt_config=torch_opt_config,
#     271     expected_acquisition_value=expected_acquisition_value,
#     272 )
#     273 # log what model was used
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\ax\models\torch\botorch_modular\acquisition.py:441, in Acquisition.optimize(self, n, search_space_digest, inequality_constraints, fixed_features, rounding_func, optimizer_options)
#     429     candidates, acqf_values = optimize_acqf_mixed(
#     430         acq_function=self.acqf,
#     431         bounds=bounds,
#    (...)    438         **optimizer_options_with_defaults,
#     439     )
#     440 elif optimizer == "optimize_acqf_mixed_alternating":
# --> 441     candidates, acqf_values = optimize_acqf_mixed_alternating(
#     442         acq_function=self.acqf,
#     443         bounds=bounds,
#     444         discrete_dims=search_space_digest.ordinal_features,
#     445         q=n,
#     446         post_processing_func=rounding_func,
#     447         fixed_features=fixed_features,
#     448         inequality_constraints=inequality_constraints,
#     449         **optimizer_options_with_defaults,
#     450     )
#     451 else:
#     452     raise AxError(  # pragma: no cover
#     453         f"Unknown optimizer: {optimizer}. This code should be unreachable."
#     454     )
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\botorch\optim\optimize_mixed.py:679, in optimize_acqf_mixed_alternating(acq_function, bounds, discrete_dims, options, q, raw_samples, num_restarts, post_processing_func, sequential, fixed_features, inequality_constraints)
#     677 discrete_dims = [dim for dim in discrete_dims if dim not in fixed_features]
#     678 if len(discrete_dims) == 0:
# --> 679     return _optimize_acqf(opt_inputs=opt_inputs)
#     680 if not (
#     681     isinstance(discrete_dims, list)
#     682     and len(set(discrete_dims)) == len(discrete_dims)
#     683     and min(discrete_dims) >= 0
#     684     and max(discrete_dims) <= dim - 1
#     685 ):
#     686     raise ValueError(
#     687         "`discrete_dims` must be a list with unique integers "
#     688         "between 0 and num_dims - 1."
#     689     )
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\botorch\optim\optimize.py:652, in _optimize_acqf(opt_inputs)
#     649     return _optimize_acqf_sequential_q(opt_inputs=opt_inputs)
#     651 # Batch optimization (including the case q=1)
# --> 652 return _optimize_acqf_batch(opt_inputs=opt_inputs)
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\botorch\optim\optimize.py:408, in _optimize_acqf_batch(opt_inputs)
#     405         batch_acq_values = torch.cat(batch_acq_values_list).flatten()
#     406     return batch_candidates, batch_acq_values, opt_warnings
# --> 408 batch_candidates, batch_acq_values, ws = _optimize_batch_candidates()
#     410 optimization_warning_raised = any(
#     411     issubclass(w.category, OptimizationWarning) for w in ws
#     412 )
#     413 if optimization_warning_raised and opt_inputs.retry_on_optimization_warning:
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\botorch\optim\optimize.py:385, in _optimize_acqf_batch.<locals>._optimize_batch_candidates()
#     380 with warnings.catch_warnings(record=True) as ws:
#     381     warnings.simplefilter("always", category=OptimizationWarning)
#     382     (
#     383         batch_candidates_curr,
#     384         batch_acq_values_curr,
# --> 385     ) = opt_inputs.gen_candidates(
#     386         batched_ics_,
#     387         opt_inputs.acq_function,
#     388         lower_bounds=lower_bounds,
#     389         upper_bounds=upper_bounds,
#     390         options=gen_options,
#     391         fixed_features=opt_inputs.fixed_features,
#     392         timeout_sec=timeout_sec,
#     393         **gen_kwargs,
#     394     )
#     395 opt_warnings += ws
#     396 batch_candidates_list.append(batch_candidates_curr)
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\botorch\generation\gen.py:240, in gen_candidates_scipy(initial_conditions, acquisition_function, lower_bounds, upper_bounds, inequality_constraints, equality_constraints, nonlinear_inequality_constraints, options, fixed_features, timeout_sec)
#     237 def f(x):
#     238     return -acquisition_function(x)
# --> 240 res = minimize_with_timeout(
#     241     fun=f_np_wrapper,
#     242     args=(f,),
#     243     x0=x0,
#     244     method=options.get("method", "SLSQP" if constraints else "L-BFGS-B"),
#     245     jac=with_grad,
#     246     bounds=bounds,
#     247     constraints=constraints,
#     248     callback=options.get("callback", None),
#     249     options={
#     250         k: v
#     251         for k, v in options.items()
#     252         if k not in ["method", "callback", "with_grad"]
#     253     },
#     254     timeout_sec=timeout_sec,
#     255 )
#     256 _process_scipy_result(res=res, options=options)
#     258 candidates = fix_features(
#     259     X=torch.from_numpy(res.x).to(initial_conditions).reshape(shapeX),
#     260     fixed_features=fixed_features,
#     261 )
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\botorch\optim\utils\timeout.py:86, in minimize_with_timeout(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options, timeout_sec)
#      83     # To prevent slowdowns after scipy 1.15.
#      84     # See https://github.com/scipy/scipy/issues/22438.
#      85     with threadpool_limits(limits=1, user_api="blas"):
# ---> 86         return optimize.minimize(
#      87             fun=fun,
#      88             x0=x0,
#      89             args=args,
#      90             method=method,
#      91             jac=jac,
#      92             hess=hess,
#      93             hessp=hessp,
#      94             bounds=bounds,
#      95             constraints=constraints,
#      96             tol=tol,
#      97             callback=wrapped_callback,
#      98             options=options,
#      99         )
#     100 except OptimizationTimeoutError as e:
#     101     msg = f"Optimization timed out after {e.runtime} seconds."
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\scipy\optimize\_minimize.py:738, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     735     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     736                              **options)
#     737 elif meth == 'l-bfgs-b':
# --> 738     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     739                            callback=callback, **options)
#     740 elif meth == 'tnc':
#     741     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     742                         **options)
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\scipy\optimize\_lbfgsb_py.py:441, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     433 _lbfgsb.setulb(m, x, low_bnd, upper_bnd, nbd, f, g, factr, pgtol, wa,
#     434                iwa, task, lsave, isave, dsave, maxls, ln_task)
#     436 if task[0] == 3:
#     437     # The minimization routine wants f and g at the current x.
#     438     # Note that interruptions due to maxfun are postponed
#     439     # until the completion of the current minimization iteration.
#     440     # Overwrite f and g:
# --> 441     f, g = func_and_grad(x)
#     442 elif task[0] == 1:
#     443     # new iteration
#     444     n_iterations += 1
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\scipy\optimize\_differentiable_functions.py:344, in ScalarFunction.fun_and_grad(self, x)
#     342 if not np.array_equal(x, self.x):
#     343     self._update_x(x)
# --> 344 self._update_fun()
#     345 self._update_grad()
#     346 return self.f, self.g
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\scipy\optimize\_differentiable_functions.py:295, in ScalarFunction._update_fun(self)
#     293 def _update_fun(self):
#     294     if not self.f_updated:
# --> 295         fx = self._wrapped_fun(self.x)
#     296         if fx < self._lowest_f:
#     297             self._lowest_x = self.x
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\scipy\optimize\_differentiable_functions.py:21, in _wrapper_fun.<locals>.wrapped(x)
#      17 ncalls[0] += 1
#      18 # Send a copy because the user may overwrite it.
#      19 # Overwriting results in undefined behaviour because
#      20 # fun(self.x) will change self.x, with the two no longer linked.
# ---> 21 fx = fun(np.copy(x), *args)
#      22 # Make sure the function returns a true scalar
#      23 if not np.isscalar(fx):
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\scipy\optimize\_optimize.py:80, in MemoizeJac.__call__(self, x, *args)
#      78 def __call__(self, x, *args):
#      79     """ returns the function value """
# ---> 80     self._compute_if_needed(x, *args)
#      81     return self._value
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\scipy\optimize\_optimize.py:74, in MemoizeJac._compute_if_needed(self, x, *args)
#      72 if not np.all(x == self.x) or self._value is None or self.jac is None:
#      73     self.x = np.asarray(x).copy()
# ---> 74     fg = self.fun(x, *args)
#      75     self.jac = fg[1]
#      76     self._value = fg[0]
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\botorch\generation\gen.py:199, in gen_candidates_scipy.<locals>.f_np_wrapper(x, f)
#     197 loss = f(X_fix).sum()
#     198 # compute gradient w.r.t. the inputs (does not accumulate in leaves)
# --> 199 gradf = _arrayify(torch.autograd.grad(loss, X)[0].contiguous().view(-1))
#     200 if np.isnan(gradf).any():
#     201     msg = (
#     202         f"{np.isnan(gradf).sum()} elements of the {x.size} element "
#     203         "gradient array `gradf` are NaN. "
#     204         "This often indicates numerical issues."
#     205     )
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\torch\autograd\__init__.py:502, in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused, is_grads_batched, materialize_grads)
#     498     result = _vmap_internals._vmap(vjp, 0, 0, allow_none_pass_through=True)(
#     499         grad_outputs_
#     500     )
#     501 else:
# --> 502     result = _engine_run_backward(
#     503         outputs,
#     504         grad_outputs_,
#     505         retain_graph,
#     506         create_graph,
#     507         inputs,
#     508         allow_unused,
#     509         accumulate_grad=False,
#     510     )
#     511 if materialize_grads:
#     512     if any(
#     513         result[i] is None and not is_tensor_like(inputs[i])
#     514         for i in range(len(inputs))
#     515     ):
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\torch\autograd\graph.py:824, in _engine_run_backward(t_outputs, *args, **kwargs)
#     822     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     823 try:
# --> 824     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     825         t_outputs, *args, **kwargs
#     826     )  # Calls into the C++ engine to run the backward pass
#     827 finally:
#     828     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# # process results

# %%
ax_client = hf.load_design_optimizer(n)
ax_client.experiment.trials
# Out:
# [INFO 06-06 10:53:30] ax.service.ax_client: Starting optimization with verbose logging. To disable logging, set the `verbose_logging` argument to `False`. Note that float values in the logs are rounded to 6 decimal points.
# {0: Trial(experiment_name='drug_surfactant', index=0, status=TrialStatus.COMPLETED, arm=Arm(name='0_0', parameters={'s1': 47, 's2': 59, 's3': 49, 's4': 31, 's5': 96, 's6': 8, 's7': 9, 's8': 35, 's9': 85, 'surfactant_conc': 77, 'drug_conc': 89})),
#  1: Trial(experiment_name='drug_surfactant', index=1, status=TrialStatus.COMPLETED, arm=Arm(name='1_0', parameters={'s1': 92, 's2': 28, 's3': 51, 's4': 69, 's5': 27, 's6': 83, 's7': 70, 's8': 58, 's9': 36, 'surfactant_conc': 30, 'drug_conc': 3})),
#  2: Trial(experiment_name='drug_surfactant', index=2, status=TrialStatus.COMPLETED, arm=Arm(name='2_0', parameters={'s1': 53, 's2': 81, 's3': 8, 's4': 21, 's5': 17, 's6': 73, 's7': 48, 's8': 97, 's9': 20, 'surfactant_conc': 14, 'drug_conc': 29})),
#  3: Trial(experiment_name='drug_surfactant', index=3, status=TrialStatus.COMPLETED, arm=Arm(name='3_0', parameters={'s1': 7, 's2': 7, 's3': 92, 's4': 84, 's5': 61, 's6': 49, 's7': 82, 's8': 24, 's9': 69, 'surfactant_conc': 68, 'drug_conc': 69})),
#  4: Trial(experiment_name='drug_surfactant', index=4, status=TrialStatus.COMPLETED, arm=Arm(name='4_0', parameters={'s1': 21, 's2': 88, 's3': 68, 's4': 90, 's5': 72, 's6': 15, 's7': 35, 's8': 81, 's9': 3, 'surfactant_conc': 50, 'drug_conc': 41})),
#  5: Trial(experiment_name='drug_surfactant', index=5, status=TrialStatus.COMPLETED, arm=Arm(name='5_0', parameters={'s1': 65, 's2': 24, 's3': 32, 's4': 2, 's5': 2, 's6': 93, 's7': 95, 's8': 1, 's9': 55, 'surfactant_conc': 95, 'drug_conc': 51})),
#  6: Trial(experiment_name='drug_surfactant', index=6, status=TrialStatus.RUNNING, arm=Arm(name='6_0', parameters={'s1': 0, 's2': 0, 's3': 100, 's4': 100, 's5': 57, 's6': 100, 's7': 100, 's8': 59, 's9': 84, 'surfactant_conc': 1, 'drug_conc': 100}))}

# %%
df_conc, df_vol = hf.design_to_conc_to_vol (n)

# %%
plate_well = input("Enter the plate well starting well (e.g., F1): ")
deepplate_well = input("Enter the deep plate well starting well (e.g., F1): ")


print("Please confirm the following information:")
print("Wellplate will start at: " + plate_well)
print("Deep plate will start at: " + deepplate_well)

print()
print("*******************************************************")
print("Continue if correct, or rerun this cell if incorrect.")
print("*******************************************************")
# Out:
# Please confirm the following information:
# Wellplate will start at: B1
# Deep plate will start at: B1
#
# *******************************************************
# Continue if correct, or rerun this cell if incorrect.
# *******************************************************

# %%
hf.generate_protocol(df_vol=df_vol, iteration=n, plate_well=plate_well, deepplate_well=deepplate_well)
# Out:
# ✅ Successfully wrote to: protocol/otflex_1.py

# %%
df_absorbance = hf.process_absorbance(iteration=n)

# %%
results = hf.build_results(n, df_conc, df_absorbance)

# %%
results

# %%
norm_results = hf.normalize_data(results, 'normalize')

# %%
norm_results

# %% [markdown]
# # load the results to the optimizer

# %%
ax_client = hf.load_data_to_optimizer(iteration = n, norm_results = norm_results)
ax_client
