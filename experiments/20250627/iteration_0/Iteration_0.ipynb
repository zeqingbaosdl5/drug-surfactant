# %% [markdown]
# # import libraries

# %%
import pandas as pd
from ax.service.ax_client import AxClient, ObjectiveProperties
import matplotlib.pyplot as plt
from ax.modelbridge.registry import Models
from ax.modelbridge.generation_strategy import GenerationStep, GenerationStrategy   
import time

import sys
sys.path.append('../')
import helper_functions as hf
# Out:
# /var/folders/9p/f66yhymx35939zzlg51g0rrc0000gn/T/ipykernel_2324/1711932296.py:5: DeprecationWarning: Please import from 'ax.generation_strategy.generation_strategy' instead of 'ax.modelbridge.generation_strategy'. The latter is deprecated and will be removed in a future release.
#   from ax.modelbridge.generation_strategy import GenerationStep, GenerationStrategy

# %% [markdown]
# # initialize the optimizer

# %%
ax_client_init_file_name = 'optimizer/optimizer_00.json'
ax_client = hf.optimizer_init()
ax_client
# Out:
# AxClient(experiment=Experiment(drug_surfactant))

# %%
ax_client.save_to_json_file(ax_client_init_file_name)

# %% [markdown]
# # generate recommendations

# %%
n = hf.get_iteration_number()

for i in range(3):
    print("Very Important: Please Confirm the Iteration Number is Iteration " + str(n))
# Out:
# Very Important: Please Confirm the Iteration Number is Iteration 0
# Very Important: Please Confirm the Iteration Number is Iteration 0
# Very Important: Please Confirm the Iteration Number is Iteration 0

# %%
time_start = time.time()

df_design, ax_client = hf.run_optimizer(current_iteration=n, n_trials=3, drug="IBP", bopt=0)

time_end = time.time()
time_duration = round((time_end - time_start)/60,2)

print("Time taken for optimization: " + str(time_duration) + " mins")
print("Time taken for optimization: " + str(time_duration * 60) + " seconds")
# Out:
# [INFO 06-27 11:18:17] ax.service.ax_client: Generated new trial 0 with parameters {'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 47, 's2': 60, 's3': 50, 's4': 31, 's5': 96, 's6': 8, 's7': 9, 's8': 35, 'surfactant_conc': 85, 'drug_conc': 100} using model Sobol.
# [INFO 06-27 11:18:17] ax.service.ax_client: Generated new trial 1 with parameters {'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 74, 's2': 0, 's3': 88, 's4': 66, 's5': 22, 's6': 52, 's7': 58, 's8': 79, 'surfactant_conc': 35, 'drug_conc': 100} using model Sobol.
# [INFO 06-27 11:18:17] ax.service.ax_client: Generated new trial 2 with parameters {'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 78, 's2': 88, 's3': 1, 's4': 3, 's5': 32, 's6': 94, 's7': 44, 's8': 58, 'surfactant_conc': 1, 'drug_conc': 100} using model Sobol.
# **************************************************************************************************************
#
# Generating random trials for
# Drug name:  Ibuprofen IBP  | Iteration:  0
#
# **************************************************************************************************************
# Time taken for optimization: 0.0 mins
# Time taken for optimization: 0.0 seconds

# %% [markdown]
# # process results

# %%
ax_client = hf.load_design_optimizer(n)
ax_client.experiment.trials
# Out:
# {0: Trial(experiment_name='drug_surfactant', index=0, status=TrialStatus.RUNNING, arm=Arm(name='0_0', parameters={'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 47, 's2': 60, 's3': 50, 's4': 31, 's5': 96, 's6': 8, 's7': 9, 's8': 35, 'surfactant_conc': 85, 'drug_conc': 100})),
#  1: Trial(experiment_name='drug_surfactant', index=1, status=TrialStatus.RUNNING, arm=Arm(name='1_0', parameters={'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 74, 's2': 0, 's3': 88, 's4': 66, 's5': 22, 's6': 52, 's7': 58, 's8': 79, 'surfactant_conc': 35, 'drug_conc': 100})),
#  2: Trial(experiment_name='drug_surfactant', index=2, status=TrialStatus.RUNNING, arm=Arm(name='2_0', parameters={'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 78, 's2': 88, 's3': 1, 's4': 3, 's5': 32, 's6': 94, 's7': 44, 's8': 58, 'surfactant_conc': 1, 'drug_conc': 100}))}

# %%
df_conc, df_vol = hf.design_to_conc_to_vol (n)

# %%
plate_well = input("Enter the plate well starting well (e.g., F1): ")
deepplate_well = input("Enter the deep plate well starting well (e.g., F1): ")


print("Please confirm the following information:")
print("Wellplate will start at: " + plate_well)
print("Deep plate will start at: " + deepplate_well)

print()
print("*******************************************************")
print("Continue if correct, or rerun this cell if incorrect.")
print("*******************************************************")
# Out:
# Please confirm the following information:
# Wellplate will start at: F1
# Deep plate will start at: H1
#
# *******************************************************
# Continue if correct, or rerun this cell if incorrect.
# *******************************************************

# %%
hf.generate_protocol(df_vol=df_vol, iteration=n, plate_well=plate_well, deepplate_well=deepplate_well)
# Out:
# ✅ Successfully wrote to: protocol/otflex_0.py

# %%
df_absorbance = hf.process_absorbance(iteration=n)
df_absorbance
# Out:
#    trial_index  success
# 0            0        0
# 1            1        0
# 2            2        0

# %%
df_conc
# Out:
#    trial_index  surfactant_conc  drug_conc        s1        s2        s3  \
# 0            0             42.5       25.0  5.944940  7.589286  6.324405
# 1            1             17.5       25.0  2.949886  0.000000  3.507973
# 2            2              0.5       25.0  0.097990  0.110553  0.001256
#
#          s4         s5        s6        s7        s8
# 0  3.921131  12.142857  1.011905  1.138393  4.427083
# 1  2.630979   0.876993  2.072893  2.312073  3.149203
# 2  0.003769   0.040201  0.118090  0.055276  0.072864

# %%
results = hf.build_results(n, df_conc, df_absorbance)

# %%
results
# Out:
#    trial_index  s1  s2  s3  s4  s5  s6  s7  s8  surfactant_input  drug_conc  \
# 0            0  47  60  50  31  96   8   9  35              42.5       25.0
# 1            1  74   0  88  66  22  52  58  79              17.5       25.0
# 2            2  78  88   1   3  32  94  44  58               0.5       25.0
#
#    success  complexity
# 0        0           8
# 1        0           7
# 2        0           8

# %%
norm_results = hf.normalize_data(results, 'normalize')

# %%
norm_results
# Out:
#    trial_index  s1  s2  s3  s4  s5  s6  s7  s8  surfactant_input  drug_conc  \
# 0            0  47  60  50  31  96   8   9  35              0.85        1.0
# 1            1  74   0  88  66  22  52  58  79              0.35        1.0
# 2            2  78  88   1   3  32  94  44  58              0.01        1.0
#
#    success  complexity
# 0      0.0       1.000
# 1      0.0       0.875
# 2      0.0       1.000

# %% [markdown]
# # load the results to the optimizer

# %%
ax_client = hf.load_data_to_optimizer(iteration = n, norm_results = norm_results)
ax_client
# Out:
# [INFO 06-27 11:57:21] ax.service.ax_client: Completed trial 0 with data: {'success': (0.0, None), 'surfactant_input': (1.0, None), 'complexity': (1.0, None)}.
# [INFO 06-27 11:57:21] ax.service.ax_client: Completed trial 1 with data: {'success': (0.0, None), 'surfactant_input': (1.0, None), 'complexity': (1.0, None)}.
# [INFO 06-27 11:57:21] ax.service.ax_client: Completed trial 2 with data: {'success': (0.0, None), 'surfactant_input': (1.0, None), 'complexity': (1.0, None)}.
# Trial 0: success=0 → overriding surfactant_input & complexity to 1
# Trial 1: success=0 → overriding surfactant_input & complexity to 1
# Trial 2: success=0 → overriding surfactant_input & complexity to 1
# AxClient(experiment=Experiment(drug_surfactant))
