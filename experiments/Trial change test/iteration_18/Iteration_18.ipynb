# %% [markdown]
# # import libraries

# %%
import pandas as pd
from ax.service.ax_client import AxClient, ObjectiveProperties
import matplotlib.pyplot as plt
from ax.modelbridge.registry import Models
from ax.modelbridge.generation_strategy import GenerationStep, GenerationStrategy   
import time


import sys
sys.path.append('../')
import helper_functions as hf
# Out:
# /var/folders/9p/f66yhymx35939zzlg51g0rrc0000gn/T/ipykernel_81718/3307975217.py:5: DeprecationWarning: Please import from 'ax.generation_strategy.generation_strategy' instead of 'ax.modelbridge.generation_strategy'. The latter is deprecated and will be removed in a future release.
#   from ax.modelbridge.generation_strategy import GenerationStep, GenerationStrategy

# %% [markdown]
# # generate recommendations

# %%
print("List of available drugs:")
print("=====================================")
for drug in hf.normalize_drug_properties_dict.keys():
    print(f"{drug}:   {hf.normalize_drug_properties_dict[drug]['full_name']}")
# Out:
# List of available drugs:
# =====================================
# IBP:   Ibuprofen
# DCF:   Diclofenac
# LOV:   Lovastatin
# ITZ:   Itraconazole
# RPD:   Risperidone

# %%
drug = input("Enter the drug name (abbreviation): ")


print("Please confirm the following information:")
print()
print("Drug:                ", drug, " (",hf.normalize_drug_properties_dict[drug]['full_name'],")")
print("Stock solution conc: ", hf.normalize_drug_properties_dict[drug]['drug_stock_conc'], "mg/mL")
print("Molecular weight:    ",hf.normalize_drug_properties_dict[drug]['normalized_properties']['Drug_MW'] * 1000)
print("LogP:                ", hf.normalize_drug_properties_dict[drug]['normalized_properties']['Drug_LogP'] * 10)
print("TPSA:                ", hf.normalize_drug_properties_dict[drug]['normalized_properties']['Drug_TPSA'] * 1000)



print()
print("*******************************************************")
print("Continue if correct, or rerun this cell if incorrect.")
print("*******************************************************")
# Out:
# Please confirm the following information:
#
# Drug:                 DCF  ( Diclofenac )
# Stock solution conc:  25 mg/mL
# Molecular weight:     296.20000000000005
# LogP:                 4.364
# TPSA:                 49.3
#
# *******************************************************
# Continue if correct, or rerun this cell if incorrect.
# *******************************************************

# %%
n = hf.get_iteration_number()

for i in range(3):
    print("Very Important: Please Confirm the Iteration Number is Iteration " + str(n))
# Out:
# Very Important: Please Confirm the Iteration Number is Iteration 18
# Very Important: Please Confirm the Iteration Number is Iteration 18
# Very Important: Please Confirm the Iteration Number is Iteration 18

# %%
import os

def change_loaded_data_to_fail(iteration, trial_index):

    n= iteration
    folder = f"iteration_{iteration}"
    base_path = os.path.join(folder, 'optimizer', f'optimizer_{iteration}')

    json_file = base_path + '.json'
    save_path = base_path + '_loaded.json'

    ax_client = ax_client = AxClient.load_from_json_file(json_file)

    raw_data = {
        "success": 0,
        "surfactant_input": 1,
        "complexity": 1
    }

    ax_client.complete_trial(trial_index=trial_index, raw_data=raw_data)
    ax_client.save_to_json_file(path)

    print(f"Trial {trial_index} in iteration {iteration} marked as success=0, surfactant_input=1, complexity=1")


change_loaded_data_to_fail(iteration=17, trial_index=52)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 26
#      21     ax_client.save_to_json_file(path)
#      23     print(f"Trial {trial_index} in iteration {iteration} marked as success=0, surfactant_input=1, complexity=1")
# ---> 26 change_loaded_data_to_fail(iteration=17, trial_index=52)
#
# Cell In[7], line 12, in change_loaded_data_to_fail(iteration, trial_index)
#       9 json_file = base_path + '.json'
#      10 save_path = base_path + '_loaded.json'
# ---> 12 ax_client = ax_client = AxClient.load_from_json_file(json_file)
#      14 raw_data = {
#      15     "success": 0,
#      16     "surfactant_input": 1,
#      17     "complexity": 1
#      18 }
#      20 ax_client.complete_trial(trial_index=trial_index, raw_data=raw_data)
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/service/ax_client.py:1389, in AxClient.load_from_json_file(cls, filepath, **kwargs)
#    1379 @classmethod
#    1380 def load_from_json_file(
#    1381     cls: type[AxClientSubclass],
#    (...)   1384     **kwargs,
#    1385 ) -> AxClientSubclass:
#    1386     """Restore an `AxClient` and its state from a JSON-serialized snapshot,
#    1387     residing in a .json file by the given path.
#    1388     """
# -> 1389     with open(filepath) as file:
#    1390         serialized = json.loads(file.read())
#    1391         return cls.from_json_snapshot(serialized=serialized, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'iteration_17/optimizer/optimizer_17.json'

# %%
time_start = time.time()


df_design, ax_client = hf.run_optimizer(current_iteration=n, drug = drug, bopt = 1, n_trials=3)

time_end = time.time()
time_duration = round((time_end - time_start)/60,2)

print("Time taken for optimization: " + str(time_duration) + " mins")
print("Time taken for optimization: " + str(time_duration * 60) + " seconds")

# %% [markdown]
# # process results

# %%
ax_client = hf.load_design_optimizer(n)
ax_client.experiment.trials

# %%
df_conc, df_vol = hf.design_to_conc_to_vol (n)

# %%
plate_well = input("Enter the plate well starting well (e.g., F1): ")
deepplate_well = input("Enter the deep plate well starting well (e.g., F1): ")


print("Please confirm the following information:")
print("Wellplate will start at: " + plate_well)
print("Deep plate will start at: " + deepplate_well)

print()
print("*******************************************************")
print("Continue if correct, or rerun this cell if incorrect.")
print("*******************************************************")

# %%
hf.generate_protocol(df_vol=df_vol, iteration=n, plate_well=plate_well, deepplate_well=deepplate_well)

# %%
df_absorbance = hf.process_absorbance(iteration=n, threshold=0.1)
df_absorbance

# %%
results = hf.build_results(n, df_conc, df_absorbance)
results

# %%
norm_results = hf.normalize_data(results, 'normalize')

# %%
norm_results

# %% [markdown]
# # load the results to the optimizer

# %%
ax_client = hf.load_data_to_optimizer(iteration = n, norm_results = norm_results)
ax_client
