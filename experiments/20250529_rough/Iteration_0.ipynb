# %% [markdown]
# # import libraries

# %%
import pandas as pd
from ax.service.ax_client import AxClient, ObjectiveProperties
import matplotlib.pyplot as plt
from ax.modelbridge.factory import Models
from ax.modelbridge.generation_strategy import GenerationStep, GenerationStrategy      
import helper_functions as hf

# %% [markdown]
# # initialize the optimizer

# %%
ax_client_init_file_name = 'optimizer/optimizer_00.json'
ax_client = hf.optimizer_init()
ax_client
# Out:
# [INFO 05-29 12:40:37] ax.service.ax_client: Starting optimization with verbose logging. To disable logging, set the `verbose_logging` argument to `False`. Note that float values in the logs are rounded to 6 decimal points.
# [INFO 05-29 12:40:37] ax.service.utils.instantiation: Created search space: SearchSpace(parameters=[RangeParameter(name='s1', parameter_type=INT, range=[0, 100]), RangeParameter(name='s2', parameter_type=INT, range=[0, 100]), RangeParameter(name='s3', parameter_type=INT, range=[0, 100]), RangeParameter(name='s4', parameter_type=INT, range=[0, 100]), RangeParameter(name='s5', parameter_type=INT, range=[0, 100]), RangeParameter(name='s6', parameter_type=INT, range=[0, 100]), RangeParameter(name='s7', parameter_type=INT, range=[0, 100]), RangeParameter(name='s8', parameter_type=INT, range=[0, 100]), RangeParameter(name='s9', parameter_type=INT, range=[0, 100]), RangeParameter(name='s10', parameter_type=INT, range=[0, 100]), RangeParameter(name='s11', parameter_type=INT, range=[0, 100]), RangeParameter(name='s12', parameter_type=INT, range=[0, 100]), RangeParameter(name='surfactant_conc', parameter_type=INT, range=[1, 100]), RangeParameter(name='drug_conc', parameter_type=INT, range=[1, 100])], parameter_constraints=[]).
# AxClient(experiment=Experiment(drug_surfactant))

# %%
ax_client.save_to_json_file(ax_client_init_file_name)
# Out:
# [INFO 05-29 12:40:37] ax.service.ax_client: Saved JSON-serialized state of optimization to `optimizer/optimizer_00.json`.

# %% [markdown]
# # iteration_0 + date

# %%
n = int(input("Enter the Iteration Number: "))

for i in range(3):
    print("Very Important: Please Confirm the Iteration Number is Iteration " + str(n))
# Out:
# Very Important: Please Confirm the Iteration Number is Iteration 0
# Very Important: Please Confirm the Iteration Number is Iteration 0
# Very Important: Please Confirm the Iteration Number is Iteration 0

# %%
df_design, ax_client = hf.run_optimizer(current_iteration=n, n_trials=16)
# Out:
# [INFO 05-29 12:40:45] ax.service.ax_client: Starting optimization with verbose logging. To disable logging, set the `verbose_logging` argument to `False`. Note that float values in the logs are rounded to 6 decimal points.
# /Users/zeqing/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:439: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 05-29 12:40:45] ax.service.ax_client: Generated new trial 0 with parameters {'s1': 47, 's2': 59, 's3': 49, 's4': 31, 's5': 96, 's6': 8, 's7': 9, 's8': 35, 's9': 85, 's10': 76, 's11': 89, 's12': 88, 'surfactant_conc': 81, 'drug_conc': 86} using model Sobol.
# /Users/zeqing/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:439: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 05-29 12:40:45] ax.service.ax_client: Generated new trial 1 with parameters {'s1': 93, 's2': 38, 's3': 50, 's4': 84, 's5': 50, 's6': 65, 's7': 78, 's8': 53, 's9': 26, 's10': 20, 's11': 36, 's12': 5, 'surfactant_conc': 29, 'drug_conc': 1} using model Sobol.
# /Users/zeqing/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:439: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 05-29 12:40:45] ax.service.ax_client: Generated new trial 2 with parameters {'s1': 51, 's2': 77, 's3': 13, 's4': 24, 's5': 19, 's6': 94, 's7': 27, 's8': 92, 's9': 2, 's10': 28, 's11': 16, 's12': 30, 'surfactant_conc': 60, 'drug_conc': 53} using model Sobol.
# /Users/zeqing/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:439: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 05-29 12:40:45] ax.service.ax_client: Generated new trial 3 with parameters {'s1': 8, 's2': 20, 's3': 88, 's4': 72, 's5': 73, 's6': 36, 's7': 60, 's8': 21, 's9': 62, 's10': 75, 's11': 58, 's12': 63, 'surfactant_conc': 12, 'drug_conc': 38} using model Sobol.
# /Users/zeqing/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:439: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 05-29 12:40:45] ax.service.ax_client: Generated new trial 4 with parameters {'s1': 22, 's2': 93, 's3': 75, 's4': 52, 's5': 54, 's6': 24, 's7': 49, 's8': 77, 's9': 22, 's10': 5, 's11': 7, 's12': 56, 'surfactant_conc': 71, 'drug_conc': 19} using model Sobol.
# /Users/zeqing/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:439: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 05-29 12:40:45] ax.service.ax_client: Generated new trial 5 with parameters {'s1': 68, 's2': 10, 's3': 25, 's4': 0, 's5': 1, 's6': 56, 's7': 64, 's8': 10, 's9': 63, 's10': 97, 's11': 66, 's12': 38, 'surfactant_conc': 19, 'drug_conc': 97} using model Sobol.
# /Users/zeqing/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:439: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 05-29 12:40:45] ax.service.ax_client: Generated new trial 6 with parameters {'s1': 76, 's2': 75, 's3': 89, 's4': 91, 's5': 30, 's6': 78, 's7': 13, 's8': 47, 's9': 90, 's10': 52, 's11': 86, 's12': 13, 'surfactant_conc': 89, 'drug_conc': 45} using model Sobol.
# /Users/zeqing/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:439: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 05-29 12:40:45] ax.service.ax_client: Generated new trial 7 with parameters {'s1': 34, 's2': 29, 's3': 12, 's4': 43, 's5': 78, 's6': 46, 's7': 100, 's8': 66, 's9': 50, 's10': 45, 's11': 38, 's12': 81, 'surfactant_conc': 40, 'drug_conc': 67} using model Sobol.
# /Users/zeqing/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:439: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 05-29 12:40:45] ax.service.ax_client: Generated new trial 8 with parameters {'s1': 27, 's2': 82, 's3': 98, 's4': 10, 's5': 38, 's6': 30, 's7': 40, 's8': 86, 's9': 14, 's10': 69, 's11': 48, 's12': 94, 'surfactant_conc': 15, 'drug_conc': 38} using model Sobol.
# /Users/zeqing/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:439: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 05-29 12:40:45] ax.service.ax_client: Generated new trial 9 with parameters {'s1': 82, 's2': 15, 's3': 1, 's4': 61, 's5': 92, 's6': 100, 's7': 73, 's8': 2, 's9': 73, 's10': 35, 's11': 78, 's12': 11, 'surfactant_conc': 64, 'drug_conc': 73} using model Sobol.
# /Users/zeqing/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:439: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 05-29 12:40:45] ax.service.ax_client: Generated new trial 10 with parameters {'s1': 74, 's2': 51, 's3': 65, 's4': 45, 's5': 65, 's6': 72, 's7': 23, 's8': 41, 's9': 99, 's10': 14, 's11': 70, 's12': 36, 'surfactant_conc': 45, 'drug_conc': 25} using model Sobol.
# /Users/zeqing/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:439: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 05-29 12:40:45] ax.service.ax_client: Generated new trial 11 with parameters {'s1': 16, 's2': 46, 's3': 36, 's4': 95, 's5': 17, 's6': 1, 's7': 90, 's8': 71, 's9': 39, 's10': 83, 's11': 5, 's12': 69, 'surfactant_conc': 97, 'drug_conc': 91} using model Sobol.
# /Users/zeqing/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:439: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 05-29 12:40:45] ax.service.ax_client: Generated new trial 12 with parameters {'s1': 2, 's2': 67, 's3': 22, 's4': 80, 's5': 12, 's6': 39, 's7': 0, 's8': 28, 's9': 77, 's10': 39, 's11': 56, 's12': 62, 'surfactant_conc': 38, 'drug_conc': 59} using model Sobol.
# /Users/zeqing/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:439: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 05-29 12:40:45] ax.service.ax_client: Generated new trial 13 with parameters {'s1': 57, 's2': 36, 's3': 77, 's4': 29, 's5': 58, 's6': 84, 's7': 86, 's8': 60, 's9': 35, 's10': 58, 's11': 20, 's12': 45, 'surfactant_conc': 86, 'drug_conc': 32} using model Sobol.
# /Users/zeqing/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:439: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 05-29 12:40:45] ax.service.ax_client: Generated new trial 14 with parameters {'s1': 100, 's2': 98, 's3': 40, 's4': 63, 's5': 86, 's6': 62, 's7': 37, 's8': 96, 's9': 11, 's10': 91, 's11': 28, 's12': 20, 'surfactant_conc': 5, 'drug_conc': 79} using model Sobol.
# /Users/zeqing/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:439: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 05-29 12:40:46] ax.service.ax_client: Generated new trial 15 with parameters {'s1': 41, 's2': 5, 's3': 61, 's4': 14, 's5': 32, 's6': 17, 's7': 51, 's8': 16, 's9': 52, 's10': 12, 's11': 99, 's12': 88, 'surfactant_conc': 56, 'drug_conc': 7} using model Sobol.
# [INFO 05-29 12:40:46] ax.service.ax_client: Saved JSON-serialized state of optimization to `optimizer/optimizer_0.json`.

# %%
df_conc, df_vol = hf.design_to_conc_to_vol (df_design)
df_absorbance = hf.process_absorbance(iteration=n)

# %%
results = hf.build_results(df_design, df_conc, df_absorbance)

# %%
norm_results = hf.normalize_data(results, 'normalize')

# %%
ax_client = hf.load_data_to_optimizer(iteration = n, norm_results = norm_results)
ax_client
# Out:
# [INFO 05-29 12:40:46] ax.service.ax_client: Starting optimization with verbose logging. To disable logging, set the `verbose_logging` argument to `False`. Note that float values in the logs are rounded to 6 decimal points.
# [INFO 05-29 12:40:46] ax.service.ax_client: Completed trial 0 with data: {'micelle_drug_conc': (0.86, None), 'surfactant_conc': (0.81, None), 'complexity': (1.0, None)}.
# [INFO 05-29 12:40:46] ax.service.ax_client: Completed trial 1 with data: {'micelle_drug_conc': (0.0, None), 'surfactant_conc': (0.29, None), 'complexity': (1.0, None)}.
# [INFO 05-29 12:40:46] ax.service.ax_client: Completed trial 2 with data: {'micelle_drug_conc': (0.0, None), 'surfactant_conc': (0.6, None), 'complexity': (1.0, None)}.
# [INFO 05-29 12:40:46] ax.service.ax_client: Completed trial 3 with data: {'micelle_drug_conc': (0.0, None), 'surfactant_conc': (0.12, None), 'complexity': (1.0, None)}.
# [INFO 05-29 12:40:46] ax.service.ax_client: Completed trial 4 with data: {'micelle_drug_conc': (0.0, None), 'surfactant_conc': (0.71, None), 'complexity': (1.0, None)}.
# [INFO 05-29 12:40:46] ax.service.ax_client: Completed trial 5 with data: {'micelle_drug_conc': (0.97, None), 'surfactant_conc': (0.19, None), 'complexity': (0.916667, None)}.
# [INFO 05-29 12:40:46] ax.service.ax_client: Completed trial 6 with data: {'micelle_drug_conc': (0.0, None), 'surfactant_conc': (0.89, None), 'complexity': (1.0, None)}.
# [INFO 05-29 12:40:46] ax.service.ax_client: Completed trial 7 with data: {'micelle_drug_conc': (0.0, None), 'surfactant_conc': (0.4, None), 'complexity': (1.0, None)}.
# [INFO 05-29 12:40:46] ax.service.ax_client: Completed trial 8 with data: {'micelle_drug_conc': (0.38, None), 'surfactant_conc': (0.15, None), 'complexity': (1.0, None)}.
# [INFO 05-29 12:40:46] ax.service.ax_client: Completed trial 9 with data: {'micelle_drug_conc': (0.73, None), 'surfactant_conc': (0.64, None), 'complexity': (1.0, None)}.
# [INFO 05-29 12:40:46] ax.service.ax_client: Completed trial 10 with data: {'micelle_drug_conc': (0.25, None), 'surfactant_conc': (0.45, None), 'complexity': (1.0, None)}.
# [INFO 05-29 12:40:46] ax.service.ax_client: Completed trial 11 with data: {'micelle_drug_conc': (0.91, None), 'surfactant_conc': (0.97, None), 'complexity': (1.0, None)}.
# [INFO 05-29 12:40:46] ax.service.ax_client: Completed trial 12 with data: {'micelle_drug_conc': (0.59, None), 'surfactant_conc': (0.38, None), 'complexity': (0.916667, None)}.
# [INFO 05-29 12:40:46] ax.service.ax_client: Completed trial 13 with data: {'micelle_drug_conc': (0.32, None), 'surfactant_conc': (0.86, None), 'complexity': (1.0, None)}.
# [INFO 05-29 12:40:46] ax.service.ax_client: Completed trial 14 with data: {'micelle_drug_conc': (0.79, None), 'surfactant_conc': (0.05, None), 'complexity': (1.0, None)}.
# [INFO 05-29 12:40:46] ax.service.ax_client: Completed trial 15 with data: {'micelle_drug_conc': (0.07, None), 'surfactant_conc': (0.56, None), 'complexity': (1.0, None)}.
# [INFO 05-29 12:40:46] ax.service.ax_client: Saved JSON-serialized state of optimization to `optimizer/optimizer_0_loaded.json`.
# AxClient(experiment=Experiment(drug_surfactant))
