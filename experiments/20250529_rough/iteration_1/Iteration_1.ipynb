# %% [markdown]
# # import libraries

# %%
import pandas as pd
from ax.service.ax_client import AxClient, ObjectiveProperties
import matplotlib.pyplot as plt
from ax.modelbridge.factory import Models
from ax.modelbridge.generation_strategy import GenerationStep, GenerationStrategy   
import time

import sys
sys.path.append('../')
import helper_functions as hf

# %% [markdown]
# # generate recommendations

# %%
n = hf.get_iteration_number()

for i in range(3):
    print("Very Important: Please Confirm the Iteration Number is Iteration " + str(n))
# Out:
# Very Important: Please Confirm the Iteration Number is Iteration 1
# Very Important: Please Confirm the Iteration Number is Iteration 1
# Very Important: Please Confirm the Iteration Number is Iteration 1

# %%
time_start = time.time()
df_design, ax_client = hf.run_optimizer(current_iteration=n, n_trials=6)
time_end = time.time()

print()
print("Time taken for generation: " + str(round((time_end - time_start)/60,2)) + " mins")
# Out:
# [INFO 05-29 14:50:37] ax.service.ax_client: Starting optimization with verbose logging. To disable logging, set the `verbose_logging` argument to `False`. Note that float values in the logs are rounded to 6 decimal points.
# /Users/zeqing/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:439: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 05-29 14:50:37] ax.service.ax_client: Generated new trial 6 with parameters {'s1': 76, 's2': 75, 's3': 89, 's4': 91, 's5': 30, 's6': 78, 's7': 13, 's8': 47, 's9': 90, 's10': 52, 's11': 86, 's12': 13, 'surfactant_conc': 89, 'drug_conc': 45} using model Sobol.
# /Users/zeqing/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/core/data.py:295: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# /Users/zeqing/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:439: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 05-29 14:50:37] ax.service.ax_client: Generated new trial 7 with parameters {'s1': 34, 's2': 29, 's3': 12, 's4': 43, 's5': 78, 's6': 46, 's7': 100, 's8': 66, 's9': 50, 's10': 45, 's11': 38, 's12': 81, 'surfactant_conc': 40, 'drug_conc': 67} using model Sobol.
# /Users/zeqing/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/core/data.py:295: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# /Users/zeqing/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:439: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 05-29 14:50:37] ax.service.ax_client: Generated new trial 8 with parameters {'s1': 27, 's2': 82, 's3': 98, 's4': 10, 's5': 38, 's6': 30, 's7': 40, 's8': 86, 's9': 14, 's10': 69, 's11': 48, 's12': 94, 'surfactant_conc': 15, 'drug_conc': 38} using model Sobol.
# /Users/zeqing/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/core/data.py:295: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# /Users/zeqing/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:439: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 05-29 14:50:37] ax.service.ax_client: Generated new trial 9 with parameters {'s1': 82, 's2': 15, 's3': 1, 's4': 61, 's5': 92, 's6': 100, 's7': 73, 's8': 2, 's9': 73, 's10': 35, 's11': 78, 's12': 11, 'surfactant_conc': 64, 'drug_conc': 73} using model Sobol.
# /Users/zeqing/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/core/data.py:295: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# /Users/zeqing/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:439: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 05-29 14:50:37] ax.service.ax_client: Generated new trial 10 with parameters {'s1': 74, 's2': 51, 's3': 65, 's4': 45, 's5': 65, 's6': 72, 's7': 23, 's8': 41, 's9': 99, 's10': 14, 's11': 70, 's12': 36, 'surfactant_conc': 45, 'drug_conc': 25} using model Sobol.
# /Users/zeqing/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/core/data.py:295: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# /Users/zeqing/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:439: UserWarning: Encountered exception in computing model fit quality: RandomModelBridge does not support prediction.
#   warn("Encountered exception in computing model fit quality: " + str(e))
# [INFO 05-29 14:50:37] ax.service.ax_client: Generated new trial 11 with parameters {'s1': 16, 's2': 46, 's3': 36, 's4': 95, 's5': 17, 's6': 1, 's7': 90, 's8': 71, 's9': 39, 's10': 83, 's11': 5, 's12': 69, 'surfactant_conc': 97, 'drug_conc': 91} using model Sobol.
# [INFO 05-29 14:50:37] ax.service.ax_client: Saved JSON-serialized state of optimization to `optimizer/optimizer_1.json`.
# Time taken for generation: 0.0 mins

# %% [markdown]
# # process results

# %%
df_conc, df_vol = hf.design_to_conc_to_vol (df_design)
df_absorbance = hf.process_absorbance(iteration=n)

# %%
hf.generate_protocol(df_vol=df_vol, iteration=n)
# Out:
# ✅ Successfully wrote to: protocol/otflex_1.py

# %%
results = hf.build_results(df_design, df_conc, df_absorbance)

# %%
norm_results = hf.normalize_data(results, 'normalize')

# %% [markdown]
# # load the results to the optimizer

# %%
ax_client = hf.load_data_to_optimizer(iteration = n, norm_results = norm_results)
ax_client
# Out:
# [INFO 05-29 14:24:24] ax.service.ax_client: Starting optimization with verbose logging. To disable logging, set the `verbose_logging` argument to `False`. Note that float values in the logs are rounded to 6 decimal points.
# [INFO 05-29 14:24:24] ax.service.ax_client: Completed trial 6 with data: {'micelle_drug_conc': (0.45, None), 'surfactant_conc': (0.89, None), 'complexity': (1.0, None)}.
# [INFO 05-29 14:24:24] ax.service.ax_client: Completed trial 7 with data: {'micelle_drug_conc': (0.0, None), 'surfactant_conc': (0.4, None), 'complexity': (1.0, None)}.
# [INFO 05-29 14:24:24] ax.service.ax_client: Completed trial 8 with data: {'micelle_drug_conc': (0.0, None), 'surfactant_conc': (0.15, None), 'complexity': (1.0, None)}.
# [INFO 05-29 14:24:24] ax.service.ax_client: Completed trial 9 with data: {'micelle_drug_conc': (0.0, None), 'surfactant_conc': (0.64, None), 'complexity': (1.0, None)}.
# [INFO 05-29 14:24:24] ax.service.ax_client: Completed trial 10 with data: {'micelle_drug_conc': (0.0, None), 'surfactant_conc': (0.45, None), 'complexity': (1.0, None)}.
# [INFO 05-29 14:24:24] ax.service.ax_client: Completed trial 11 with data: {'micelle_drug_conc': (0.91, None), 'surfactant_conc': (0.97, None), 'complexity': (1.0, None)}.
# [INFO 05-29 14:24:24] ax.service.ax_client: Saved JSON-serialized state of optimization to `optimizer/optimizer_1_loaded.json`.
# AxClient(experiment=Experiment(drug_surfactant))
