# %% [markdown]
# # import libraries

# %%
import pandas as pd
from ax.service.ax_client import AxClient, ObjectiveProperties
import matplotlib.pyplot as plt
from ax.modelbridge.factory import Models
from ax.modelbridge.generation_strategy import GenerationStep, GenerationStrategy   
import time

import sys
sys.path.append('../')
import helper_functions as hf

# %% [markdown]
# # generate recommendations

# %%
n = hf.get_iteration_number()

for i in range(3):
    print("Very Important: Please Confirm the Iteration Number is Iteration " + str(n))
# Out:
# Very Important: Please Confirm the Iteration Number is Iteration 1
# Very Important: Please Confirm the Iteration Number is Iteration 1
# Very Important: Please Confirm the Iteration Number is Iteration 1

# %%
time_start = time.time()
df_design, ax_client = hf.run_optimizer(current_iteration=n, n_trials=6)
time_end = time.time()

print()
print("Time taken for generation: " + str(round((time_end - time_start)/60,2)) + " mins")
# Out:
# [INFO 05-30 12:45:40] ax.service.ax_client: Starting optimization with verbose logging. To disable logging, set the `verbose_logging` argument to `False`. Note that float values in the logs are rounded to 6 decimal points.
# [INFO 05-30 12:53:38] ax.service.ax_client: Generated new trial 6 with parameters {'s1': 100, 's2': 0, 's3': 81, 's4': 100, 's5': 41, 's6': 94, 's7': 100, 's8': 0, 's9': 20, 's10': 86, 's11': 59, 's12': 0, 'surfactant_conc': 1, 'drug_conc': 1} using model SAASBO.
# c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\ax\core\data.py:295: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [INFO 05-30 12:55:39] ax.service.ax_client: Generated new trial 7 with parameters {'s1': 100, 's2': 0, 's3': 0, 's4': 100, 's5': 100, 's6': 65, 's7': 100, 's8': 0, 's9': 25, 's10': 0, 's11': 0, 's12': 0, 'surfactant_conc': 1, 'drug_conc': 1} using model SAASBO.
# c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\ax\core\data.py:295: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [INFO 05-30 12:57:58] ax.service.ax_client: Generated new trial 8 with parameters {'s1': 100, 's2': 0, 's3': 100, 's4': 100, 's5': 0, 's6': 100, 's7': 100, 's8': 0, 's9': 100, 's10': 0, 's11': 100, 's12': 0, 'surfactant_conc': 1, 'drug_conc': 1} using model SAASBO.
# c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\ax\core\data.py:295: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [INFO 05-30 13:00:17] ax.service.ax_client: Generated new trial 9 with parameters {'s1': 100, 's2': 0, 's3': 0, 's4': 100, 's5': 100, 's6': 0, 's7': 100, 's8': 100, 's9': 0, 's10': 100, 's11': 100, 's12': 0, 'surfactant_conc': 1, 'drug_conc': 1} using model SAASBO.
# c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\ax\core\data.py:295: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [INFO 05-30 13:02:31] ax.service.ax_client: Generated new trial 10 with parameters {'s1': 100, 's2': 0, 's3': 100, 's4': 100, 's5': 0, 's6': 0, 's7': 100, 's8': 0, 's9': 0, 's10': 100, 's11': 0, 's12': 0, 'surfactant_conc': 1, 'drug_conc': 1} using model SAASBO.
# c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\ax\core\data.py:295: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [INFO 05-30 13:05:03] ax.service.ax_client: Generated new trial 11 with parameters {'s1': 100, 's2': 41, 's3': 0, 's4': 100, 's5': 0, 's6': 100, 's7': 100, 's8': 0, 's9': 100, 's10': 100, 's11': 0, 's12': 0, 'surfactant_conc': 1, 'drug_conc': 1} using model SAASBO.
# [INFO 05-30 13:05:03] ax.service.ax_client: Saved JSON-serialized state of optimization to `optimizer/optimizer_1.json`.
# Time taken for generation: 19.38 mins

# %% [markdown]
# # process results

# %%
df_conc, df_vol = hf.design_to_conc_to_vol (df_design)

# %%
hf.generate_protocol(df_vol=df_vol, iteration=n, plate_well='G1', deepplat_well='G1')
# Out:
# ✅ Successfully wrote to: protocol/otflex_1.py

# %%
df_absorbance = hf.process_absorbance(iteration=n)

# %%
results = hf.build_results(df_design, df_conc, df_absorbance)

# %%
norm_results = hf.normalize_data(results, 'normalize')

# %% [markdown]
# # load the results to the optimizer

# %%
ax_client = hf.load_data_to_optimizer(iteration = n, norm_results = norm_results)
ax_client
# Out:
# [INFO 05-30 15:13:39] ax.service.ax_client: Starting optimization with verbose logging. To disable logging, set the `verbose_logging` argument to `False`. Note that float values in the logs are rounded to 6 decimal points.
# [INFO 05-30 15:13:39] ax.service.ax_client: Completed trial 6 with data: {'micelle_drug_conc': (0.01, None), 'surfactant_conc': (0.01, None), 'complexity': (0.75, None)}.
# [INFO 05-30 15:13:39] ax.service.ax_client: Completed trial 7 with data: {'micelle_drug_conc': (0.01, None), 'surfactant_conc': (0.01, None), 'complexity': (0.5, None)}.
# [INFO 05-30 15:13:39] ax.service.ax_client: Completed trial 8 with data: {'micelle_drug_conc': (0.01, None), 'surfactant_conc': (0.01, None), 'complexity': (0.583333, None)}.
# [INFO 05-30 15:13:39] ax.service.ax_client: Completed trial 9 with data: {'micelle_drug_conc': (0.01, None), 'surfactant_conc': (0.01, None), 'complexity': (0.583333, None)}.
# [INFO 05-30 15:13:39] ax.service.ax_client: Completed trial 10 with data: {'micelle_drug_conc': (0.01, None), 'surfactant_conc': (0.01, None), 'complexity': (0.416667, None)}.
# [INFO 05-30 15:13:39] ax.service.ax_client: Completed trial 11 with data: {'micelle_drug_conc': (0.01, None), 'surfactant_conc': (0.01, None), 'complexity': (0.583333, None)}.
# [INFO 05-30 15:13:39] ax.service.ax_client: Saved JSON-serialized state of optimization to `optimizer/optimizer_1_loaded.json`.
# AxClient(experiment=Experiment(drug_surfactant))
