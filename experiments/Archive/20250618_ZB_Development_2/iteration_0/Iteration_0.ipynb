# %% [markdown]
# # import libraries

# %%
import pandas as pd
from ax.service.ax_client import AxClient, ObjectiveProperties
import matplotlib.pyplot as plt
from ax.modelbridge.registry import Models
from ax.modelbridge.generation_strategy import GenerationStep, GenerationStrategy   
import time

import sys
sys.path.append('../')
import helper_functions as hf
# Out:
# /var/folders/hk/7jjnrbrj53n1t8_bmkhf0_k00000gn/T/ipykernel_69963/1711932296.py:5: DeprecationWarning: Please import from 'ax.generation_strategy.generation_strategy' instead of 'ax.modelbridge.generation_strategy'. The latter is deprecated and will be removed in a future release.
#   from ax.modelbridge.generation_strategy import GenerationStep, GenerationStrategy

# %% [markdown]
# # initialize the optimizer

# %%
ax_client_init_file_name = 'optimizer/optimizer_00.json'
ax_client = hf.optimizer_init()
ax_client
# Out:
# ---------------------------------------------------------------------------
# DeprecationWarning                        Traceback (most recent call last)
# Cell In[3], line 2
#       1 ax_client_init_file_name = 'optimizer/optimizer_00.json'
# ----> 2 ax_client = hf.optimizer_init()
#       3 ax_client
#
# File ~/0_Github/drug_surfactant/experiments/Archive/20250618_ZB_Development_2/iteration_0/../helper_functions.py:34, in optimizer_init()
#      28 def optimizer_init():
#      29
#      30     # generation strategy
#      31     gs = GenerationStrategy(
#      32         steps=[
#      33             GenerationStep(
# ---> 34                 model=Models.SOBOL,
#      35                 num_trials=6,  # how many sobol trials to perform (rule of thumb: 2 * number of params)
#      36                 model_kwargs={"seed": 0},
#      37             ),
#      38             GenerationStep(
#      39                 model=Models.GPEI,
#      40                 num_trials=-1,
#      41                 model_kwargs={},
#      42             ),
#      43         ]
#      44     )
#      46     # initialize the AxClient
#      47     ax_client = AxClient(generation_strategy=gs)
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/modelbridge/registry.py:483, in ModelsMetaClass.__getattr__(self, name)
#     482 def __getattr__(self, name: str) -> None:
# --> 483     raise DeprecationWarning(
#     484         "Models is deprecated, use `ax.modelbridge.registry.Generators` instead."
#     485     )
#
# DeprecationWarning: Models is deprecated, use `ax.modelbridge.registry.Generators` instead.

# %%
ax_client.save_to_json_file(ax_client_init_file_name)

# %% [markdown]
# # generate recommendations

# %%
n = hf.get_iteration_number()

for i in range(3):
    print("Very Important: Please Confirm the Iteration Number is Iteration " + str(n))

# %%
time_start = time.time()

df_design, ax_client = hf.run_optimizer(current_iteration=n, n_trials=6)

time_end = time.time()
time_duration = round((time_end - time_start)/60,2)

print("Time taken for optimization: " + str(time_duration) + " mins")
print("Time taken for optimization: " + str(time_duration * 60) + " seconds")

# %% [markdown]
# # process results

# %%
ax_client = hf.load_design_optimizer(n)
ax_client.experiment.trials

# %%
df_conc, df_vol = hf.design_to_conc_to_vol (n)

# %%
plate_well = input("Enter the plate well starting well (e.g., F1): ")
deepplate_well = input("Enter the deep plate well starting well (e.g., F1): ")


print("Please confirm the following information:")
print("Wellplate will start at: " + plate_well)
print("Deep plate will start at: " + deepplate_well)

print()
print("*******************************************************")
print("Continue if correct, or rerun this cell if incorrect.")
print("*******************************************************")

# %%
hf.generate_protocol(df_vol=df_vol, iteration=n, plate_well=plate_well, deepplate_well=deepplate_well)

# %%
df_absorbance = hf.process_absorbance(iteration=n)
df_absorbance

# %%
results = hf.build_results(n, df_conc, df_absorbance)

# %%
results

# %%
norm_results = hf.normalize_data(results, 'normalize')

# %%
norm_results

# %% [markdown]
# # load the results to the optimizer

# %%
ax_client = hf.load_data_to_optimizer(iteration = n, norm_results = norm_results)
ax_client
