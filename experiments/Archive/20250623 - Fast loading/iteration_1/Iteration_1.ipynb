# %% [markdown]
# # import libraries

# %%
import pandas as pd
from ax.service.ax_client import AxClient, ObjectiveProperties
import matplotlib.pyplot as plt
from ax.modelbridge.factory import Models
from ax.modelbridge.generation_strategy import GenerationStep, GenerationStrategy   
import time


import sys
sys.path.append('../')
import helper_functions as hf

# %% [markdown]
# # generate recommendations

# %%
n = hf.get_iteration_number()

for i in range(3):
    print("Very Important: Please Confirm the Iteration Number is Iteration " + str(n))
# Out:
# Very Important: Please Confirm the Iteration Number is Iteration 1
# Very Important: Please Confirm the Iteration Number is Iteration 1
# Very Important: Please Confirm the Iteration Number is Iteration 1

# %%
time_start = time.time()


df_design, ax_client = hf.run_optimizer(current_iteration=n, drug = "IBP", bopt = 1,n_trials=6)

time_end = time.time()
time_duration = round((time_end - time_start)/60,2)

print("Time taken for optimization: " + str(time_duration) + " mins")
print("Time taken for optimization: " + str(time_duration * 60) + " seconds")
# Out:
# [INFO 06-25 09:44:44] ax.service.ax_client: Starting optimization with verbose logging. To disable logging, set the `verbose_logging` argument to `False`. Note that float values in the logs are rounded to 6 decimal points.
# [INFO 06-25 09:44:44] ax.modelbridge.transforms.standardize_y: Outcome complexity is constant, within tolerance.
# **************************************************************************************************************
#
# Generating Bayesian Optimization trialsfor
# Drug name:  Ibuprofen IBP  | Iteration:  1
#
# **************************************************************************************************************
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/botorch/models/utils/assorted.py:267: InputDataWarning: Data (outcome observations) is not standardized (std = tensor([0.], dtype=torch.float64), mean = tensor([0.], dtype=torch.float64)).Please consider scaling the input to zero mean and unit variance.
#   check_standardization(Y=train_Y, raise_on_fail=raise_on_fail)
# [INFO 06-25 09:46:31] ax.service.ax_client: Generated new trial 6 with parameters {'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 0, 's2': 0, 's3': 100, 's4': 100, 's5': 0, 's6': 100, 's7': 100, 's8': 0, 'surfactant_conc': 1, 'drug_conc': 100} using model SAASBO.
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/core/data.py:295: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [INFO 06-25 09:46:31] ax.modelbridge.transforms.standardize_y: Outcome complexity is constant, within tolerance.
# [INFO 06-25 09:48:07] ax.service.ax_client: Generated new trial 7 with parameters {'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 0, 's2': 0, 's3': 0, 's4': 100, 's5': 0, 's6': 0, 's7': 100, 's8': 0, 'surfactant_conc': 1, 'drug_conc': 100} using model SAASBO.
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/core/data.py:295: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [INFO 06-25 09:48:07] ax.modelbridge.transforms.standardize_y: Outcome complexity is constant, within tolerance.
# [INFO 06-25 09:50:21] ax.service.ax_client: Generated new trial 8 with parameters {'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 0, 's2': 0, 's3': 100, 's4': 0, 's5': 100, 's6': 100, 's7': 100, 's8': 0, 'surfactant_conc': 58, 'drug_conc': 100} using model SAASBO.
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/core/data.py:295: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [INFO 06-25 09:50:21] ax.modelbridge.transforms.standardize_y: Outcome complexity is constant, within tolerance.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 time_start = time.time()
# ----> 4 df_design, ax_client = hf.run_optimizer(current_iteration=n, drug = "IBP", bopt = 1,n_trials=6)
#       6 time_end = time.time()
#       7 time_duration = round((time_end - time_start)/60,2)
#
# File ~/Documents/GitHub/drug_surfactant/experiments/Archive/20250623 - Fast loading/iteration_1/../helper_functions.py:254, in run_optimizer(current_iteration, drug, bopt, n_trials)
#     251 print()
#     252 print("**************************************************************************************************************")
# --> 254 trials, _ = ax_client.get_next_trials(n_trials, fixed_features=drug_features)
#     256 # Prepare the trial data for DataFrame
#     257 trials_data = []
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/service/ax_client.py:671, in AxClient.get_next_trials(self, max_trials, ttl_seconds, fixed_features)
#     669 for _ in range(max_trials):
#     670     try:
# --> 671         params, trial_index = self.get_next_trial(
#     672             ttl_seconds=ttl_seconds, fixed_features=fixed_features
#     673         )
#     674         trials_dict[trial_index] = params
#     675     except OptimizationComplete as err:
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/utils/common/executils.py:169, in retry_on_exception.<locals>.func_wrapper.<locals>.actual_wrapper(*args, **kwargs)
#     165             wait_interval = min(
#     166                 MAX_WAIT_SECONDS, initial_wait_seconds * 2 ** (i - 1)
#     167             )
#     168             time.sleep(wait_interval)
# --> 169         return func(*args, **kwargs)
#     171 # If we are here, it means the retries were finished but
#     172 # The error was suppressed. Hence return the default value provided.
#     173 return default_return_on_suppression
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/service/ax_client.py:576, in AxClient.get_next_trial(self, ttl_seconds, force, fixed_features)
#     572         raise OptimizationShouldStop(message=global_stopping_message)
#     574 try:
#     575     trial = self.experiment.new_trial(
# --> 576         generator_run=self._gen_new_generator_run(
#     577             fixed_features=fixed_features
#     578         ),
#     579         ttl_seconds=ttl_seconds,
#     580     )
#     581 except MaxParallelismReachedException as e:
#     582     if self._early_stopping_strategy is not None:
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/service/ax_client.py:1818, in AxClient._gen_new_generator_run(self, n, fixed_features)
#    1810 fixed_feats = (
#    1811     InstantiationBase.make_fixed_observation_features(
#    1812         fixed_features=fixed_features
#    (...)   1815     else None
#    1816 )
#    1817 with with_rng_seed(seed=self._random_seed):
# -> 1818     return none_throws(self.generation_strategy).gen(
#    1819         experiment=self.experiment,
#    1820         n=n,
#    1821         pending_observations=self._get_pending_observation_features(
#    1822             experiment=self.experiment
#    1823         ),
#    1824         fixed_features=fixed_feats,
#    1825     )
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/generation_strategy.py:339, in GenerationStrategy.gen(self, experiment, data, pending_observations, n, fixed_features)
#     304 def gen(
#     305     self,
#     306     experiment: Experiment,
#    (...)    310     fixed_features: ObservationFeatures | None = None,
#     311 ) -> GeneratorRun:
#     312     """Produce the next points in the experiment. Additional kwargs passed to
#     313     this method are propagated directly to the underlying model's `gen`, along
#     314     with the `model_gen_kwargs` set on the current generation node.
#    (...)    337             resuggesting points that are currently being evaluated.
#     338     """
# --> 339     gr = self._gen_with_multiple_nodes(
#     340         experiment=experiment,
#     341         data=data,
#     342         n=n,
#     343         pending_observations=pending_observations,
#     344         fixed_features=fixed_features,
#     345     )
#     346     if len(gr) > 1:
#     347         raise UnsupportedError(
#     348             "By calling into GenerationStrategy.gen(), you are should be "
#     349             "expecting a single `Trial` with only one `GeneratorRun`. However, "
#     350             "the underlying GenerationStrategy produced multiple `GeneratorRuns` "
#     351             f"and returned the following list of `GeneratorRun`-s: {gr}"
#     352         )
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/generation_strategy.py:453, in GenerationStrategy._gen_with_multiple_nodes(self, experiment, data, pending_observations, n, fixed_features, arms_per_node)
#     451 if arms_from_node != 0:
#     452     try:
# --> 453         curr_node_gr = self._curr.gen(
#     454             n=arms_from_node,
#     455             pending_observations=pending_observations,
#     456             arms_by_signature_for_deduplication=(
#     457                 experiment.arms_by_signature_for_deduplication
#     458             ),
#     459             fixed_features=fixed_features_from_node,
#     460         )
#     461     except DataRequiredError as err:
#     462         # Model needs more data, so we log the error and return
#     463         # as many generator runs as we were able to produce, unless
#     464         # no trials were produced at all (in which case its safe to raise).
#     465         if len(grs) == 0:
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/generation_node.py:902, in GenerationStep.gen(self, n, pending_observations, max_gen_draws_for_deduplication, arms_by_signature_for_deduplication, **model_gen_kwargs)
#     894 def gen(
#     895     self,
#     896     n: int | None = None,
#    (...)    900     **model_gen_kwargs: Any,
#     901 ) -> GeneratorRun:
# --> 902     gr = super().gen(
#     903         n=n,
#     904         pending_observations=pending_observations,
#     905         max_gen_draws_for_deduplication=max_gen_draws_for_deduplication,
#     906         arms_by_signature_for_deduplication=arms_by_signature_for_deduplication,
#     907         **model_gen_kwargs,
#     908     )
#     909     gr._generation_step_index = self.index
#     910     return gr
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/generation_node.py:408, in GenerationNode.gen(self, n, pending_observations, max_gen_draws_for_deduplication, arms_by_signature_for_deduplication, **model_gen_kwargs)
#     405 # Keep generating until each of `generator_run.arms` is not a duplicate
#     406 # of a previous arm, if `should_deduplicate is True`
#     407 while should_generate_run:
# --> 408     generator_run = self._gen(
#     409         n=n,
#     410         pending_observations=pending_observations,
#     411         **model_gen_kwargs,
#     412     )
#     413     should_generate_run = (
#     414         self.should_deduplicate
#     415         and arms_by_signature_for_deduplication
#    (...)    419         )
#     420     )
#     421     n_gen_draws += 1
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/generation_node.py:479, in GenerationNode._gen(self, n, pending_observations, **model_gen_kwargs)
#     475 if n is None and model_spec.model_gen_kwargs:
#     476     # If `n` is not specified, ensure that the `None` value does not
#     477     # override the one set in `model_spec.model_gen_kwargs`.
#     478     n = model_spec.model_gen_kwargs.get("n", None)
# --> 479 return model_spec.gen(
#     480     n=n,
#     481     # For `pending_observations`, prefer the input to this function, as
#     482     # `pending_observations` are dynamic throughout the experiment and thus
#     483     # unlikely to be specified in `model_spec.model_gen_kwargs`.
#     484     pending_observations=pending_observations,
#     485     **model_gen_kwargs,
#     486 )
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/model_spec.py:238, in ModelSpec.gen(self, **model_gen_kwargs)
#     236 # copy to ensure there is no in-place modification
#     237 model_gen_kwargs = deepcopy(model_gen_kwargs)
# --> 238 generator_run = fitted_model.gen(**model_gen_kwargs)
#     239 fit_and_std_quality_and_generalization_dict = (
#     240     get_fit_and_std_quality_and_generalization_dict(
#     241         fitted_model_bridge=self.fitted_model,
#     242     )
#     243 )
#     244 generator_run._gen_metadata = (
#     245     {} if generator_run.gen_metadata is None else generator_run.gen_metadata
#     246 )
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/base.py:861, in ModelBridge.gen(self, n, search_space, optimization_config, pending_observations, fixed_features, model_gen_options)
#     854 base_gen_args = self._get_transformed_gen_args(
#     855     search_space=search_space,
#     856     optimization_config=optimization_config,
#     857     pending_observations=pending_observations,
#     858     fixed_features=fixed_features,
#     859 )
#     860 # Apply terminal transform and gen
# --> 861 gen_results = self._gen(
#     862     n=n,
#     863     search_space=base_gen_args.search_space,
#     864     optimization_config=base_gen_args.optimization_config,
#     865     pending_observations=base_gen_args.pending_observations,
#     866     fixed_features=base_gen_args.fixed_features,
#     867     model_gen_options=model_gen_options,
#     868 )
#     870 observation_features = gen_results.observation_features
#     871 best_obsf = gen_results.best_observation_features
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/torch.py:711, in TorchModelBridge._gen(self, n, search_space, pending_observations, fixed_features, model_gen_options, optimization_config)
#     702 search_space_digest, torch_opt_config = self._get_transformed_model_gen_args(
#     703     search_space=search_space,
#     704     pending_observations=pending_observations,
#    (...)    707     optimization_config=optimization_config,
#     708 )
#     710 # Generate the candidates
# --> 711 gen_results = none_throws(self.model).gen(
#     712     n=n,
#     713     search_space_digest=search_space_digest,
#     714     torch_opt_config=torch_opt_config,
#     715 )
#     717 gen_metadata = dict(gen_results.gen_metadata)
#     718 if (
#     719     isinstance(optimization_config, MultiObjectiveOptimizationConfig)
#     720     and gen_metadata.get("objective_thresholds", None) is not None
#    (...)    724     # if using a hypervolume based acquisition function, then
#     725     # the inferred objective thresholds are in gen_metadata.
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/models/torch/botorch_modular/model.py:255, in BoTorchModel.gen(self, n, search_space_digest, torch_opt_config)
#     249 acqf = self._instantiate_acquisition(
#     250     search_space_digest=search_space_digest,
#     251     torch_opt_config=torch_opt_config,
#     252     acq_options=acq_options,
#     253 )
#     254 botorch_rounding_func = get_rounding_func(torch_opt_config.rounding_func)
# --> 255 candidates, expected_acquisition_value, weights = acqf.optimize(
#     256     n=n,
#     257     search_space_digest=search_space_digest,
#     258     inequality_constraints=_to_inequality_constraints(
#     259         linear_constraints=torch_opt_config.linear_constraints
#     260     ),
#     261     fixed_features=torch_opt_config.fixed_features,
#     262     rounding_func=botorch_rounding_func,
#     263     optimizer_options=assert_is_instance(
#     264         opt_options,
#     265         dict,
#     266     ),
#     267 )
#     268 gen_metadata = self._get_gen_metadata_from_acqf(
#     269     acqf=acqf,
#     270     torch_opt_config=torch_opt_config,
#     271     expected_acquisition_value=expected_acquisition_value,
#     272 )
#     273 # log what model was used
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/models/torch/botorch_modular/acquisition.py:441, in Acquisition.optimize(self, n, search_space_digest, inequality_constraints, fixed_features, rounding_func, optimizer_options)
#     429     candidates, acqf_values = optimize_acqf_mixed(
#     430         acq_function=self.acqf,
#     431         bounds=bounds,
#    (...)    438         **optimizer_options_with_defaults,
#     439     )
#     440 elif optimizer == "optimize_acqf_mixed_alternating":
# --> 441     candidates, acqf_values = optimize_acqf_mixed_alternating(
#     442         acq_function=self.acqf,
#     443         bounds=bounds,
#     444         discrete_dims=search_space_digest.ordinal_features,
#     445         q=n,
#     446         post_processing_func=rounding_func,
#     447         fixed_features=fixed_features,
#     448         inequality_constraints=inequality_constraints,
#     449         **optimizer_options_with_defaults,
#     450     )
#     451 else:
#     452     raise AxError(  # pragma: no cover
#     453         f"Unknown optimizer: {optimizer}. This code should be unreachable."
#     454     )
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/botorch/optim/optimize_mixed.py:679, in optimize_acqf_mixed_alternating(acq_function, bounds, discrete_dims, options, q, raw_samples, num_restarts, post_processing_func, sequential, fixed_features, inequality_constraints)
#     677 discrete_dims = [dim for dim in discrete_dims if dim not in fixed_features]
#     678 if len(discrete_dims) == 0:
# --> 679     return _optimize_acqf(opt_inputs=opt_inputs)
#     680 if not (
#     681     isinstance(discrete_dims, list)
#     682     and len(set(discrete_dims)) == len(discrete_dims)
#     683     and min(discrete_dims) >= 0
#     684     and max(discrete_dims) <= dim - 1
#     685 ):
#     686     raise ValueError(
#     687         "`discrete_dims` must be a list with unique integers "
#     688         "between 0 and num_dims - 1."
#     689     )
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/botorch/optim/optimize.py:652, in _optimize_acqf(opt_inputs)
#     649     return _optimize_acqf_sequential_q(opt_inputs=opt_inputs)
#     651 # Batch optimization (including the case q=1)
# --> 652 return _optimize_acqf_batch(opt_inputs=opt_inputs)
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/botorch/optim/optimize.py:408, in _optimize_acqf_batch(opt_inputs)
#     405         batch_acq_values = torch.cat(batch_acq_values_list).flatten()
#     406     return batch_candidates, batch_acq_values, opt_warnings
# --> 408 batch_candidates, batch_acq_values, ws = _optimize_batch_candidates()
#     410 optimization_warning_raised = any(
#     411     issubclass(w.category, OptimizationWarning) for w in ws
#     412 )
#     413 if optimization_warning_raised and opt_inputs.retry_on_optimization_warning:
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/botorch/optim/optimize.py:385, in _optimize_acqf_batch.<locals>._optimize_batch_candidates()
#     380 with warnings.catch_warnings(record=True) as ws:
#     381     warnings.simplefilter("always", category=OptimizationWarning)
#     382     (
#     383         batch_candidates_curr,
#     384         batch_acq_values_curr,
# --> 385     ) = opt_inputs.gen_candidates(
#     386         batched_ics_,
#     387         opt_inputs.acq_function,
#     388         lower_bounds=lower_bounds,
#     389         upper_bounds=upper_bounds,
#     390         options=gen_options,
#     391         fixed_features=opt_inputs.fixed_features,
#     392         timeout_sec=timeout_sec,
#     393         **gen_kwargs,
#     394     )
#     395 opt_warnings += ws
#     396 batch_candidates_list.append(batch_candidates_curr)
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/botorch/generation/gen.py:148, in gen_candidates_scipy(initial_conditions, acquisition_function, lower_bounds, upper_bounds, inequality_constraints, equality_constraints, nonlinear_inequality_constraints, options, fixed_features, timeout_sec)
#     137 _no_fixed_features = _remove_fixed_features_from_optimization(
#     138     fixed_features=fixed_features,
#     139     acquisition_function=acquisition_function,
#    (...)    145     nonlinear_inequality_constraints=nonlinear_inequality_constraints,
#     146 )
#     147 # call the routine with no fixed_features
# --> 148 clamped_candidates, batch_acquisition = gen_candidates_scipy(
#     149     initial_conditions=_no_fixed_features.initial_conditions,
#     150     acquisition_function=_no_fixed_features.acquisition_function,
#     151     lower_bounds=_no_fixed_features.lower_bounds,
#     152     upper_bounds=_no_fixed_features.upper_bounds,
#     153     inequality_constraints=_no_fixed_features.inequality_constraints,
#     154     equality_constraints=_no_fixed_features.equality_constraints,
#     155     nonlinear_inequality_constraints=_no_fixed_features.nonlinear_inequality_constraints,  # noqa: E501
#     156     options=options,
#     157     fixed_features=None,
#     158     timeout_sec=timeout_sec,
#     159 )
#     160 clamped_candidates = _no_fixed_features.acquisition_function._construct_X_full(
#     161     clamped_candidates
#     162 )
#     163 return clamped_candidates, batch_acquisition
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/botorch/generation/gen.py:240, in gen_candidates_scipy(initial_conditions, acquisition_function, lower_bounds, upper_bounds, inequality_constraints, equality_constraints, nonlinear_inequality_constraints, options, fixed_features, timeout_sec)
#     237 def f(x):
#     238     return -acquisition_function(x)
# --> 240 res = minimize_with_timeout(
#     241     fun=f_np_wrapper,
#     242     args=(f,),
#     243     x0=x0,
#     244     method=options.get("method", "SLSQP" if constraints else "L-BFGS-B"),
#     245     jac=with_grad,
#     246     bounds=bounds,
#     247     constraints=constraints,
#     248     callback=options.get("callback", None),
#     249     options={
#     250         k: v
#     251         for k, v in options.items()
#     252         if k not in ["method", "callback", "with_grad"]
#     253     },
#     254     timeout_sec=timeout_sec,
#     255 )
#     256 _process_scipy_result(res=res, options=options)
#     258 candidates = fix_features(
#     259     X=torch.from_numpy(res.x).to(initial_conditions).reshape(shapeX),
#     260     fixed_features=fixed_features,
#     261 )
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/botorch/optim/utils/timeout.py:86, in minimize_with_timeout(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options, timeout_sec)
#      83     # To prevent slowdowns after scipy 1.15.
#      84     # See https://github.com/scipy/scipy/issues/22438.
#      85     with threadpool_limits(limits=1, user_api="blas"):
# ---> 86         return optimize.minimize(
#      87             fun=fun,
#      88             x0=x0,
#      89             args=args,
#      90             method=method,
#      91             jac=jac,
#      92             hess=hess,
#      93             hessp=hessp,
#      94             bounds=bounds,
#      95             constraints=constraints,
#      96             tol=tol,
#      97             callback=wrapped_callback,
#      98             options=options,
#      99         )
#     100 except OptimizationTimeoutError as e:
#     101     msg = f"Optimization timed out after {e.runtime} seconds."
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/scipy/optimize/_minimize.py:750, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     747     res = _minimize_cobyqa(fun, x0, args, bounds, constraints, callback,
#     748                            **options)
#     749 elif meth == 'slsqp':
# --> 750     res = _minimize_slsqp(fun, x0, args, jac, bounds,
#     751                           constraints, callback=callback, **options)
#     752 elif meth == 'trust-constr':
#     753     res = _minimize_trustregion_constr(fun, x0, args, jac, hess, hessp,
#     754                                        bounds, constraints,
#     755                                        callback=callback, **options)
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/scipy/optimize/_slsqp_py.py:435, in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, finite_diff_rel_step, **unknown_options)
#     429 slsqp(m, meq, x, xl, xu, fx, c, g, a, acc, majiter, mode, w, jw,
#     430       alpha, f0, gs, h1, h2, h3, h4, t, t0, tol,
#     431       iexact, incons, ireset, itermx, line,
#     432       n1, n2, n3)
#     434 if mode == 1:  # objective and constraint evaluation required
# --> 435     fx = wrapped_fun(x)
#     436     c = _eval_constraint(x, cons)
#     438 if mode == -1:  # gradient evaluation required
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/scipy/optimize/_optimize.py:305, in _clip_x_for_func.<locals>.eval(x)
#     303 def eval(x):
#     304     x = _check_clip_x(x, bounds)
# --> 305     return func(x)
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:326, in ScalarFunction.fun(self, x)
#     324 if not np.array_equal(x, self.x):
#     325     self._update_x(x)
# --> 326 self._update_fun()
#     327 return self.f
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:295, in ScalarFunction._update_fun(self)
#     293 def _update_fun(self):
#     294     if not self.f_updated:
# --> 295         fx = self._wrapped_fun(self.x)
#     296         if fx < self._lowest_f:
#     297             self._lowest_x = self.x
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:21, in _wrapper_fun.<locals>.wrapped(x)
#      17 ncalls[0] += 1
#      18 # Send a copy because the user may overwrite it.
#      19 # Overwriting results in undefined behaviour because
#      20 # fun(self.x) will change self.x, with the two no longer linked.
# ---> 21 fx = fun(np.copy(x), *args)
#      22 # Make sure the function returns a true scalar
#      23 if not np.isscalar(fx):
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/scipy/optimize/_optimize.py:80, in MemoizeJac.__call__(self, x, *args)
#      78 def __call__(self, x, *args):
#      79     """ returns the function value """
# ---> 80     self._compute_if_needed(x, *args)
#      81     return self._value
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/scipy/optimize/_optimize.py:74, in MemoizeJac._compute_if_needed(self, x, *args)
#      72 if not np.all(x == self.x) or self._value is None or self.jac is None:
#      73     self.x = np.asarray(x).copy()
# ---> 74     fg = self.fun(x, *args)
#      75     self.jac = fg[1]
#      76     self._value = fg[0]
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/botorch/generation/gen.py:197, in gen_candidates_scipy.<locals>.f_np_wrapper(x, f)
#     189 X = (
#     190     torch.from_numpy(x)
#     191     .to(initial_conditions)
#    (...)    194     .requires_grad_(True)
#     195 )
#     196 X_fix = fix_features(X, fixed_features=fixed_features)
# --> 197 loss = f(X_fix).sum()
#     198 # compute gradient w.r.t. the inputs (does not accumulate in leaves)
#     199 gradf = _arrayify(torch.autograd.grad(loss, X)[0].contiguous().view(-1))
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/botorch/generation/gen.py:238, in gen_candidates_scipy.<locals>.f(x)
#     237 def f(x):
# --> 238     return -acquisition_function(x)
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/botorch/acquisition/fixed_feature.py:154, in FixedFeatureAcquisitionFunction.forward(self, X)
#     143 r"""Evaluate base acquisition function under the fixed features.
#     144
#     145 Args:
#    (...)    151     `_construct_X_full`).
#     152 """
#     153 X_full = self._construct_X_full(X)
# --> 154 return self.acq_func(X_full)
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/botorch/utils/transforms.py:344, in concatenate_pending_points.<locals>.decorated(cls, X, **kwargs)
#     342 if cls.X_pending is not None:
#     343     X = torch.cat([X, match_batch_shape(cls.X_pending, X)], dim=-2)
# --> 344 return method(cls, X, **kwargs)
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/botorch/utils/transforms.py:298, in t_batch_mode_transform.<locals>.decorator.<locals>.decorated(acqf, X, *args, **kwargs)
#     296 # add t-batch dim
#     297 X = X if X.dim() > 2 else X.unsqueeze(0)
# --> 298 output = method(acqf, X, *args, **kwargs)
#     299 if hasattr(acqf, "model") and is_ensemble(acqf.model):
#     300     # IDEA: this could be wrapped into SampleReducingMCAcquisitionFunction
#     301     output = (
#     302         output.mean(dim=-1) if not acqf._log else logmeanexp(output, dim=-1)
#     303     )
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/botorch/acquisition/multi_objective/logei.py:466, in qLogNoisyExpectedHypervolumeImprovement.forward(self, X)
#     464 samples = self._get_f_X_samples(posterior=posterior, q_in=q_in)
#     465 # Add previous nehvi from pending points.
# --> 466 nehvi = self._compute_log_qehvi(samples=samples, X=X)
#     467 if self.incremental_nehvi:
#     468     return nehvi
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/botorch/acquisition/multi_objective/logei.py:226, in qLogExpectedHypervolumeImprovement._compute_log_qehvi(self, samples, X)
#     220 log_improvement_i = self._log_improvement(obj_subsets, view_shape)
#     222 # 2) take the minimum log improvement over all i subsets.
#     223 # since all hyperrectangles share one vertex, the opposite vertex of the
#     224 # overlap is given by the component-wise minimum.
#     225 # negative of maximum of negative log_improvement is approximation to min.
# --> 226 log_improvement_i = self._smooth_min(
#     227     log_improvement_i,
#     228     dim=-2,
#     229 )  # mc_samples x batch_shape x num_cells x q_choose_i x m
#     231 # 3) compute the log lengths of the cells' sides.
#     232 # mc_samples x batch_shape x num_cells x q_choose_i x m
#     233 log_lengths_i = self._log_cell_lengths(log_improvement_i, view_shape)
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/botorch/acquisition/multi_objective/logei.py:305, in qLogExpectedHypervolumeImprovement._smooth_min(self, X, dim, keepdim)
#     303 def _smooth_min(self, X: Tensor, dim: int, keepdim: bool = False) -> Tensor:
#     304     f = fatmin if self.fat else smooth_amin
# --> 305     return f(X, tau=self.tau_max, dim=dim)
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/botorch/utils/safe_math.py:371, in fatmin(x, dim, keepdim, tau, alpha)
#     348 def fatmin(
#     349     x: Tensor,
#     350     dim: int | tuple[int, ...],
#    (...)    353     alpha: float = ALPHA,
#     354 ) -> Tensor:
#     355     """Computes a smooth approximation to amin(X, dim=dim) with a fat tail.
#     356
#     357     Args:
#    (...)    369         A Tensor of smooth approximations to `amin(X, dim=dim)` with a fat tail.
#     370     """
# --> 371     return -fatmax(-x, dim=dim, keepdim=keepdim, tau=tau, alpha=alpha)
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/botorch/utils/safe_math.py:345, in fatmax(x, dim, keepdim, tau, alpha)
#     342 def max_fun(x: Tensor, dim: int | tuple[int, ...], keepdim: bool = False) -> Tensor:
#     343     return tau * _pareto(-x / tau, alpha=alpha).sum(dim=dim, keepdim=keepdim).log()
# --> 345 return _inf_max_helper(max_fun=max_fun, x=x, dim=dim, keepdim=keepdim)
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/botorch/utils/safe_math.py:178, in _inf_max_helper(max_fun, x, dim, keepdim)
#     172 M_no_inf = M.masked_fill(M.isinf(), 0.0)
#     173 y_no_inf = x.masked_fill(has_inf_max, 0.0) - M_no_inf
#     175 res = torch.where(
#     176     has_inf_max,
#     177     y_inf.sum(dim=dim, keepdim=True),
# --> 178     M_no_inf + max_fun(y_no_inf, dim=dim, keepdim=True),
#     179 )
#     180 # NOTE: Using `sum` instead of `squeeze` because PyTorch < 2.0 does not support
#     181 # tuple `dim` arguments. `sum` and `squeeze` are equivalent here because the
#     182 # `dim` dimensions have length one after the reductions in the previous lines.
#     183 # TODO: Replace `sum` with `squeeze` once PyTorch >= 2.0 is required.
#     184 return res if keepdim else res.sum(dim=dim)
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/botorch/utils/safe_math.py:343, in fatmax.<locals>.max_fun(x, dim, keepdim)
#     342 def max_fun(x: Tensor, dim: int | tuple[int, ...], keepdim: bool = False) -> Tensor:
# --> 343     return tau * _pareto(-x / tau, alpha=alpha).sum(dim=dim, keepdim=keepdim).log()
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/botorch/utils/safe_math.py:447, in _pareto(x, alpha, check)
#     443     """Computes a Lorentzian, i.e. an un-normalized Cauchy density function."""
#     444     return 1 / (1 + x.square())
# --> 447 def _pareto(x: Tensor, alpha: float, check: bool = True) -> Tensor:
#     448     """Computes a rational polynomial that is
#     449     1) monotonically decreasing for `x > 0`,
#     450     2) is equal to 1 at `x = 0`,
#    (...)    463         The tensor corresponding to the rational polynomial with the stated properties.
#     464     """
#     465     if check and (x < 0).any():
#
# KeyboardInterrupt:

# %% [markdown]
# # process results

# %%
ax_client = hf.load_design_optimizer(n)
ax_client.experiment.trials

# %%
df_conc, df_vol = hf.design_to_conc_to_vol (n)

# %%
plate_well = input("Enter the plate well starting well (e.g., F1): ")
deepplate_well = input("Enter the deep plate well starting well (e.g., F1): ")


print("Please confirm the following information:")
print("Wellplate will start at: " + plate_well)
print("Deep plate will start at: " + deepplate_well)

print()
print("*******************************************************")
print("Continue if correct, or rerun this cell if incorrect.")
print("*******************************************************")

# %%
hf.generate_protocol(df_vol=df_vol, iteration=n, plate_well=plate_well, deepplate_well=deepplate_well)

# %%
df_absorbance = hf.process_absorbance(iteration=n, threshold=0.1)
df_absorbance

# %%
results = hf.build_results(n, df_conc, df_absorbance)
results

# %%
norm_results = hf.normalize_data(results, 'normalize')

# %%
norm_results

# %% [markdown]
# # load the results to the optimizer

# %%
ax_client = hf.load_data_to_optimizer(iteration = n, norm_results = norm_results)
ax_client
