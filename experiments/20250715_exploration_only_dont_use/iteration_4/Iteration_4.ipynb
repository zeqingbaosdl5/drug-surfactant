# %% [markdown]
# # import libraries

# %%
import pandas as pd
from ax.service.ax_client import AxClient, ObjectiveProperties
import matplotlib.pyplot as plt
from ax.modelbridge.registry import Models
from ax.modelbridge.generation_strategy import GenerationStep, GenerationStrategy   
import time


import sys
sys.path.append('../')
import helper_functions as hf
# Out:
# /var/folders/9p/f66yhymx35939zzlg51g0rrc0000gn/T/ipykernel_60007/3307975217.py:5: DeprecationWarning: Please import from 'ax.generation_strategy.generation_strategy' instead of 'ax.modelbridge.generation_strategy'. The latter is deprecated and will be removed in a future release.
#   from ax.modelbridge.generation_strategy import GenerationStep, GenerationStrategy

# %% [markdown]
# # generate recommendations

# %%
n = hf.get_iteration_number()

for i in range(3):
    print("Very Important: Please Confirm the Iteration Number is Iteration " + str(n))

print()

list_of_drugs = ['IBP'] * 2 + ['LOV'] * 2 + ['DCF'] * 2 + ['GLV'] * 2

for i in range(3):
    print("Very Important: Please Confirm the Drugs are: ", list_of_drugs)
# Out:
# Very Important: Please Confirm the Iteration Number is Iteration 4
# Very Important: Please Confirm the Iteration Number is Iteration 4
# Very Important: Please Confirm the Iteration Number is Iteration 4
#
# Very Important: Please Confirm the Drugs are:  ['IBP', 'IBP', 'LOV', 'LOV', 'DCF', 'DCF', 'GLV', 'GLV']
# Very Important: Please Confirm the Drugs are:  ['IBP', 'IBP', 'LOV', 'LOV', 'DCF', 'DCF', 'GLV', 'GLV']
# Very Important: Please Confirm the Drugs are:  ['IBP', 'IBP', 'LOV', 'LOV', 'DCF', 'DCF', 'GLV', 'GLV']

# %%
results_so_far = hf.results_so_far(n)
results_so_far
# Out:
#     trial_index arm_name trial_status   generation_node  success  \
# 0             0      0_0    COMPLETED  GenerationStep_0      0.0
# 1             1      1_0    COMPLETED  GenerationStep_0      0.0
# 2             2      2_0    COMPLETED  GenerationStep_0      0.0
# 3             3      3_0    COMPLETED  GenerationStep_0      0.0
# 4             4      4_0    COMPLETED  GenerationStep_0      0.0
# 5             5      5_0    COMPLETED  GenerationStep_0      0.0
# 6             6      6_0    COMPLETED  GenerationStep_0      0.0
# 7             7      7_0    COMPLETED  GenerationStep_0      0.0
# 8             8      8_0    COMPLETED  GenerationStep_1      1.0
# 9             9      9_0    COMPLETED  GenerationStep_1      1.0
# 10           10     10_0    COMPLETED  GenerationStep_1      0.0
# 11           11     11_0    COMPLETED  GenerationStep_1      0.0
# 12           12     12_0    COMPLETED  GenerationStep_1      0.0
# 13           13     13_0    COMPLETED  GenerationStep_1      0.0
# 14           14     14_0    COMPLETED  GenerationStep_1      0.0
# 15           15     15_0    COMPLETED  GenerationStep_1      0.0
# 16           16     16_0    COMPLETED  GenerationStep_1      1.0
# 17           17     17_0    COMPLETED  GenerationStep_1      1.0
# 18           18     18_0    COMPLETED  GenerationStep_1      0.0
# 19           19     19_0    COMPLETED  GenerationStep_1      0.0
# 20           20     20_0    COMPLETED  GenerationStep_1      1.0
# 21           21     21_0    COMPLETED  GenerationStep_1      0.0
# 22           22     22_0    COMPLETED  GenerationStep_1      0.0
# 23           23     23_0    COMPLETED  GenerationStep_1      0.0
# 24           24     24_0    COMPLETED  GenerationStep_1      1.0
# 25           25     25_0    COMPLETED  GenerationStep_1      1.0
# 26           26     26_0    COMPLETED  GenerationStep_1      1.0
# 27           27     27_0    COMPLETED  GenerationStep_1      0.0
# 28           28     28_0    COMPLETED  GenerationStep_1      1.0
# 29           29     29_0    COMPLETED  GenerationStep_1      1.0
# 30           30     30_0    COMPLETED  GenerationStep_1      0.0
# 31           31     31_0    COMPLETED  GenerationStep_1      0.0
#
#     surfactant_input  complexity  Drug_MW  Drug_LogP  Drug_TPSA   s1   s2  \
# 0                1.0       1.000   0.2063     0.3073     0.0373   48   60
# 1                1.0       1.000   0.2063     0.3073     0.0373   74    0
# 2                1.0       1.000   0.4045     0.4196     0.0728   78   88
# 3                1.0       1.000   0.4045     0.4196     0.0728    0   46
# 4                1.0       1.000   0.2962     0.4364     0.0493   16   82
# 5                1.0       1.000   0.2962     0.4364     0.0493   93   27
# 6                1.0       1.000   0.3528     0.2810     0.0711   59   65
# 7                1.0       1.000   0.3528     0.2810     0.0711   31   19
# 8                1.0       0.750   0.2063     0.3073     0.0373    0  100
# 9                1.0       0.375   0.2063     0.3073     0.0373    0  100
# 10               1.0       1.000   0.4045     0.4196     0.0728  100    0
# 11               1.0       1.000   0.4045     0.4196     0.0728    0    0
# 12               1.0       1.000   0.2962     0.4364     0.0493  100  100
# 13               1.0       1.000   0.2962     0.4364     0.0493    0    0
# 14               1.0       1.000   0.3528     0.2810     0.0711  100  100
# 15               1.0       1.000   0.3528     0.2810     0.0711    0    0
# 16               1.0       0.500   0.2063     0.3073     0.0373    0  100
# 17               1.0       0.500   0.2063     0.3073     0.0373    0  100
# 18               1.0       1.000   0.4045     0.4196     0.0728    0  100
# 19               1.0       1.000   0.4045     0.4196     0.0728    0  100
# 20               1.0       0.500   0.2962     0.4364     0.0493    0  100
# 21               1.0       1.000   0.2962     0.4364     0.0493    0  100
# 22               1.0       1.000   0.3528     0.2810     0.0711    0  100
# 23               1.0       1.000   0.3528     0.2810     0.0711    0  100
# 24               1.0       0.250   0.2063     0.3073     0.0373    0  100
# 25               1.0       0.250   0.2063     0.3073     0.0373    0    0
# 26               1.0       0.375   0.4045     0.4196     0.0728    0  100
# 27               1.0       1.000   0.4045     0.4196     0.0728    0    0
# 28               1.0       0.375   0.2962     0.4364     0.0493    0  100
# 29               1.0       0.375   0.2962     0.4364     0.0493    0   11
# 30               1.0       1.000   0.3528     0.2810     0.0711    0  100
# 31               1.0       1.000   0.3528     0.2810     0.0711    0    0
#
#      s3   s4   s5   s6   s7   s8  surfactant_conc  drug_conc
# 0    49   31   96    8    9   35               86        100
# 1    88   66   22   52   58   79               35        100
# 2     1    3   32   94   44   58                1        100
# 3    61   94   63   49   98    0               52        100
# 4    85   84   71   23   35   65               21        100
# 5    27   17   47   67   83   22               71        100
# 6    62   55    7   76   19   43               94        100
# 7    25   46   87   32   74   99               44        100
# 8   100    0  100  100  100  100              100        100
# 9     0    0    0    0  100  100              100        100
# 10    0  100    0    0    0    0                1        100
# 11  100    0  100  100    0    0                1        100
# 12    0  100    0    0  100  100              100        100
# 13  100    0  100  100    0    0                1        100
# 14    0  100    0    0  100    0                1        100
# 15    0    0    0    0    4    0                1        100
# 16  100    0    0    0  100  100              100        100
# 17    0    0    0  100  100  100              100        100
# 18  100    0    0    0  100  100              100        100
# 19    0    3    0  100  100    0              100        100
# 20  100    0    0    0  100  100              100        100
# 21    0    3    0  100  100    0              100        100
# 22  100    0    0    0  100  100              100        100
# 23    0   13    0  100  100  100              100        100
# 24    0    0    0    0  100    0              100        100
# 25    0    0    0    0  100  100              100        100
# 26    0    0    0    0  100  100              100        100
# 27  100    0    0  100  100  100              100        100
# 28    0    0    0    0  100  100              100        100
# 29    0    0    0    0  100  100              100        100
# 30    0  100  100    0    0    0              100        100
# 31    0  100  100  100    0  100              100        100

# %%
time_start = time.time()


df_design, ax_client = hf.run_optimizer(current_iteration=n, drug_list= list_of_drugs,  bopt = 1)

time_end = time.time()
time_duration = round((time_end - time_start)/60,2)

print("Time taken for optimization: " + str(time_duration) + " mins")
print("Time taken for optimization: " + str(time_duration * 60) + " seconds")
# Out:
# [WARNING 07-14 14:06:47] ax.modelbridge.transforms.standardize_y: Outcome surfactant_input is constant, within tolerance.
# **************************************************************************************************** 1  out of  8 ****************************************************************************************************
# ********************************************************************************************************************************************************************************************************
#
# Generating a Bayesian Optimization trial for
# Drug name:  Ibuprofen IBP  | Iteration:  4
#
# ********************************************************************************************************************************************************************************************************
# ********************************************************************************************************************************************************************************************************
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/botorch/models/utils/assorted.py:273: InputDataWarning: Data (outcome observations) is not standardized (std = tensor([1.0000, 1.0000, 0.0000], dtype=torch.float64), mean = tensor([ 4.1633e-17, -5.5511e-17,  0.0000e+00], dtype=torch.float64)).Please consider scaling the input to zero mean and unit variance.
#   check_standardization(Y=train_Y, raise_on_fail=raise_on_fail)
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:486: RuntimeWarning: divide by zero encountered in scalar divide
#   inv_model_std_quality = max_std if max_std > 1 / min_std else min_std
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:489: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 / inv_model_std_quality
# [INFO 07-14 14:06:55] ax.service.ax_client: Generated new trial 32 with parameters {'Drug_MW': 0.2063, 'Drug_LogP': 0.3073, 'Drug_TPSA': 0.0373, 's1': 0, 's2': 0, 's3': 17, 's4': 0, 's5': 0, 's6': 3, 's7': 100, 's8': 0, 'surfactant_conc': 100, 'drug_conc': 100} using model BO_MIXED.
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/core/data.py:293: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 07-14 14:06:55] ax.modelbridge.transforms.standardize_y: Outcome surfactant_input is constant, within tolerance.
# **************************************************************************************************** 2  out of  8 ****************************************************************************************************
# ********************************************************************************************************************************************************************************************************
#
# Generating a Bayesian Optimization trial for
# Drug name:  Ibuprofen IBP  | Iteration:  4
#
# ********************************************************************************************************************************************************************************************************
# ********************************************************************************************************************************************************************************************************
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:486: RuntimeWarning: divide by zero encountered in scalar divide
#   inv_model_std_quality = max_std if max_std > 1 / min_std else min_std
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:489: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 / inv_model_std_quality
# [INFO 07-14 14:06:57] ax.service.ax_client: Generated new trial 33 with parameters {'Drug_MW': 0.2063, 'Drug_LogP': 0.3073, 'Drug_TPSA': 0.0373, 's1': 0, 's2': 0, 's3': 18, 's4': 0, 's5': 100, 's6': 2, 's7': 100, 's8': 0, 'surfactant_conc': 100, 'drug_conc': 100} using model BO_MIXED.
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/core/data.py:293: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 07-14 14:06:57] ax.modelbridge.transforms.standardize_y: Outcome surfactant_input is constant, within tolerance.
# **************************************************************************************************** 3  out of  8 ****************************************************************************************************
# ********************************************************************************************************************************************************************************************************
#
# Generating a Bayesian Optimization trial for
# Drug name:  Lovastatin LOV  | Iteration:  4
#
# ********************************************************************************************************************************************************************************************************
# ********************************************************************************************************************************************************************************************************
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/linear_operator/utils/cholesky.py:40: NumericalWarning: A not p.d., added jitter of 1.0e-08 to the diagonal
#   warnings.warn(
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:486: RuntimeWarning: divide by zero encountered in scalar divide
#   inv_model_std_quality = max_std if max_std > 1 / min_std else min_std
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:489: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 / inv_model_std_quality
# [INFO 07-14 14:06:58] ax.service.ax_client: Generated new trial 34 with parameters {'Drug_MW': 0.4045, 'Drug_LogP': 0.4196, 'Drug_TPSA': 0.0728, 's1': 0, 's2': 100, 's3': 0, 's4': 0, 's5': 100, 's6': 0, 's7': 100, 's8': 100, 'surfactant_conc': 100, 'drug_conc': 100} using model BO_MIXED.
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/core/data.py:293: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 07-14 14:06:58] ax.modelbridge.transforms.standardize_y: Outcome surfactant_input is constant, within tolerance.
# **************************************************************************************************** 4  out of  8 ****************************************************************************************************
# ********************************************************************************************************************************************************************************************************
#
# Generating a Bayesian Optimization trial for
# Drug name:  Lovastatin LOV  | Iteration:  4
#
# ********************************************************************************************************************************************************************************************************
# ********************************************************************************************************************************************************************************************************
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:486: RuntimeWarning: divide by zero encountered in scalar divide
#   inv_model_std_quality = max_std if max_std > 1 / min_std else min_std
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:489: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 / inv_model_std_quality
# [INFO 07-14 14:07:00] ax.service.ax_client: Generated new trial 35 with parameters {'Drug_MW': 0.4045, 'Drug_LogP': 0.4196, 'Drug_TPSA': 0.0728, 's1': 0, 's2': 100, 's3': 0, 's4': 100, 's5': 0, 's6': 0, 's7': 100, 's8': 0, 'surfactant_conc': 100, 'drug_conc': 100} using model BO_MIXED.
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/core/data.py:293: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 07-14 14:07:00] ax.modelbridge.transforms.standardize_y: Outcome surfactant_input is constant, within tolerance.
# **************************************************************************************************** 5  out of  8 ****************************************************************************************************
# ********************************************************************************************************************************************************************************************************
#
# Generating a Bayesian Optimization trial for
# Drug name:  Diclofenac DCF  | Iteration:  4
#
# ********************************************************************************************************************************************************************************************************
# ********************************************************************************************************************************************************************************************************
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:486: RuntimeWarning: divide by zero encountered in scalar divide
#   inv_model_std_quality = max_std if max_std > 1 / min_std else min_std
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:489: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 / inv_model_std_quality
# [INFO 07-14 14:07:02] ax.service.ax_client: Generated new trial 36 with parameters {'Drug_MW': 0.2962, 'Drug_LogP': 0.4364, 'Drug_TPSA': 0.0493, 's1': 0, 's2': 0, 's3': 25, 's4': 0, 's5': 0, 's6': 0, 's7': 100, 's8': 0, 'surfactant_conc': 100, 'drug_conc': 100} using model BO_MIXED.
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/core/data.py:293: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 07-14 14:07:02] ax.modelbridge.transforms.standardize_y: Outcome surfactant_input is constant, within tolerance.
# **************************************************************************************************** 6  out of  8 ****************************************************************************************************
# ********************************************************************************************************************************************************************************************************
#
# Generating a Bayesian Optimization trial for
# Drug name:  Diclofenac DCF  | Iteration:  4
#
# ********************************************************************************************************************************************************************************************************
# ********************************************************************************************************************************************************************************************************
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:486: RuntimeWarning: divide by zero encountered in scalar divide
#   inv_model_std_quality = max_std if max_std > 1 / min_std else min_std
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:489: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 / inv_model_std_quality
# [INFO 07-14 14:07:04] ax.service.ax_client: Generated new trial 37 with parameters {'Drug_MW': 0.2962, 'Drug_LogP': 0.4364, 'Drug_TPSA': 0.0493, 's1': 0, 's2': 100, 's3': 22, 's4': 0, 's5': 100, 's6': 0, 's7': 100, 's8': 0, 'surfactant_conc': 100, 'drug_conc': 100} using model BO_MIXED.
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/core/data.py:293: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 07-14 14:07:04] ax.modelbridge.transforms.standardize_y: Outcome surfactant_input is constant, within tolerance.
# **************************************************************************************************** 7  out of  8 ****************************************************************************************************
# ********************************************************************************************************************************************************************************************************
#
# Generating a Bayesian Optimization trial for
# Drug name:  Griseofulvin GLV  | Iteration:  4
#
# ********************************************************************************************************************************************************************************************************
# ********************************************************************************************************************************************************************************************************
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:486: RuntimeWarning: divide by zero encountered in scalar divide
#   inv_model_std_quality = max_std if max_std > 1 / min_std else min_std
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:489: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 / inv_model_std_quality
# [INFO 07-14 14:07:05] ax.service.ax_client: Generated new trial 38 with parameters {'Drug_MW': 0.3528, 'Drug_LogP': 0.281, 'Drug_TPSA': 0.0711, 's1': 0, 's2': 100, 's3': 0, 's4': 0, 's5': 100, 's6': 0, 's7': 100, 's8': 0, 'surfactant_conc': 100, 'drug_conc': 100} using model BO_MIXED.
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/core/data.py:293: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [WARNING 07-14 14:07:05] ax.modelbridge.transforms.standardize_y: Outcome surfactant_input is constant, within tolerance.
# **************************************************************************************************** 8  out of  8 ****************************************************************************************************
# ********************************************************************************************************************************************************************************************************
#
# Generating a Bayesian Optimization trial for
# Drug name:  Griseofulvin GLV  | Iteration:  4
#
# ********************************************************************************************************************************************************************************************************
# ********************************************************************************************************************************************************************************************************
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:486: RuntimeWarning: divide by zero encountered in scalar divide
#   inv_model_std_quality = max_std if max_std > 1 / min_std else min_std
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/cross_validation.py:489: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 / inv_model_std_quality
# [INFO 07-14 14:07:07] ax.service.ax_client: Generated new trial 39 with parameters {'Drug_MW': 0.3528, 'Drug_LogP': 0.281, 'Drug_TPSA': 0.0711, 's1': 0, 's2': 100, 's3': 0, 's4': 0, 's5': 0, 's6': 0, 's7': 100, 's8': 100, 'surfactant_conc': 1, 'drug_conc': 100} using model BO_MIXED.
# Time taken for optimization: 0.34 mins
# Time taken for optimization: 20.400000000000002 seconds

# %% [markdown]
# # process results

# %%
ax_client = hf.load_design_optimizer(n)
ax_client.experiment.trials
# Out:
# {0: Trial(experiment_name='drug_surfactant', index=0, status=TrialStatus.COMPLETED, arm=Arm(name='0_0', parameters={'Drug_MW': 0.2063, 'Drug_LogP': 0.3073, 'Drug_TPSA': 0.0373, 's1': 48, 's2': 60, 's3': 49, 's4': 31, 's5': 96, 's6': 8, 's7': 9, 's8': 35, 'surfactant_conc': 86, 'drug_conc': 100})),
#  1: Trial(experiment_name='drug_surfactant', index=1, status=TrialStatus.COMPLETED, arm=Arm(name='1_0', parameters={'Drug_MW': 0.2063, 'Drug_LogP': 0.3073, 'Drug_TPSA': 0.0373, 's1': 74, 's2': 0, 's3': 88, 's4': 66, 's5': 22, 's6': 52, 's7': 58, 's8': 79, 'surfactant_conc': 35, 'drug_conc': 100})),
#  2: Trial(experiment_name='drug_surfactant', index=2, status=TrialStatus.COMPLETED, arm=Arm(name='2_0', parameters={'Drug_MW': 0.4045, 'Drug_LogP': 0.4196, 'Drug_TPSA': 0.0728, 's1': 78, 's2': 88, 's3': 1, 's4': 3, 's5': 32, 's6': 94, 's7': 44, 's8': 58, 'surfactant_conc': 1, 'drug_conc': 100})),
#  3: Trial(experiment_name='drug_surfactant', index=3, status=TrialStatus.COMPLETED, arm=Arm(name='3_0', parameters={'Drug_MW': 0.4045, 'Drug_LogP': 0.4196, 'Drug_TPSA': 0.0728, 's1': 0, 's2': 46, 's3': 61, 's4': 94, 's5': 63, 's6': 49, 's7': 98, 's8': 0, 'surfactant_conc': 52, 'drug_conc': 100})),
#  4: Trial(experiment_name='drug_surfactant', index=4, status=TrialStatus.COMPLETED, arm=Arm(name='4_0', parameters={'Drug_MW': 0.2962, 'Drug_LogP': 0.4364, 'Drug_TPSA': 0.0493, 's1': 16, 's2': 82, 's3': 85, 's4': 84, 's5': 71, 's6': 23, 's7': 35, 's8': 65, 'surfactant_conc': 21, 'drug_conc': 100})),
#  5: Trial(experiment_name='drug_surfactant', index=5, status=TrialStatus.COMPLETED, arm=Arm(name='5_0', parameters={'Drug_MW': 0.2962, 'Drug_LogP': 0.4364, 'Drug_TPSA': 0.0493, 's1': 93, 's2': 27, 's3': 27, 's4': 17, 's5': 47, 's6': 67, 's7': 83, 's8': 22, 'surfactant_conc': 71, 'drug_conc': 100})),
#  6: Trial(experiment_name='drug_surfactant', index=6, status=TrialStatus.COMPLETED, arm=Arm(name='6_0', parameters={'Drug_MW': 0.3528, 'Drug_LogP': 0.281, 'Drug_TPSA': 0.0711, 's1': 59, 's2': 65, 's3': 62, 's4': 55, 's5': 7, 's6': 76, 's7': 19, 's8': 43, 'surfactant_conc': 94, 'drug_conc': 100})),
#  7: Trial(experiment_name='drug_surfactant', index=7, status=TrialStatus.COMPLETED, arm=Arm(name='7_0', parameters={'Drug_MW': 0.3528, 'Drug_LogP': 0.281, 'Drug_TPSA': 0.0711, 's1': 31, 's2': 19, 's3': 25, 's4': 46, 's5': 87, 's6': 32, 's7': 74, 's8': 99, 'surfactant_conc': 44, 'drug_conc': 100})),
#  8: Trial(experiment_name='drug_surfactant', index=8, status=TrialStatus.COMPLETED, arm=Arm(name='8_0', parameters={'Drug_MW': 0.2063, 'Drug_LogP': 0.3073, 'Drug_TPSA': 0.0373, 's1': 0, 's2': 100, 's3': 100, 's4': 0, 's5': 100, 's6': 100, 's7': 100, 's8': 100, 'surfactant_conc': 100, 'drug_conc': 100})),
#  9: Trial(experiment_name='drug_surfactant', index=9, status=TrialStatus.COMPLETED, arm=Arm(name='9_0', parameters={'Drug_MW': 0.2063, 'Drug_LogP': 0.3073, 'Drug_TPSA': 0.0373, 's1': 0, 's2': 100, 's3': 0, 's4': 0, 's5': 0, 's6': 0, 's7': 100, 's8': 100, 'surfactant_conc': 100, 'drug_conc': 100})),
#  10: Trial(experiment_name='drug_surfactant', index=10, status=TrialStatus.COMPLETED, arm=Arm(name='10_0', parameters={'Drug_MW': 0.4045, 'Drug_LogP': 0.4196, 'Drug_TPSA': 0.0728, 's1': 100, 's2': 0, 's3': 0, 's4': 100, 's5': 0, 's6': 0, 's7': 0, 's8': 0, 'surfactant_conc': 1, 'drug_conc': 100})),
#  11: Trial(experiment_name='drug_surfactant', index=11, status=TrialStatus.COMPLETED, arm=Arm(name='11_0', parameters={'Drug_MW': 0.4045, 'Drug_LogP': 0.4196, 'Drug_TPSA': 0.0728, 's1': 0, 's2': 0, 's3': 100, 's4': 0, 's5': 100, 's6': 100, 's7': 0, 's8': 0, 'surfactant_conc': 1, 'drug_conc': 100})),
#  12: Trial(experiment_name='drug_surfactant', index=12, status=TrialStatus.COMPLETED, arm=Arm(name='12_0', parameters={'Drug_MW': 0.2962, 'Drug_LogP': 0.4364, 'Drug_TPSA': 0.0493, 's1': 100, 's2': 100, 's3': 0, 's4': 100, 's5': 0, 's6': 0, 's7': 100, 's8': 100, 'surfactant_conc': 100, 'drug_conc': 100})),
#  13: Trial(experiment_name='drug_surfactant', index=13, status=TrialStatus.COMPLETED, arm=Arm(name='13_0', parameters={'Drug_MW': 0.2962, 'Drug_LogP': 0.4364, 'Drug_TPSA': 0.0493, 's1': 0, 's2': 0, 's3': 100, 's4': 0, 's5': 100, 's6': 100, 's7': 0, 's8': 0, 'surfactant_conc': 1, 'drug_conc': 100})),
#  14: Trial(experiment_name='drug_surfactant', index=14, status=TrialStatus.COMPLETED, arm=Arm(name='14_0', parameters={'Drug_MW': 0.3528, 'Drug_LogP': 0.281, 'Drug_TPSA': 0.0711, 's1': 100, 's2': 100, 's3': 0, 's4': 100, 's5': 0, 's6': 0, 's7': 100, 's8': 0, 'surfactant_conc': 1, 'drug_conc': 100})),
#  15: Trial(experiment_name='drug_surfactant', index=15, status=TrialStatus.COMPLETED, arm=Arm(name='15_0', parameters={'Drug_MW': 0.3528, 'Drug_LogP': 0.281, 'Drug_TPSA': 0.0711, 's1': 0, 's2': 0, 's3': 0, 's4': 0, 's5': 0, 's6': 0, 's7': 4, 's8': 0, 'surfactant_conc': 1, 'drug_conc': 100})),
#  16: Trial(experiment_name='drug_surfactant', index=16, status=TrialStatus.COMPLETED, arm=Arm(name='16_0', parameters={'Drug_MW': 0.2063, 'Drug_LogP': 0.3073, 'Drug_TPSA': 0.0373, 's1': 0, 's2': 100, 's3': 100, 's4': 0, 's5': 0, 's6': 0, 's7': 100, 's8': 100, 'surfactant_conc': 100, 'drug_conc': 100})),
#  17: Trial(experiment_name='drug_surfactant', index=17, status=TrialStatus.COMPLETED, arm=Arm(name='17_0', parameters={'Drug_MW': 0.2063, 'Drug_LogP': 0.3073, 'Drug_TPSA': 0.0373, 's1': 0, 's2': 100, 's3': 0, 's4': 0, 's5': 0, 's6': 100, 's7': 100, 's8': 100, 'surfactant_conc': 100, 'drug_conc': 100})),
#  18: Trial(experiment_name='drug_surfactant', index=18, status=TrialStatus.COMPLETED, arm=Arm(name='18_0', parameters={'Drug_MW': 0.4045, 'Drug_LogP': 0.4196, 'Drug_TPSA': 0.0728, 's1': 0, 's2': 100, 's3': 100, 's4': 0, 's5': 0, 's6': 0, 's7': 100, 's8': 100, 'surfactant_conc': 100, 'drug_conc': 100})),
#  19: Trial(experiment_name='drug_surfactant', index=19, status=TrialStatus.COMPLETED, arm=Arm(name='19_0', parameters={'Drug_MW': 0.4045, 'Drug_LogP': 0.4196, 'Drug_TPSA': 0.0728, 's1': 0, 's2': 100, 's3': 0, 's4': 3, 's5': 0, 's6': 100, 's7': 100, 's8': 0, 'surfactant_conc': 100, 'drug_conc': 100})),
#  20: Trial(experiment_name='drug_surfactant', index=20, status=TrialStatus.COMPLETED, arm=Arm(name='20_0', parameters={'Drug_MW': 0.2962, 'Drug_LogP': 0.4364, 'Drug_TPSA': 0.0493, 's1': 0, 's2': 100, 's3': 100, 's4': 0, 's5': 0, 's6': 0, 's7': 100, 's8': 100, 'surfactant_conc': 100, 'drug_conc': 100})),
#  21: Trial(experiment_name='drug_surfactant', index=21, status=TrialStatus.COMPLETED, arm=Arm(name='21_0', parameters={'Drug_MW': 0.2962, 'Drug_LogP': 0.4364, 'Drug_TPSA': 0.0493, 's1': 0, 's2': 100, 's3': 0, 's4': 3, 's5': 0, 's6': 100, 's7': 100, 's8': 0, 'surfactant_conc': 100, 'drug_conc': 100})),
#  22: Trial(experiment_name='drug_surfactant', index=22, status=TrialStatus.COMPLETED, arm=Arm(name='22_0', parameters={'Drug_MW': 0.3528, 'Drug_LogP': 0.281, 'Drug_TPSA': 0.0711, 's1': 0, 's2': 100, 's3': 100, 's4': 0, 's5': 0, 's6': 0, 's7': 100, 's8': 100, 'surfactant_conc': 100, 'drug_conc': 100})),
#  23: Trial(experiment_name='drug_surfactant', index=23, status=TrialStatus.COMPLETED, arm=Arm(name='23_0', parameters={'Drug_MW': 0.3528, 'Drug_LogP': 0.281, 'Drug_TPSA': 0.0711, 's1': 0, 's2': 100, 's3': 0, 's4': 13, 's5': 0, 's6': 100, 's7': 100, 's8': 100, 'surfactant_conc': 100, 'drug_conc': 100})),
#  24: Trial(experiment_name='drug_surfactant', index=24, status=TrialStatus.COMPLETED, arm=Arm(name='24_0', parameters={'Drug_MW': 0.2063, 'Drug_LogP': 0.3073, 'Drug_TPSA': 0.0373, 's1': 0, 's2': 100, 's3': 0, 's4': 0, 's5': 0, 's6': 0, 's7': 100, 's8': 0, 'surfactant_conc': 100, 'drug_conc': 100})),
#  25: Trial(experiment_name='drug_surfactant', index=25, status=TrialStatus.COMPLETED, arm=Arm(name='25_0', parameters={'Drug_MW': 0.2063, 'Drug_LogP': 0.3073, 'Drug_TPSA': 0.0373, 's1': 0, 's2': 0, 's3': 0, 's4': 0, 's5': 0, 's6': 0, 's7': 100, 's8': 100, 'surfactant_conc': 100, 'drug_conc': 100})),
#  26: Trial(experiment_name='drug_surfactant', index=26, status=TrialStatus.COMPLETED, arm=Arm(name='26_0', parameters={'Drug_MW': 0.4045, 'Drug_LogP': 0.4196, 'Drug_TPSA': 0.0728, 's1': 0, 's2': 100, 's3': 0, 's4': 0, 's5': 0, 's6': 0, 's7': 100, 's8': 100, 'surfactant_conc': 100, 'drug_conc': 100})),
#  27: Trial(experiment_name='drug_surfactant', index=27, status=TrialStatus.COMPLETED, arm=Arm(name='27_0', parameters={'Drug_MW': 0.4045, 'Drug_LogP': 0.4196, 'Drug_TPSA': 0.0728, 's1': 0, 's2': 0, 's3': 100, 's4': 0, 's5': 0, 's6': 100, 's7': 100, 's8': 100, 'surfactant_conc': 100, 'drug_conc': 100})),
#  28: Trial(experiment_name='drug_surfactant', index=28, status=TrialStatus.COMPLETED, arm=Arm(name='28_0', parameters={'Drug_MW': 0.2962, 'Drug_LogP': 0.4364, 'Drug_TPSA': 0.0493, 's1': 0, 's2': 100, 's3': 0, 's4': 0, 's5': 0, 's6': 0, 's7': 100, 's8': 100, 'surfactant_conc': 100, 'drug_conc': 100})),
#  29: Trial(experiment_name='drug_surfactant', index=29, status=TrialStatus.COMPLETED, arm=Arm(name='29_0', parameters={'Drug_MW': 0.2962, 'Drug_LogP': 0.4364, 'Drug_TPSA': 0.0493, 's1': 0, 's2': 11, 's3': 0, 's4': 0, 's5': 0, 's6': 0, 's7': 100, 's8': 100, 'surfactant_conc': 100, 'drug_conc': 100})),
#  30: Trial(experiment_name='drug_surfactant', index=30, status=TrialStatus.COMPLETED, arm=Arm(name='30_0', parameters={'Drug_MW': 0.3528, 'Drug_LogP': 0.281, 'Drug_TPSA': 0.0711, 's1': 0, 's2': 100, 's3': 0, 's4': 100, 's5': 100, 's6': 0, 's7': 0, 's8': 0, 'surfactant_conc': 100, 'drug_conc': 100})),
#  31: Trial(experiment_name='drug_surfactant', index=31, status=TrialStatus.COMPLETED, arm=Arm(name='31_0', parameters={'Drug_MW': 0.3528, 'Drug_LogP': 0.281, 'Drug_TPSA': 0.0711, 's1': 0, 's2': 0, 's3': 0, 's4': 100, 's5': 100, 's6': 100, 's7': 0, 's8': 100, 'surfactant_conc': 100, 'drug_conc': 100})),
#  32: Trial(experiment_name='drug_surfactant', index=32, status=TrialStatus.RUNNING, arm=Arm(name='32_0', parameters={'Drug_MW': 0.2063, 'Drug_LogP': 0.3073, 'Drug_TPSA': 0.0373, 's1': 0, 's2': 0, 's3': 17, 's4': 0, 's5': 0, 's6': 3, 's7': 100, 's8': 0, 'surfactant_conc': 100, 'drug_conc': 100})),
#  33: Trial(experiment_name='drug_surfactant', index=33, status=TrialStatus.RUNNING, arm=Arm(name='33_0', parameters={'Drug_MW': 0.2063, 'Drug_LogP': 0.3073, 'Drug_TPSA': 0.0373, 's1': 0, 's2': 0, 's3': 18, 's4': 0, 's5': 100, 's6': 2, 's7': 100, 's8': 0, 'surfactant_conc': 100, 'drug_conc': 100})),
#  34: Trial(experiment_name='drug_surfactant', index=34, status=TrialStatus.RUNNING, arm=Arm(name='34_0', parameters={'Drug_MW': 0.4045, 'Drug_LogP': 0.4196, 'Drug_TPSA': 0.0728, 's1': 0, 's2': 100, 's3': 0, 's4': 0, 's5': 100, 's6': 0, 's7': 100, 's8': 100, 'surfactant_conc': 100, 'drug_conc': 100})),
#  35: Trial(experiment_name='drug_surfactant', index=35, status=TrialStatus.RUNNING, arm=Arm(name='35_0', parameters={'Drug_MW': 0.4045, 'Drug_LogP': 0.4196, 'Drug_TPSA': 0.0728, 's1': 0, 's2': 100, 's3': 0, 's4': 100, 's5': 0, 's6': 0, 's7': 100, 's8': 0, 'surfactant_conc': 100, 'drug_conc': 100})),
#  36: Trial(experiment_name='drug_surfactant', index=36, status=TrialStatus.RUNNING, arm=Arm(name='36_0', parameters={'Drug_MW': 0.2962, 'Drug_LogP': 0.4364, 'Drug_TPSA': 0.0493, 's1': 0, 's2': 0, 's3': 25, 's4': 0, 's5': 0, 's6': 0, 's7': 100, 's8': 0, 'surfactant_conc': 100, 'drug_conc': 100})),
#  37: Trial(experiment_name='drug_surfactant', index=37, status=TrialStatus.RUNNING, arm=Arm(name='37_0', parameters={'Drug_MW': 0.2962, 'Drug_LogP': 0.4364, 'Drug_TPSA': 0.0493, 's1': 0, 's2': 100, 's3': 22, 's4': 0, 's5': 100, 's6': 0, 's7': 100, 's8': 0, 'surfactant_conc': 100, 'drug_conc': 100})),
#  38: Trial(experiment_name='drug_surfactant', index=38, status=TrialStatus.RUNNING, arm=Arm(name='38_0', parameters={'Drug_MW': 0.3528, 'Drug_LogP': 0.281, 'Drug_TPSA': 0.0711, 's1': 0, 's2': 100, 's3': 0, 's4': 0, 's5': 100, 's6': 0, 's7': 100, 's8': 0, 'surfactant_conc': 100, 'drug_conc': 100})),
#  39: Trial(experiment_name='drug_surfactant', index=39, status=TrialStatus.RUNNING, arm=Arm(name='39_0', parameters={'Drug_MW': 0.3528, 'Drug_LogP': 0.281, 'Drug_TPSA': 0.0711, 's1': 0, 's2': 100, 's3': 0, 's4': 0, 's5': 0, 's6': 0, 's7': 100, 's8': 100, 'surfactant_conc': 1, 'drug_conc': 100}))}

# %%
df_conc, df_vol = hf.design_to_conc_to_vol (n)

# %%
plate_well = input("Enter the plate well starting well (e.g., F1): ")
deepplate_well = input("Enter the deep plate well starting well (e.g., F1): ")


print("Please confirm the following information:")
print("Wellplate will start at: " + plate_well)
print("Deep plate will start at: " + deepplate_well)

print()
print("*******************************************************")
print("Continue if correct, or rerun this cell if incorrect.")
print("*******************************************************")
# Out:
# Please confirm the following information:
# Wellplate will start at: E1
# Deep plate will start at: G6
#
# *******************************************************
# Continue if correct, or rerun this cell if incorrect.
# *******************************************************

# %%
hf.generate_protocol(df_vol=df_vol, iteration=n, plate_well=plate_well, deepplate_well=deepplate_well)
# Out:
# ✅ Successfully wrote to: protocol/otflex_4.py

# %%
df_absorbance = hf.process_absorbance(iteration=n, threshold=0.06)
df_absorbance
# Out:
#    trial_index  success
# 0            0        1
# 1            1        1
# 2            2        1
# 3            3        0
# 4            4        0
# 5            5        1
# 6            6        0
# 7            7        0

# %%
results = hf.build_results(n, df_conc, df_absorbance)
results
# Out:
#    trial_index drug_name  s1   s2  s3   s4   s5  s6   s7   s8  \
# 0           32       IBP   0    0  17    0    0   3  100    0
# 1           33       IBP   0    0  18    0  100   2  100    0
# 2           34       LOV   0  100   0    0  100   0  100  100
# 3           35       LOV   0  100   0  100    0   0  100    0
# 4           36       DCF   0    0  25    0    0   0  100    0
# 5           37       DCF   0  100  22    0  100   0  100    0
# 6           38       GLV   0  100   0    0  100   0  100    0
# 7           39       GLV   0  100   0    0    0   0  100  100
#
#    surfactant_input  drug_conc  success  complexity
# 0              50.0       25.0        1           3
# 1              50.0       25.0        1           4
# 2              50.0       25.0        1           4
# 3              50.0       25.0        0           3
# 4              50.0       25.0        0           2
# 5              50.0       25.0        1           4
# 6              50.0       25.0        0           3
# 7               0.5       25.0        0           3

# %%
norm_results = hf.normalize_data(results, 'normalize')

# %%
norm_results
# Out:
#    trial_index drug_name  s1   s2  s3   s4   s5  s6   s7   s8  \
# 0           32       IBP   0    0  17    0    0   3  100    0
# 1           33       IBP   0    0  18    0  100   2  100    0
# 2           34       LOV   0  100   0    0  100   0  100  100
# 3           35       LOV   0  100   0  100    0   0  100    0
# 4           36       DCF   0    0  25    0    0   0  100    0
# 5           37       DCF   0  100  22    0  100   0  100    0
# 6           38       GLV   0  100   0    0  100   0  100    0
# 7           39       GLV   0  100   0    0    0   0  100  100
#
#    surfactant_input  drug_conc  success  complexity
# 0              1.00        1.0      1.0       0.375
# 1              1.00        1.0      1.0       0.500
# 2              1.00        1.0      1.0       0.500
# 3              1.00        1.0      0.0       0.375
# 4              1.00        1.0      0.0       0.250
# 5              1.00        1.0      1.0       0.500
# 6              1.00        1.0      0.0       0.375
# 7              0.01        1.0      0.0       0.375

# %% [markdown]
# # load the results to the optimizer

# %%
ax_client = hf.load_data_to_optimizer(iteration = n, norm_results = norm_results)
ax_client
# Out:
# [INFO 07-14 15:52:31] ax.service.ax_client: Completed trial 32 with data: {'success': (1.0, None), 'surfactant_input': (1.0, None), 'complexity': (0.375, None)}.
# [INFO 07-14 15:52:31] ax.service.ax_client: Completed trial 33 with data: {'success': (1.0, None), 'surfactant_input': (1.0, None), 'complexity': (0.5, None)}.
# [INFO 07-14 15:52:31] ax.service.ax_client: Completed trial 34 with data: {'success': (1.0, None), 'surfactant_input': (1.0, None), 'complexity': (0.5, None)}.
# [INFO 07-14 15:52:31] ax.service.ax_client: Completed trial 35 with data: {'success': (0.0, None), 'surfactant_input': (1.0, None), 'complexity': (1.0, None)}.
# [INFO 07-14 15:52:31] ax.service.ax_client: Completed trial 36 with data: {'success': (0.0, None), 'surfactant_input': (1.0, None), 'complexity': (1.0, None)}.
# [INFO 07-14 15:52:31] ax.service.ax_client: Completed trial 37 with data: {'success': (1.0, None), 'surfactant_input': (1.0, None), 'complexity': (0.5, None)}.
# [INFO 07-14 15:52:31] ax.service.ax_client: Completed trial 38 with data: {'success': (0.0, None), 'surfactant_input': (1.0, None), 'complexity': (1.0, None)}.
# [INFO 07-14 15:52:31] ax.service.ax_client: Completed trial 39 with data: {'success': (0.0, None), 'surfactant_input': (1.0, None), 'complexity': (1.0, None)}.
# Trial 32: success=1 → using surfactant_input=1.0, complexity=0.375
# Trial 33: success=1 → using surfactant_input=1.0, complexity=0.5
# Trial 34: success=1 → using surfactant_input=1.0, complexity=0.5
# Trial 35: success=0 → overriding surfactant_input & complexity to 1
# Trial 36: success=0 → overriding surfactant_input & complexity to 1
# Trial 37: success=1 → using surfactant_input=1.0, complexity=0.5
# Trial 38: success=0 → overriding surfactant_input & complexity to 1
# Trial 39: success=0 → overriding surfactant_input & complexity to 1
# AxClient(experiment=Experiment(drug_surfactant))
