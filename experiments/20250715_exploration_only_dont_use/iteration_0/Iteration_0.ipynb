# %% [markdown]
# # import libraries

# %%
import pandas as pd
from ax.service.ax_client import AxClient, ObjectiveProperties
import matplotlib.pyplot as plt
from ax.modelbridge.registry import Models
from ax.modelbridge.generation_strategy import GenerationStep, GenerationStrategy   
import time

import sys
sys.path.append('../')
import helper_functions as hf
# Out:
# /var/folders/hk/7jjnrbrj53n1t8_bmkhf0_k00000gn/T/ipykernel_57948/1711932296.py:5: DeprecationWarning: Please import from 'ax.generation_strategy.generation_strategy' instead of 'ax.modelbridge.generation_strategy'. The latter is deprecated and will be removed in a future release.
#   from ax.modelbridge.generation_strategy import GenerationStep, GenerationStrategy

# %% [markdown]
# # initialize the optimizer

# %%
ax_client_init_file_name = 'optimizer/optimizer_00.json'
ax_client = hf.optimizer_init()
ax_client
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 ax_client_init_file_name = 'optimizer/optimizer_00.json'
# ----> 2 ax_client = hf.optimizer_init()
#       3 ax_client
#
# File ~/0_Github/drug_surfactant/experiments/20250715_exploration_only_dont_use/iteration_0/../helper_functions.py:103, in optimizer_init()
#     100 ax_client = AxClient(generation_strategy=gs)
#     102 # create the design space and objective space
# --> 103 ax_client.create_experiment(
#     104     name="drug_surfactant",
#     105     parameters=[
#     106         # drug properties…
#     107         {"name": "Drug_MW",   "type": "range", "bounds": [0.0, 1.0], "value_type": "float"},
#     108         {"name": "Drug_LogP", "type": "range", "bounds": [0.0, 1.0], "value_type": "float"},
#     109         {"name": "Drug_TPSA", "type": "range", "bounds": [0.0, 1.0], "value_type": "float"},
#     110
#     111         # 8 surfactant amounts
#     112         *[{"name": f"s{i}", "type": "range", "bounds": [0, 100], "value_type": "int"}
#     113         for i in range(1, 9)],
#     114
#     115         # 8 binary selectors
#     116         *[{"name": f"b{i}", "type": "range",  "bounds": [0, 1], "value_type": "int"}
#     117         for i in range(1, 9)],
#     118
#     119         # overall concentrations
#     120         {"name": "surfactant_conc", "type": "range", "bounds": [1, 100], "value_type": "int"},
#     121         {"name": "drug_conc",       "type": "range", "bounds": [1, 100], "value_type": "int"},
#     122     ],
#     123     objectives={
#     124         'success':           ObjectiveProperties(minimize=False, threshold=0.5),
#     125         'surfactant_input':  ObjectiveProperties(minimize=True),
#     126         'complexity':        ObjectiveProperties(minimize=True),
#     127     },
#     128     parameter_constraints=[
#     129         # exactly two surfactants active
#     130         "b1 + b2 + b3 + b4 + b5 + b6 + b7 + b8 >= 2",
#     131         "b1 + b2 + b3 + b4 + b5 + b6 + b7 + b8 <= 2",
#     132         # link selectors to amounts
#     133         *[f"s{i} <= 100 * b{i}"       for i in range(1, 9)],
#     134         *[f"s{i} >= 1 * b{i}"         for i in range(1, 9)],  # optional
#     135     ],
#     136 )
#     139 return ax_client
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/service/ax_client.py:331, in AxClient.create_experiment(self, parameters, name, description, owners, objectives, parameter_constraints, outcome_constraints, status_quo, overwrite_existing_experiment, experiment_type, tracking_metric_names, choose_generation_strategy_kwargs, support_intermediate_data, immutable_search_space_and_opt_config, is_test, metric_definitions, default_trial_type, default_runner)
#     326     if len(objectives.keys()) > 1:
#     327         objective_kwargs["objective_thresholds"] = (
#     328             self.build_objective_thresholds(objectives)
#     329         )
# --> 331 experiment = self.make_experiment(
#     332     name=name,
#     333     description=description,
#     334     owners=owners,
#     335     parameters=parameters,
#     336     parameter_constraints=parameter_constraints,
#     337     outcome_constraints=outcome_constraints,
#     338     status_quo=status_quo,
#     339     experiment_type=experiment_type,
#     340     tracking_metric_names=tracking_metric_names,
#     341     metric_definitions=metric_definitions,
#     342     support_intermediate_data=support_intermediate_data,
#     343     immutable_search_space_and_opt_config=immutable_search_space_and_opt_config,
#     344     is_test=is_test,
#     345     default_trial_type=default_trial_type,
#     346     default_runner=default_runner,
#     347     **objective_kwargs,
#     348 )
#     349 self._set_runner(experiment=experiment)
#     350 self._set_experiment(
#     351     experiment=experiment,
#     352     overwrite_existing_experiment=overwrite_existing_experiment,
#     353 )
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/service/utils/instantiation.py:946, in InstantiationBase.make_experiment(cls, parameters, name, description, owners, parameter_constraints, outcome_constraints, status_quo, experiment_type, tracking_metric_names, metric_definitions, objectives, objective_thresholds, support_intermediate_data, immutable_search_space_and_opt_config, auxiliary_experiments_by_purpose, default_trial_type, default_runner, is_test)
#     927 if default_trial_type is not None:
#     928     return MultiTypeExperiment(
#     929         name=none_throws(name),
#     930         search_space=cls.make_search_space(parameters, parameter_constraints),
#    (...)    940         default_data_type=default_data_type,
#     941     )
#     943 return Experiment(
#     944     name=name,
#     945     description=description,
# --> 946     search_space=cls.make_search_space(parameters, parameter_constraints),
#     947     optimization_config=optimization_config,
#     948     status_quo=status_quo_arm,
#     949     experiment_type=experiment_type,
#     950     tracking_metrics=tracking_metrics,
#     951     default_data_type=default_data_type,
#     952     properties=properties,
#     953     auxiliary_experiments_by_purpose=auxiliary_experiments_by_purpose,
#     954     is_test=is_test,
#     955 )
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/service/utils/instantiation.py:741, in InstantiationBase.make_search_space(cls, parameters, parameter_constraints)
#     737 search_space_cls = HierarchicalSearchSpace if is_hss else SearchSpace
#     739 parameter_map = {p.name: p for p in typed_parameters}
# --> 741 typed_parameter_constraints = [
#     742     cls.constraint_from_str(c, parameter_map) for c in parameter_constraints
#     743 ]
#     745 if any(
#     746     any(
#     747         isinstance(parameter_map[parameter], ChoiceParameter)
#    (...)    750     for constraint in typed_parameter_constraints
#     751 ):
#     752     raise UnsupportedError(
#     753         "Constraints on ChoiceParameters are not allowed. Try absorbing "
#     754         "this constraint into the associated range parameter's bounds."
#     755     )
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/service/utils/instantiation.py:742, in <listcomp>(.0)
#     737 search_space_cls = HierarchicalSearchSpace if is_hss else SearchSpace
#     739 parameter_map = {p.name: p for p in typed_parameters}
#     741 typed_parameter_constraints = [
# --> 742     cls.constraint_from_str(c, parameter_map) for c in parameter_constraints
#     743 ]
#     745 if any(
#     746     any(
#     747         isinstance(parameter_map[parameter], ChoiceParameter)
#    (...)    750     for constraint in typed_parameter_constraints
#     751 ):
#     752     raise UnsupportedError(
#     753         "Constraints on ChoiceParameters are not allowed. Try absorbing "
#     754         "this constraint into the associated range parameter's bounds."
#     755     )
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/service/utils/instantiation.py:405, in InstantiationBase.constraint_from_str(representation, parameters)
#     401 sum_const = (
#     402     len(tokens) >= 5 and len(tokens) % 2 == 1 and tokens[-2] in COMPARISON_OPS
#     403 )
#     404 if not (order_const or sum_const):
# --> 405     raise ValueError(
#     406         "Parameter constraint should be of form <parameter_name> >= "
#     407         "<other_parameter_name> for order constraints or `<parameter_name> "
#     408         "+ <other_parameter_name> >= x, where any number of terms can be "
#     409         "added and `x` is a float bound. Acceptable comparison operators "
#     410         'are ">=" and "<=".'
#     411     )
#     413 # Case "x1 >= x2" => order constraint.
#     414 if len(tokens) == 3 and not last_token_is_numeric:
#
# ValueError: Parameter constraint should be of form <parameter_name> >= <other_parameter_name> for order constraints or `<parameter_name> + <other_parameter_name> >= x, where any number of terms can be added and `x` is a float bound. Acceptable comparison operators are ">=" and "<=".

# %%
ax_client.save_to_json_file(ax_client_init_file_name)

# %% [markdown]
# # generate recommendations

# %%
n = hf.get_iteration_number()

for i in range(3):
    print("Very Important: Please Confirm the Iteration Number is Iteration " + str(n))

print()

list_of_drugs = ['IBP'] * 2 + ['LOV'] * 2 + ['DCF'] * 2 + ['GLV'] * 2

for i in range(3):
    print("Very Important: Please Confirm the Drugs are: ", list_of_drugs)
# Out:
# Very Important: Please Confirm the Iteration Number is Iteration 0
# Very Important: Please Confirm the Iteration Number is Iteration 0
# Very Important: Please Confirm the Iteration Number is Iteration 0
#
# Very Important: Please Confirm the Drugs are:  ['IBP', 'IBP', 'LOV', 'LOV', 'DCF', 'DCF', 'GLV', 'GLV']
# Very Important: Please Confirm the Drugs are:  ['IBP', 'IBP', 'LOV', 'LOV', 'DCF', 'DCF', 'GLV', 'GLV']
# Very Important: Please Confirm the Drugs are:  ['IBP', 'IBP', 'LOV', 'LOV', 'DCF', 'DCF', 'GLV', 'GLV']

# %%
time_start = time.time()



df_design, ax_client = hf.run_optimizer(current_iteration=n, drug_list= list_of_drugs, bopt=0)

time_end = time.time()
time_duration = round((time_end - time_start)/60,2)

print("Time taken for optimization: " + str(time_duration) + " mins")
print("Time taken for optimization: " + str(time_duration * 60) + " seconds")
# Out:
# [INFO 07-11 09:33:24] ax.service.ax_client: Generated new trial 0 with parameters {'Drug_MW': 0.2063, 'Drug_LogP': 0.3073, 'Drug_TPSA': 0.0373, 's1': 48, 's2': 60, 's3': 49, 's4': 31, 's5': 96, 's6': 8, 's7': 9, 's8': 35, 'surfactant_conc': 86, 'drug_conc': 100} using model Sobol.
# [INFO 07-11 09:33:24] ax.service.ax_client: Generated new trial 1 with parameters {'Drug_MW': 0.2063, 'Drug_LogP': 0.3073, 'Drug_TPSA': 0.0373, 's1': 74, 's2': 0, 's3': 88, 's4': 66, 's5': 22, 's6': 52, 's7': 58, 's8': 79, 'surfactant_conc': 35, 'drug_conc': 100} using model Sobol.
# [INFO 07-11 09:33:24] ax.service.ax_client: Generated new trial 2 with parameters {'Drug_MW': 0.4045, 'Drug_LogP': 0.4196, 'Drug_TPSA': 0.0728, 's1': 78, 's2': 88, 's3': 1, 's4': 3, 's5': 32, 's6': 94, 's7': 44, 's8': 58, 'surfactant_conc': 1, 'drug_conc': 100} using model Sobol.
# [INFO 07-11 09:33:24] ax.service.ax_client: Generated new trial 3 with parameters {'Drug_MW': 0.4045, 'Drug_LogP': 0.4196, 'Drug_TPSA': 0.0728, 's1': 0, 's2': 46, 's3': 61, 's4': 94, 's5': 63, 's6': 49, 's7': 98, 's8': 0, 'surfactant_conc': 52, 'drug_conc': 100} using model Sobol.
# [INFO 07-11 09:33:24] ax.service.ax_client: Generated new trial 4 with parameters {'Drug_MW': 0.2962, 'Drug_LogP': 0.4364, 'Drug_TPSA': 0.0493, 's1': 16, 's2': 82, 's3': 85, 's4': 84, 's5': 71, 's6': 23, 's7': 35, 's8': 65, 'surfactant_conc': 21, 'drug_conc': 100} using model Sobol.
# [INFO 07-11 09:33:24] ax.service.ax_client: Generated new trial 5 with parameters {'Drug_MW': 0.2962, 'Drug_LogP': 0.4364, 'Drug_TPSA': 0.0493, 's1': 93, 's2': 27, 's3': 27, 's4': 17, 's5': 47, 's6': 67, 's7': 83, 's8': 22, 'surfactant_conc': 71, 'drug_conc': 100} using model Sobol.
# [INFO 07-11 09:33:24] ax.service.ax_client: Generated new trial 6 with parameters {'Drug_MW': 0.3528, 'Drug_LogP': 0.281, 'Drug_TPSA': 0.0711, 's1': 59, 's2': 65, 's3': 62, 's4': 55, 's5': 7, 's6': 76, 's7': 19, 's8': 43, 'surfactant_conc': 94, 'drug_conc': 100} using model Sobol.
# [INFO 07-11 09:33:24] ax.service.ax_client: Generated new trial 7 with parameters {'Drug_MW': 0.3528, 'Drug_LogP': 0.281, 'Drug_TPSA': 0.0711, 's1': 31, 's2': 19, 's3': 25, 's4': 46, 's5': 87, 's6': 32, 's7': 74, 's8': 99, 'surfactant_conc': 44, 'drug_conc': 100} using model Sobol.
# **************************************************************************************************** 1  out of  8 ****************************************************************************************************
# ********************************************************************************************************************************************************************************************************
#
# Generating a random trial for
# Drug name:  Ibuprofen IBP  | Iteration:  0
#
# ********************************************************************************************************************************************************************************************************
# ********************************************************************************************************************************************************************************************************
# **************************************************************************************************** 2  out of  8 ****************************************************************************************************
# ********************************************************************************************************************************************************************************************************
#
# Generating a random trial for
# Drug name:  Ibuprofen IBP  | Iteration:  0
#
# ********************************************************************************************************************************************************************************************************
# ********************************************************************************************************************************************************************************************************
# **************************************************************************************************** 3  out of  8 ****************************************************************************************************
# ********************************************************************************************************************************************************************************************************
#
# Generating a random trial for
# Drug name:  Lovastatin LOV  | Iteration:  0
#
# ********************************************************************************************************************************************************************************************************
# ********************************************************************************************************************************************************************************************************
# **************************************************************************************************** 4  out of  8 ****************************************************************************************************
# ********************************************************************************************************************************************************************************************************
#
# Generating a random trial for
# Drug name:  Lovastatin LOV  | Iteration:  0
#
# ********************************************************************************************************************************************************************************************************
# ********************************************************************************************************************************************************************************************************
# **************************************************************************************************** 5  out of  8 ****************************************************************************************************
# ********************************************************************************************************************************************************************************************************
#
# Generating a random trial for
# Drug name:  Diclofenac DCF  | Iteration:  0
#
# ********************************************************************************************************************************************************************************************************
# ********************************************************************************************************************************************************************************************************
# **************************************************************************************************** 6  out of  8 ****************************************************************************************************
# ********************************************************************************************************************************************************************************************************
#
# Generating a random trial for
# Drug name:  Diclofenac DCF  | Iteration:  0
#
# ********************************************************************************************************************************************************************************************************
# ********************************************************************************************************************************************************************************************************
# **************************************************************************************************** 7  out of  8 ****************************************************************************************************
# ********************************************************************************************************************************************************************************************************
#
# Generating a random trial for
# Drug name:  Griseofulvin GLV  | Iteration:  0
#
# ********************************************************************************************************************************************************************************************************
# ********************************************************************************************************************************************************************************************************
# **************************************************************************************************** 8  out of  8 ****************************************************************************************************
# ********************************************************************************************************************************************************************************************************
#
# Generating a random trial for
# Drug name:  Griseofulvin GLV  | Iteration:  0
#
# ********************************************************************************************************************************************************************************************************
# ********************************************************************************************************************************************************************************************************
# Time taken for optimization: 0.0 mins
# Time taken for optimization: 0.0 seconds

# %% [markdown]
# # process results

# %%
ax_client = hf.load_design_optimizer(n)
ax_client.experiment.trials
# Out:
# {0: Trial(experiment_name='drug_surfactant', index=0, status=TrialStatus.RUNNING, arm=Arm(name='0_0', parameters={'Drug_MW': 0.2063, 'Drug_LogP': 0.3073, 'Drug_TPSA': 0.0373, 's1': 48, 's2': 60, 's3': 49, 's4': 31, 's5': 96, 's6': 8, 's7': 9, 's8': 35, 'surfactant_conc': 86, 'drug_conc': 100})),
#  1: Trial(experiment_name='drug_surfactant', index=1, status=TrialStatus.RUNNING, arm=Arm(name='1_0', parameters={'Drug_MW': 0.2063, 'Drug_LogP': 0.3073, 'Drug_TPSA': 0.0373, 's1': 74, 's2': 0, 's3': 88, 's4': 66, 's5': 22, 's6': 52, 's7': 58, 's8': 79, 'surfactant_conc': 35, 'drug_conc': 100})),
#  2: Trial(experiment_name='drug_surfactant', index=2, status=TrialStatus.RUNNING, arm=Arm(name='2_0', parameters={'Drug_MW': 0.4045, 'Drug_LogP': 0.4196, 'Drug_TPSA': 0.0728, 's1': 78, 's2': 88, 's3': 1, 's4': 3, 's5': 32, 's6': 94, 's7': 44, 's8': 58, 'surfactant_conc': 1, 'drug_conc': 100})),
#  3: Trial(experiment_name='drug_surfactant', index=3, status=TrialStatus.RUNNING, arm=Arm(name='3_0', parameters={'Drug_MW': 0.4045, 'Drug_LogP': 0.4196, 'Drug_TPSA': 0.0728, 's1': 0, 's2': 46, 's3': 61, 's4': 94, 's5': 63, 's6': 49, 's7': 98, 's8': 0, 'surfactant_conc': 52, 'drug_conc': 100})),
#  4: Trial(experiment_name='drug_surfactant', index=4, status=TrialStatus.RUNNING, arm=Arm(name='4_0', parameters={'Drug_MW': 0.2962, 'Drug_LogP': 0.4364, 'Drug_TPSA': 0.0493, 's1': 16, 's2': 82, 's3': 85, 's4': 84, 's5': 71, 's6': 23, 's7': 35, 's8': 65, 'surfactant_conc': 21, 'drug_conc': 100})),
#  5: Trial(experiment_name='drug_surfactant', index=5, status=TrialStatus.RUNNING, arm=Arm(name='5_0', parameters={'Drug_MW': 0.2962, 'Drug_LogP': 0.4364, 'Drug_TPSA': 0.0493, 's1': 93, 's2': 27, 's3': 27, 's4': 17, 's5': 47, 's6': 67, 's7': 83, 's8': 22, 'surfactant_conc': 71, 'drug_conc': 100})),
#  6: Trial(experiment_name='drug_surfactant', index=6, status=TrialStatus.RUNNING, arm=Arm(name='6_0', parameters={'Drug_MW': 0.3528, 'Drug_LogP': 0.281, 'Drug_TPSA': 0.0711, 's1': 59, 's2': 65, 's3': 62, 's4': 55, 's5': 7, 's6': 76, 's7': 19, 's8': 43, 'surfactant_conc': 94, 'drug_conc': 100})),
#  7: Trial(experiment_name='drug_surfactant', index=7, status=TrialStatus.RUNNING, arm=Arm(name='7_0', parameters={'Drug_MW': 0.3528, 'Drug_LogP': 0.281, 'Drug_TPSA': 0.0711, 's1': 31, 's2': 19, 's3': 25, 's4': 46, 's5': 87, 's6': 32, 's7': 74, 's8': 99, 'surfactant_conc': 44, 'drug_conc': 100}))}

# %%
df_conc, df_vol = hf.design_to_conc_to_vol (n)

# %%
df_conc
# Out:
#    trial_index drug_name  surfactant_conc  drug_conc        s1        s2  \
# 0            0       IBP             43.0       25.0  6.142857  7.678571
# 1            1       IBP             17.5       25.0  2.949886  0.000000
# 2            2       LOV              0.5       25.0  0.097990  0.110553
# 3            3       LOV             26.0       25.0  0.000000  2.909976
# 4            4       DCF             10.5       25.0  0.364425  1.867679
# 5            5       DCF             35.5       25.0  8.620104  2.502611
# 6            6       GLV             47.0       25.0  7.183938  7.914508
# 7            7       GLV             22.0       25.0  1.651332  1.012107
#
#          s3        s4         s5        s6        s7        s8
# 0  6.270833  3.967262  12.285714  1.023810  1.151786  4.479167
# 1  3.507973  2.630979   0.876993  2.072893  2.312073  3.149203
# 2  0.001256  0.003769   0.040201  0.118090  0.055276  0.072864
# 3  3.858881  5.946472   3.985401  3.099757  6.199513  0.000000
# 4  1.936009  1.913232   1.617137  0.523861  0.797180  1.480477
# 5  2.502611  1.575718   4.356397  6.210183  7.693211  2.039164
# 6  7.549223  6.696891   0.852332  9.253886  2.313472  5.235751
# 7  1.331719  2.450363   4.634383  1.704600  3.941889  5.273608

# %%
df_vol
# Out:
#    trial_index drug_name   drug          s1          s2          s3  \
# 0            0       IBP  180.0  147.428571  184.285714  150.500000
# 1            1       IBP  180.0   70.797267    0.000000   84.191344
# 2            2       LOV  180.0    2.351759    2.653266    0.030151
# 3            3       LOV  180.0    0.000000   69.839416   92.613139
# 4            4       DCF  180.0    8.746204   44.824295   46.464208
# 5            5       DCF  180.0  206.882507   60.062663   60.062663
# 6            6       GLV  180.0  172.414508  189.948187  181.181347
# 7            7       GLV  180.0   39.631961   24.290557   31.961259
#
#            s4          s5          s6          s7          s8  dmso   water  \
# 0   95.214286  294.857143   24.571429   27.642857  107.500000   0.0   168.0
# 1   63.143508   21.047836   49.749431   55.489749   75.580866   0.0   780.0
# 2    0.090452    0.964824    2.834171    1.326633    1.748744   0.0  1188.0
# 3  142.715328   95.649635   74.394161  148.788321    0.000000   0.0   576.0
# 4   45.917570   38.811280   12.572668   19.132321   35.531453   0.0   948.0
# 5   37.817232  104.553525  149.044386  184.637076   48.939948   0.0   348.0
# 6  160.725389   20.455959  222.093264   55.523316  125.658031   0.0    72.0
# 7   58.808717  111.225182   40.910412   94.605327  126.566586   0.0   672.0
#
#      IBP    LOV    DCF    GLV
# 0  180.0    0.0    0.0    0.0
# 1  180.0    0.0    0.0    0.0
# 2    0.0  180.0    0.0    0.0
# 3    0.0  180.0    0.0    0.0
# 4    0.0    0.0  180.0    0.0
# 5    0.0    0.0  180.0    0.0
# 6    0.0    0.0    0.0  180.0
# 7    0.0    0.0    0.0  180.0

# %%
plate_well = input("Enter the plate well starting well (e.g., F1): ")
deepplate_well = input("Enter the deep plate well starting well (e.g., F1): ")



print("Please confirm the following information:")
print("Wellplate will start at: " + plate_well)
print("Deep plate will start at: " + deepplate_well)



print()
print("*******************************************************")
print("Continue if correct, or rerun this cell if incorrect.")
print("*******************************************************")
# Out:
# Please confirm the following information:
# Wellplate will start at: E1
# Deep plate will start at: G7
#
# *******************************************************
# Continue if correct, or rerun this cell if incorrect.
# *******************************************************

# %%
hf.generate_protocol(df_vol=df_vol, iteration=n, plate_well=plate_well, deepplate_well=deepplate_well)
# Out:
# ✅ Successfully wrote to: protocol/otflex_0.py

# %%
df_absorbance = hf.process_absorbance(iteration=n)
df_absorbance
# Out:
#    trial_index  success
# 0            0        0
# 1            1        0
# 2            2        0
# 3            3        0
# 4            4        0
# 5            5        0
# 6            6        0
# 7            7        0

# %%
df_conc
# Out:
#    trial_index drug_name  surfactant_conc  drug_conc        s1        s2  \
# 0            0       IBP             43.0       25.0  6.142857  7.678571
# 1            1       IBP             17.5       25.0  2.949886  0.000000
# 2            2       LOV              0.5       25.0  0.097990  0.110553
# 3            3       LOV             26.0       25.0  0.000000  2.909976
# 4            4       DCF             10.5       25.0  0.364425  1.867679
# 5            5       DCF             35.5       25.0  8.620104  2.502611
# 6            6       GLV             47.0       25.0  7.183938  7.914508
# 7            7       GLV             22.0       25.0  1.651332  1.012107
#
#          s3        s4         s5        s6        s7        s8
# 0  6.270833  3.967262  12.285714  1.023810  1.151786  4.479167
# 1  3.507973  2.630979   0.876993  2.072893  2.312073  3.149203
# 2  0.001256  0.003769   0.040201  0.118090  0.055276  0.072864
# 3  3.858881  5.946472   3.985401  3.099757  6.199513  0.000000
# 4  1.936009  1.913232   1.617137  0.523861  0.797180  1.480477
# 5  2.502611  1.575718   4.356397  6.210183  7.693211  2.039164
# 6  7.549223  6.696891   0.852332  9.253886  2.313472  5.235751
# 7  1.331719  2.450363   4.634383  1.704600  3.941889  5.273608

# %%
results = hf.build_results(n, df_conc, df_absorbance)

# %%
results
# Out:
#    trial_index drug_name  s1  s2  s3  s4  s5  s6  s7  s8  surfactant_input  \
# 0            0       IBP  48  60  49  31  96   8   9  35              43.0
# 1            1       IBP  74   0  88  66  22  52  58  79              17.5
# 2            2       LOV  78  88   1   3  32  94  44  58               0.5
# 3            3       LOV   0  46  61  94  63  49  98   0              26.0
# 4            4       DCF  16  82  85  84  71  23  35  65              10.5
# 5            5       DCF  93  27  27  17  47  67  83  22              35.5
# 6            6       GLV  59  65  62  55   7  76  19  43              47.0
# 7            7       GLV  31  19  25  46  87  32  74  99              22.0
#
#    drug_conc  success  complexity
# 0       25.0        0           8
# 1       25.0        0           7
# 2       25.0        0           8
# 3       25.0        0           6
# 4       25.0        0           8
# 5       25.0        0           8
# 6       25.0        0           8
# 7       25.0        0           8

# %%
norm_results = hf.normalize_data(results, 'normalize')

# %%
norm_results
# Out:
#    trial_index drug_name  s1  s2  s3  s4  s5  s6  s7  s8  surfactant_input  \
# 0            0       IBP  48  60  49  31  96   8   9  35              0.86
# 1            1       IBP  74   0  88  66  22  52  58  79              0.35
# 2            2       LOV  78  88   1   3  32  94  44  58              0.01
# 3            3       LOV   0  46  61  94  63  49  98   0              0.52
# 4            4       DCF  16  82  85  84  71  23  35  65              0.21
# 5            5       DCF  93  27  27  17  47  67  83  22              0.71
# 6            6       GLV  59  65  62  55   7  76  19  43              0.94
# 7            7       GLV  31  19  25  46  87  32  74  99              0.44
#
#    drug_conc  success  complexity
# 0        1.0      0.0       1.000
# 1        1.0      0.0       0.875
# 2        1.0      0.0       1.000
# 3        1.0      0.0       0.750
# 4        1.0      0.0       1.000
# 5        1.0      0.0       1.000
# 6        1.0      0.0       1.000
# 7        1.0      0.0       1.000

# %% [markdown]
# # load the results to the optimizer

# %%
ax_client = hf.load_data_to_optimizer(iteration = n, norm_results = norm_results)
ax_client
# Out:
# [INFO 07-11 11:45:33] ax.service.ax_client: Completed trial 0 with data: {'success': (0.0, None), 'surfactant_input': (1.0, None), 'complexity': (1.0, None)}.
# [INFO 07-11 11:45:33] ax.service.ax_client: Completed trial 1 with data: {'success': (0.0, None), 'surfactant_input': (1.0, None), 'complexity': (1.0, None)}.
# [INFO 07-11 11:45:33] ax.service.ax_client: Completed trial 2 with data: {'success': (0.0, None), 'surfactant_input': (1.0, None), 'complexity': (1.0, None)}.
# [INFO 07-11 11:45:33] ax.service.ax_client: Completed trial 3 with data: {'success': (0.0, None), 'surfactant_input': (1.0, None), 'complexity': (1.0, None)}.
# [INFO 07-11 11:45:33] ax.service.ax_client: Completed trial 4 with data: {'success': (0.0, None), 'surfactant_input': (1.0, None), 'complexity': (1.0, None)}.
# [INFO 07-11 11:45:33] ax.service.ax_client: Completed trial 5 with data: {'success': (0.0, None), 'surfactant_input': (1.0, None), 'complexity': (1.0, None)}.
# [INFO 07-11 11:45:33] ax.service.ax_client: Completed trial 6 with data: {'success': (0.0, None), 'surfactant_input': (1.0, None), 'complexity': (1.0, None)}.
# [INFO 07-11 11:45:33] ax.service.ax_client: Completed trial 7 with data: {'success': (0.0, None), 'surfactant_input': (1.0, None), 'complexity': (1.0, None)}.
# Trial 0: success=0 → overriding surfactant_input & complexity to 1
# Trial 1: success=0 → overriding surfactant_input & complexity to 1
# Trial 2: success=0 → overriding surfactant_input & complexity to 1
# Trial 3: success=0 → overriding surfactant_input & complexity to 1
# Trial 4: success=0 → overriding surfactant_input & complexity to 1
# Trial 5: success=0 → overriding surfactant_input & complexity to 1
# Trial 6: success=0 → overriding surfactant_input & complexity to 1
# Trial 7: success=0 → overriding surfactant_input & complexity to 1
# AxClient(experiment=Experiment(drug_surfactant))
