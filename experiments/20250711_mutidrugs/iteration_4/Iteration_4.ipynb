# %% [markdown]
# # import libraries

# %%
import pandas as pd
from ax.service.ax_client import AxClient, ObjectiveProperties
import matplotlib.pyplot as plt
from ax.modelbridge.registry import Models
from ax.modelbridge.generation_strategy import GenerationStep, GenerationStrategy   
import time


import sys
sys.path.append('../')
import helper_functions as hf
# Out:
# /var/folders/hk/7jjnrbrj53n1t8_bmkhf0_k00000gn/T/ipykernel_35844/3307975217.py:5: DeprecationWarning: Please import from 'ax.generation_strategy.generation_strategy' instead of 'ax.modelbridge.generation_strategy'. The latter is deprecated and will be removed in a future release.
#   from ax.modelbridge.generation_strategy import GenerationStep, GenerationStrategy

# %% [markdown]
# # generate recommendations

# %%
n = hf.get_iteration_number()

for i in range(3):
    print("Very Important: Please Confirm the Iteration Number is Iteration " + str(n))

print()

list_of_drugs = ['IBP'] * 2 + ['LOV'] * 2 + ['DCF'] * 2 + ['GLV'] * 2

for i in range(3):
    print("Very Important: Please Confirm the Drugs are: ", list_of_drugs)
# Out:
# Very Important: Please Confirm the Iteration Number is Iteration 4
# Very Important: Please Confirm the Iteration Number is Iteration 4
# Very Important: Please Confirm the Iteration Number is Iteration 4
#
# Very Important: Please Confirm the Drugs are:  ['IBP', 'IBP', 'LOV', 'LOV', 'DCF', 'DCF', 'GLV', 'GLV']
# Very Important: Please Confirm the Drugs are:  ['IBP', 'IBP', 'LOV', 'LOV', 'DCF', 'DCF', 'GLV', 'GLV']
# Very Important: Please Confirm the Drugs are:  ['IBP', 'IBP', 'LOV', 'LOV', 'DCF', 'DCF', 'GLV', 'GLV']

# %%
results_so_far = hf.results_so_far(n)
results_so_far
# Out:
#     trial_index arm_name trial_status   generation_node  success  \
# 0             0      0_0    COMPLETED  GenerationStep_0      0.0
# 1             1      1_0    COMPLETED  GenerationStep_0      0.0
# 2             2      2_0    COMPLETED  GenerationStep_0      0.0
# 3             3      3_0    COMPLETED  GenerationStep_0      0.0
# 4             4      4_0    COMPLETED  GenerationStep_0      0.0
# 5             5      5_0    COMPLETED  GenerationStep_0      0.0
# 6             6      6_0    COMPLETED  GenerationStep_0      0.0
# 7             7      7_0    COMPLETED  GenerationStep_0      0.0
# 8             8      8_0    COMPLETED  GenerationStep_1      1.0
# 9             9      9_0    COMPLETED  GenerationStep_1      1.0
# 10           10     10_0    COMPLETED  GenerationStep_1      0.0
# 11           11     11_0    COMPLETED  GenerationStep_1      0.0
# 12           12     12_0    COMPLETED  GenerationStep_1      0.0
# 13           13     13_0    COMPLETED  GenerationStep_1      0.0
# 14           14     14_0    COMPLETED  GenerationStep_1      0.0
# 15           15     15_0    COMPLETED  GenerationStep_1      0.0
# 16           16     16_0    COMPLETED  GenerationStep_1      1.0
# 17           17     17_0    COMPLETED  GenerationStep_1      1.0
# 18           18     18_0    COMPLETED  GenerationStep_1      0.0
# 19           19     19_0    COMPLETED  GenerationStep_1      0.0
# 20           20     20_0    COMPLETED  GenerationStep_1      1.0
# 21           21     21_0    COMPLETED  GenerationStep_1      0.0
# 22           22     22_0    COMPLETED  GenerationStep_1      0.0
# 23           23     23_0    COMPLETED  GenerationStep_1      0.0
# 24           24     24_0    COMPLETED  GenerationStep_1      1.0
# 25           25     25_0    COMPLETED  GenerationStep_1      1.0
# 26           26     26_0    COMPLETED  GenerationStep_1      1.0
# 27           27     27_0    COMPLETED  GenerationStep_1      0.0
# 28           28     28_0    COMPLETED  GenerationStep_1      1.0
# 29           29     29_0    COMPLETED  GenerationStep_1      1.0
# 30           30     30_0    COMPLETED  GenerationStep_1      0.0
# 31           31     31_0    COMPLETED  GenerationStep_1      0.0
#
#     surfactant_input  complexity  Drug_MW  Drug_LogP  Drug_TPSA   s1   s2  \
# 0                1.0       1.000   0.2063     0.3073     0.0373   48   60
# 1                1.0       1.000   0.2063     0.3073     0.0373   74    0
# 2                1.0       1.000   0.4045     0.4196     0.0728   78   88
# 3                1.0       1.000   0.4045     0.4196     0.0728    0   46
# 4                1.0       1.000   0.2962     0.4364     0.0493   16   82
# 5                1.0       1.000   0.2962     0.4364     0.0493   93   27
# 6                1.0       1.000   0.3528     0.2810     0.0711   59   65
# 7                1.0       1.000   0.3528     0.2810     0.0711   31   19
# 8                1.0       0.750   0.2063     0.3073     0.0373    0  100
# 9                1.0       0.375   0.2063     0.3073     0.0373    0  100
# 10               1.0       1.000   0.4045     0.4196     0.0728  100    0
# 11               1.0       1.000   0.4045     0.4196     0.0728    0    0
# 12               1.0       1.000   0.2962     0.4364     0.0493  100  100
# 13               1.0       1.000   0.2962     0.4364     0.0493    0    0
# 14               1.0       1.000   0.3528     0.2810     0.0711  100  100
# 15               1.0       1.000   0.3528     0.2810     0.0711    0    0
# 16               1.0       0.500   0.2063     0.3073     0.0373    0  100
# 17               1.0       0.500   0.2063     0.3073     0.0373    0  100
# 18               1.0       1.000   0.4045     0.4196     0.0728    0  100
# 19               1.0       1.000   0.4045     0.4196     0.0728    0  100
# 20               1.0       0.500   0.2962     0.4364     0.0493    0  100
# 21               1.0       1.000   0.2962     0.4364     0.0493    0  100
# 22               1.0       1.000   0.3528     0.2810     0.0711    0  100
# 23               1.0       1.000   0.3528     0.2810     0.0711    0  100
# 24               1.0       0.250   0.2063     0.3073     0.0373    0  100
# 25               1.0       0.250   0.2063     0.3073     0.0373    0    0
# 26               1.0       0.375   0.4045     0.4196     0.0728    0  100
# 27               1.0       1.000   0.4045     0.4196     0.0728    0    0
# 28               1.0       0.375   0.2962     0.4364     0.0493    0  100
# 29               1.0       0.375   0.2962     0.4364     0.0493    0   11
# 30               1.0       1.000   0.3528     0.2810     0.0711    0  100
# 31               1.0       1.000   0.3528     0.2810     0.0711    0    0
#
#      s3   s4   s5   s6   s7   s8  surfactant_conc  drug_conc
# 0    49   31   96    8    9   35               86        100
# 1    88   66   22   52   58   79               35        100
# 2     1    3   32   94   44   58                1        100
# 3    61   94   63   49   98    0               52        100
# 4    85   84   71   23   35   65               21        100
# 5    27   17   47   67   83   22               71        100
# 6    62   55    7   76   19   43               94        100
# 7    25   46   87   32   74   99               44        100
# 8   100    0  100  100  100  100              100        100
# 9     0    0    0    0  100  100              100        100
# 10    0  100    0    0    0    0                1        100
# 11  100    0  100  100    0    0                1        100
# 12    0  100    0    0  100  100              100        100
# 13  100    0  100  100    0    0                1        100
# 14    0  100    0    0  100    0                1        100
# 15    0    0    0    0    4    0                1        100
# 16  100    0    0    0  100  100              100        100
# 17    0    0    0  100  100  100              100        100
# 18  100    0    0    0  100  100              100        100
# 19    0    3    0  100  100    0              100        100
# 20  100    0    0    0  100  100              100        100
# 21    0    3    0  100  100    0              100        100
# 22  100    0    0    0  100  100              100        100
# 23    0   13    0  100  100  100              100        100
# 24    0    0    0    0  100    0              100        100
# 25    0    0    0    0  100  100              100        100
# 26    0    0    0    0  100  100              100        100
# 27  100    0    0  100  100  100              100        100
# 28    0    0    0    0  100  100              100        100
# 29    0    0    0    0  100  100              100        100
# 30    0  100  100    0    0    0              100        100
# 31    0  100  100  100    0  100              100        100

# %%
time_start = time.time()


df_design, ax_client = hf.run_optimizer(current_iteration=n, drug_list= list_of_drugs,  bopt = 1)

time_end = time.time()
time_duration = round((time_end - time_start)/60,2)

print("Time taken for optimization: " + str(time_duration) + " mins")
print("Time taken for optimization: " + str(time_duration * 60) + " seconds")
# Out:
# [WARNING 07-14 14:03:58] ax.modelbridge.transforms.standardize_y: Outcome surfactant_input is constant, within tolerance.
# **************************************************************************************************** 1  out of  8 ****************************************************************************************************
# ********************************************************************************************************************************************************************************************************
#
# Generating a Bayesian Optimization trial for
# Drug name:  Ibuprofen IBP  | Iteration:  4
#
# ********************************************************************************************************************************************************************************************************
# ********************************************************************************************************************************************************************************************************
# /Users/zeqing/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/botorch/models/utils/assorted.py:273: InputDataWarning: Data (outcome observations) is not standardized (std = tensor([1.0000, 1.0000, 0.0000], dtype=torch.float64), mean = tensor([ 4.1633e-17, -5.5511e-17,  0.0000e+00], dtype=torch.float64)).Please consider scaling the input to zero mean and unit variance.
#   check_standardization(Y=train_Y, raise_on_fail=raise_on_fail)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 time_start = time.time()
# ----> 4 df_design, ax_client = hf.run_optimizer(current_iteration=n, drug_list= list_of_drugs,  bopt = 1)
#       6 time_end = time.time()
#       7 time_duration = round((time_end - time_start)/60,2)
#
# File ~/0_Github/drug_surfactant/experiments/20250711_mutidrugs/iteration_4/../helper_functions.py:347, in run_optimizer(current_iteration, drug_list, bopt, n_trials)
#     344 print("*" * 200)
#     345 print("*" * 200)
# --> 347 trials, _ = ax_client.get_next_trials(n_trials, fixed_features=drug_features)
#     349 # Prepare the trial data for DataFrame
#     351 for trial_index, parameters in trials.items():
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/service/ax_client.py:658, in AxClient.get_next_trials(self, max_trials, ttl_seconds, fixed_features)
#     656 for _ in range(max_trials):
#     657     try:
# --> 658         params, trial_index = self.get_next_trial(
#     659             ttl_seconds=ttl_seconds, fixed_features=fixed_features
#     660         )
#     661         trials_dict[trial_index] = params
#     662     except OptimizationComplete as err:
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/utils/common/executils.py:169, in retry_on_exception.<locals>.func_wrapper.<locals>.actual_wrapper(*args, **kwargs)
#     165             wait_interval = min(
#     166                 MAX_WAIT_SECONDS, initial_wait_seconds * 2 ** (i - 1)
#     167             )
#     168             time.sleep(wait_interval)
# --> 169         return func(*args, **kwargs)
#     171 # If we are here, it means the retries were finished but
#     172 # The error was suppressed. Hence return the default value provided.
#     173 return default_return_on_suppression
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/service/ax_client.py:563, in AxClient.get_next_trial(self, ttl_seconds, force, fixed_features)
#     559         raise OptimizationShouldStop(message=global_stopping_message)
#     561 try:
#     562     trial = self.experiment.new_trial(
# --> 563         generator_run=self._gen_new_generator_run(
#     564             fixed_features=fixed_features
#     565         ),
#     566         ttl_seconds=ttl_seconds,
#     567     )
#     568 except MaxParallelismReachedException as e:
#     569     if self._early_stopping_strategy is not None:
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/service/ax_client.py:1731, in AxClient._gen_new_generator_run(self, n, fixed_features)
#    1723 fixed_feats = (
#    1724     InstantiationBase.make_fixed_observation_features(
#    1725         fixed_features=fixed_features
#    (...)   1728     else None
#    1729 )
#    1730 with with_rng_seed(seed=self._random_seed):
# -> 1731     return none_throws(self.generation_strategy).gen(
#    1732         experiment=self.experiment,
#    1733         n=n,
#    1734         pending_observations=self._get_pending_observation_features(
#    1735             experiment=self.experiment
#    1736         ),
#    1737         fixed_features=fixed_feats,
#    1738     )
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/generation_strategy/generation_strategy.py:343, in GenerationStrategy.gen(self, experiment, data, pending_observations, n, fixed_features)
#     314 """Produce the next points in the experiment. Additional kwargs passed to
#     315 this method are propagated directly to the underlying model's `gen`, along
#     316 with the `model_gen_kwargs` set on the current generation node.
#    (...)    339         resuggesting points that are currently being evaluated.
#     340 """
#     341 self.experiment = experiment
# --> 343 gr = self._gen_with_multiple_nodes(
#     344     experiment=experiment,
#     345     data=data,
#     346     n=n,
#     347     pending_observations=pending_observations,
#     348     fixed_features=fixed_features,
#     349 )
#     350 if len(gr) > 1:
#     351     raise UnsupportedError(
#     352         "By calling into GenerationStrategy.gen(), you are should be "
#     353         "expecting a single `Trial` with only one `GeneratorRun`. However, "
#     354         "the underlying GenerationStrategy produced multiple `GeneratorRuns` "
#     355         f"and returned the following list of `GeneratorRun`-s: {gr}"
#     356     )
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/generation_strategy/generation_strategy.py:778, in GenerationStrategy._gen_with_multiple_nodes(self, experiment, n, pending_observations, data, fixed_features, arms_per_node, first_generation_in_multi)
#     776 transitioned = self._maybe_transition_to_next_node()
#     777 try:
# --> 778     gr = self._curr.gen(
#     779         experiment=experiment,
#     780         data=data,
#     781         pending_observations=pending_observations,
#     782         skip_fit=not (first_generation_in_multi or transitioned),
#     783         **pack_gs_gen_kwargs,
#     784     )
#     785     # TODO[@drfreund]: Do we need this or can we just not keep `GS._model`?
#     786     self._model = self._curr._fitted_model
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/generation_strategy/generation_node.py:1178, in GenerationStep.gen(self, experiment, n, pending_observations, skip_fit, data, **gs_gen_kwargs)
#    1168 def gen(
#    1169     self,
#    1170     *,
#    (...)   1176     **gs_gen_kwargs: Any,
#    1177 ) -> GeneratorRun | None:
# -> 1178     gr = super().gen(
#    1179         experiment=experiment,
#    1180         n=n,
#    1181         pending_observations=pending_observations,
#    1182         data=data,
#    1183         skip_fit=skip_fit,
#    1184         **gs_gen_kwargs,
#    1185     )
#    1186     if gr is None:
#    1187         raise AxError(
#    1188             "This `GenerationStep`'s underlying `GenerationNode` returned "
#    1189             "`None` from `gen`. This is an unexpected state for a "
#    1190             "`GenerationStep`-based generation strategy."
#    1191         )
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/generation_strategy/generation_node.py:430, in GenerationNode.gen(self, experiment, pending_observations, skip_fit, data, **gs_gen_kwargs)
#     427     return None
#     429 if not skip_fit:
# --> 430     self._fit(experiment=experiment, data=data)
#     431 model_gen_kwargs = gs_gen_kwargs.copy()
#     432 model_gen_kwargs.update(input_constructor_values)
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/generation_strategy/generation_node.py:357, in GenerationNode._fit(self, experiment, data, **kwargs)
#     355 for model_spec in self.model_specs:
#     356     try:
# --> 357         model_spec.fit(  # Stores the fitted model as `model_spec._fitted_model`
#     358             experiment=experiment,
#     359             data=data,
#     360             **{
#     361                 **self._get_model_state_from_last_generator_run(
#     362                     model_spec=model_spec
#     363                 ),
#     364                 **kwargs,
#     365             },
#     366         )
#     367     except Exception as e:
#     368         if len(self.model_specs) == 1:
#     369             # If no other model specs, raise.
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/generation_strategy/model_spec.py:148, in GeneratorSpec.fit(self, experiment, data, **model_kwargs)
#     142     self.fitted_model._fit_if_implemented(
#     143         search_space=search_space, observations=observations, time_so_far=0.0
#     144     )
#     146 else:
#     147     # Fit from scratch.
# --> 148     self._fitted_model = self.model_enum(
#     149         experiment=experiment,
#     150         data=data,
#     151         **combined_model_kwargs,
#     152     )
#     153     self._last_fit_arg_ids = self._get_fit_arg_ids(
#     154         experiment=experiment, combined_model_kwargs=combined_model_kwargs
#     155     )
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/modelbridge/registry.py:369, in ModelRegistryBase.__call__(self, search_space, experiment, data, silently_filter_kwargs, **kwargs)
#     356 bridge_kwargs = consolidate_kwargs(
#     357     kwargs_iterable=[
#     358         get_function_default_arguments(bridge_class),
#    (...)    365     ),
#     366 )
#     368 # Create model bridge with the consolidated kwargs.
# --> 369 model_bridge = bridge_class(
#     370     search_space=search_space or none_throws(experiment).search_space,
#     371     experiment=experiment,
#     372     data=data,
#     373     model=model,
#     374     **bridge_kwargs,
#     375 )
#     377 if model_setup_info.not_saved_model_kwargs:
#     378     for key in model_setup_info.not_saved_model_kwargs:
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/modelbridge/torch.py:150, in TorchAdapter.__init__(self, experiment, model, search_space, data, transforms, transform_configs, optimization_config, expand_model_space, fit_tracking_metrics, fit_on_init, default_model_gen_options, torch_device, data_loader_config, fit_out_of_design, fit_abandoned, fit_only_completed_map_metrics)
#     147 self.parameters: list[str] = []
#     148 self.outcomes: list[str] = []
# --> 150 super().__init__(
#     151     experiment=experiment,
#     152     search_space=search_space,
#     153     data=data,
#     154     model=model,
#     155     transforms=transforms,
#     156     transform_configs=transform_configs,
#     157     optimization_config=optimization_config,
#     158     expand_model_space=expand_model_space,
#     159     fit_tracking_metrics=fit_tracking_metrics,
#     160     fit_on_init=fit_on_init,
#     161     data_loader_config=data_loader_config,
#     162     fit_out_of_design=fit_out_of_design,
#     163     fit_abandoned=fit_abandoned,
#     164     fit_only_completed_map_metrics=fit_only_completed_map_metrics,
#     165 )
#     167 # Re-assign self.model for more precise typing.
#     168 self.model: TorchGenerator = model
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/modelbridge/base.py:248, in Adapter.__init__(self, experiment, model, search_space, data, transforms, transform_configs, optimization_config, expand_model_space, fit_tracking_metrics, fit_on_init, data_loader_config, fit_out_of_design, fit_abandoned, fit_only_completed_map_metrics)
#     241 if fit_on_init:
#     242     observations, search_space = self._transform_data(
#     243         observations=observations_raw,
#     244         search_space=self._model_space,
#     245         transforms=self._raw_transforms,
#     246         transform_configs=self._transform_configs,
#     247     )
# --> 248     self._fit_if_implemented(
#     249         search_space=search_space,
#     250         observations=observations,
#     251         time_so_far=time.monotonic() - t_fit_start,
#     252     )
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/modelbridge/base.py:271, in Adapter._fit_if_implemented(self, search_space, observations, time_so_far)
#     269 try:
#     270     t_fit_start = time.monotonic()
# --> 271     self._fit(search_space=search_space, observations=observations)
#     272     increment = time.monotonic() - t_fit_start + time_so_far
#     273     self.fit_time += increment
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/modelbridge/torch.py:672, in TorchAdapter._fit(self, search_space, observations, parameters, **kwargs)
#     665     return
#     666 datasets, candidate_metadata, search_space_digest = self._get_fit_args(
#     667     search_space=search_space,
#     668     observations=observations,
#     669     parameters=parameters,
#     670     update_outcomes_and_parameters=True,
#     671 )
# --> 672 self.model.fit(
#     673     datasets=datasets,
#     674     search_space_digest=search_space_digest,
#     675     candidate_metadata=candidate_metadata,
#     676     **kwargs,
#     677 )
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/models/torch/botorch_modular/model.py:201, in BoTorchGenerator.fit(self, datasets, search_space_digest, candidate_metadata, state_dict, refit, **additional_model_inputs)
#     199     for config in config_list:
#     200         config.model_options.update(additional_model_inputs)
# --> 201 self.surrogate.fit(
#     202     datasets=datasets,
#     203     search_space_digest=search_space_digest,
#     204     candidate_metadata=candidate_metadata,
#     205     state_dict=state_dict,
#     206     refit=refit,
#     207     repeat_model_selection_if_dataset_changed=True,
#     208 )
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/models/torch/botorch_modular/surrogate.py:1009, in Surrogate.fit(self, datasets, search_space_digest, candidate_metadata, state_dict, refit, repeat_model_selection_if_dataset_changed)
#    1007 if len(model_configs) == 1 or (model_config is not None):
#    1008     best_model_config = model_config or model_configs[0]
# -> 1009     model = self._construct_model(
#    1010         dataset=dataset,
#    1011         search_space_digest=search_space_digest,
#    1012         model_config=best_model_config,
#    1013         default_botorch_model_class=default_botorch_model_class,
#    1014         state_dict=submodel_state_dict,
#    1015         refit=refit,
#    1016     )
#    1017 # Case 2: There is more than 1 model config and we want to refit
#    1018 # or don't know what the previous best model was
#    1019 else:
#    1020     if len(dataset.outcome_names) > 1:
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/models/torch/botorch_modular/surrogate.py:881, in Surrogate._construct_model(self, dataset, search_space_digest, model_config, default_botorch_model_class, state_dict, refit)
#     879     model.load_state_dict(state_dict)
#     880 if state_dict is None or refit:
# --> 881     fit_botorch_model(
#     882         model,  # Intentionally not using named args for dispatcher.
#     883         mll_class=model_config.mll_class,
#     884         mll_options=model_config.mll_options,
#     885     )
#     886 return model
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/botorch/utils/dispatcher.py:95, in Dispatcher.__call__(self, *args, **kwargs)
#      93 func = self.__getitem__(types=types)
#      94 try:
# ---> 95     return func(*args, **kwargs)
#      96 except MDNotImplementedError:
#      97     # Traverses registered methods in order, yields whenever a match is found
#      98     funcs = self.dispatch_iter(*types)
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/models/torch/botorch_modular/utils.py:451, in _fit_botorch_model_gpytorch(model, mll_class, mll_options)
#     449 mll_options = mll_options or {}
#     450 mll = mll_class(likelihood=model.likelihood, model=model, **mll_options)
# --> 451 fit_gpytorch_mll(mll)
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/botorch/fit.py:115, in fit_gpytorch_mll(mll, closure, optimizer, closure_kwargs, optimizer_kwargs, **kwargs)
#     112 if optimizer is not None:  # defer to per-method defaults
#     113     kwargs["optimizer"] = optimizer
# --> 115 return FitGPyTorchMLL(
#     116     mll,
#     117     type(mll.likelihood),
#     118     type(mll.model),
#     119     closure=closure,
#     120     closure_kwargs=closure_kwargs,
#     121     optimizer_kwargs=optimizer_kwargs,
#     122     **kwargs,
#     123 )
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/botorch/utils/dispatcher.py:95, in Dispatcher.__call__(self, *args, **kwargs)
#      93 func = self.__getitem__(types=types)
#      94 try:
# ---> 95     return func(*args, **kwargs)
#      96 except MDNotImplementedError:
#      97     # Traverses registered methods in order, yields whenever a match is found
#      98     funcs = self.dispatch_iter(*types)
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/botorch/fit.py:215, in _fit_fallback(mll, _, __, closure, optimizer, closure_kwargs, optimizer_kwargs, max_attempts, pick_best_of_all_attempts, warning_handler, caught_exception_types, **ignore)
#     213 with catch_warnings(record=True) as warning_list:
#     214     simplefilter("always", category=OptimizationWarning)
# --> 215     result = optimizer(mll, closure=closure, **optimizer_kwargs)
#     217 # Resolve warnings and determine whether or not to retry
#     218 success = True
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/botorch/optim/fit.py:94, in fit_gpytorch_mll_scipy(mll, parameters, bounds, closure, closure_kwargs, method, options, callback, timeout_sec)
#      91 if closure_kwargs is not None:
#      92     closure = partial(closure, **closure_kwargs)
# ---> 94 result = scipy_minimize(
#      95     closure=closure,
#      96     parameters=parameters,
#      97     bounds=bounds,
#      98     method=method,
#      99     options=options,
#     100     callback=callback,
#     101     timeout_sec=timeout_sec,
#     102 )
#     103 if result.status not in [OptimizationStatus.SUCCESS, OptimizationStatus.STOPPED]:
#     104     warn(
#     105         f"`scipy_minimize` terminated with status {result.status}, displaying"
#     106         f" original message from `scipy.optimize.minimize`: {result.message}",
#     107         OptimizationWarning,
#     108         stacklevel=2,
#     109     )
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/botorch/optim/core.py:114, in scipy_minimize(closure, parameters, bounds, callback, x0, method, options, timeout_sec)
#     106         result = OptimizationResult(
#     107             step=next(call_counter),
#     108             fval=float(wrapped_closure(x)[0]),
#     109             status=OptimizationStatus.RUNNING,
#     110             runtime=monotonic() - start_time,
#     111         )
#     112         return callback(parameters, result)  # pyre-ignore [29]
# --> 114 raw = minimize_with_timeout(
#     115     wrapped_closure,
#     116     wrapped_closure.state if x0 is None else x0.astype(np_float64, copy=False),
#     117     jac=True,
#     118     bounds=bounds_np,
#     119     method=method,
#     120     options=options,
#     121     callback=wrapped_callback,
#     122     timeout_sec=timeout_sec,
#     123 )
#     125 # Post-processing and outcome handling
#     126 wrapped_closure.state = asarray(raw.x)  # set parameter state to optimal values
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/botorch/optim/utils/timeout.py:86, in minimize_with_timeout(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options, timeout_sec)
#      83     # To prevent slowdowns after scipy 1.15.
#      84     # See https://github.com/scipy/scipy/issues/22438.
#      85     with threadpool_limits(limits=1, user_api="blas"):
# ---> 86         return optimize.minimize(
#      87             fun=fun,
#      88             x0=x0,
#      89             args=args,
#      90             method=method,
#      91             jac=jac,
#      92             hess=hess,
#      93             hessp=hessp,
#      94             bounds=bounds,
#      95             constraints=constraints,
#      96             tol=tol,
#      97             callback=wrapped_callback,
#      98             options=options,
#      99         )
#     100 except OptimizationTimeoutError as e:
#     101     msg = f"Optimization timed out after {e.runtime} seconds."
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/scipy/optimize/_minimize.py:738, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     735     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     736                              **options)
#     737 elif meth == 'l-bfgs-b':
# --> 738     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     739                            callback=callback, **options)
#     740 elif meth == 'tnc':
#     741     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     742                         **options)
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/scipy/optimize/_lbfgsb_py.py:441, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     433 _lbfgsb.setulb(m, x, low_bnd, upper_bnd, nbd, f, g, factr, pgtol, wa,
#     434                iwa, task, lsave, isave, dsave, maxls, ln_task)
#     436 if task[0] == 3:
#     437     # The minimization routine wants f and g at the current x.
#     438     # Note that interruptions due to maxfun are postponed
#     439     # until the completion of the current minimization iteration.
#     440     # Overwrite f and g:
# --> 441     f, g = func_and_grad(x)
#     442 elif task[0] == 1:
#     443     # new iteration
#     444     n_iterations += 1
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:344, in ScalarFunction.fun_and_grad(self, x)
#     342 if not np.array_equal(x, self.x):
#     343     self._update_x(x)
# --> 344 self._update_fun()
#     345 self._update_grad()
#     346 return self.f, self.g
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:295, in ScalarFunction._update_fun(self)
#     293 def _update_fun(self):
#     294     if not self.f_updated:
# --> 295         fx = self._wrapped_fun(self.x)
#     296         if fx < self._lowest_f:
#     297             self._lowest_x = self.x
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:21, in _wrapper_fun.<locals>.wrapped(x)
#      17 ncalls[0] += 1
#      18 # Send a copy because the user may overwrite it.
#      19 # Overwriting results in undefined behaviour because
#      20 # fun(self.x) will change self.x, with the two no longer linked.
# ---> 21 fx = fun(np.copy(x), *args)
#      22 # Make sure the function returns a true scalar
#      23 if not np.isscalar(fx):
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/scipy/optimize/_optimize.py:80, in MemoizeJac.__call__(self, x, *args)
#      78 def __call__(self, x, *args):
#      79     """ returns the function value """
# ---> 80     self._compute_if_needed(x, *args)
#      81     return self._value
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/scipy/optimize/_optimize.py:74, in MemoizeJac._compute_if_needed(self, x, *args)
#      72 if not np.all(x == self.x) or self._value is None or self.jac is None:
#      73     self.x = np.asarray(x).copy()
# ---> 74     fg = self.fun(x, *args)
#      75     self.jac = fg[1]
#      76     self._value = fg[0]
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/botorch/optim/closures/core.py:149, in NdarrayOptimizationClosure.__call__(self, state, **kwargs)
#     146     self.state = state
#     148 try:
# --> 149     value_tensor, grad_tensors = self.closure(**kwargs)
#     150     value = self.as_array(value_tensor)
#     151     grads = self._get_gradient_ndarray(fill_value=self.fill_value)
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/botorch/optim/closures/core.py:70, in ForwardBackwardClosure.__call__(self, **kwargs)
#      68 values = self.forward(**kwargs)
#      69 value = values if self.reducer is None else self.reducer(values)
# ---> 70 self.backward(value)
#      72 grads = tuple(param.grad for param in self.parameters.values())
#      73 if self.callback:
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/torch/_tensor.py:522, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     512 if has_torch_function_unary(self):
#     513     return handle_torch_function(
#     514         Tensor.backward,
#     515         (self,),
#    (...)    520         inputs=inputs,
#     521     )
# --> 522 torch.autograd.backward(
#     523     self, gradient, retain_graph, create_graph, inputs=inputs
#     524 )
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/torch/autograd/__init__.py:266, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     261     retain_graph = create_graph
#     263 # The reason we repeat the same comment below is that
#     264 # some Python versions print out the first line of a multi-line function
#     265 # calls in the traceback and some print out the last line
# --> 266 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     267     tensors,
#     268     grad_tensors_,
#     269     retain_graph,
#     270     create_graph,
#     271     inputs,
#     272     allow_unreachable=True,
#     273     accumulate_grad=True,
#     274 )
#
# KeyboardInterrupt:

# %% [markdown]
# # process results

# %%
ax_client = hf.load_design_optimizer(n)
ax_client.experiment.trials

# %%
df_conc, df_vol = hf.design_to_conc_to_vol (n)

# %%
plate_well = input("Enter the plate well starting well (e.g., F1): ")
deepplate_well = input("Enter the deep plate well starting well (e.g., F1): ")


print("Please confirm the following information:")
print("Wellplate will start at: " + plate_well)
print("Deep plate will start at: " + deepplate_well)

print()
print("*******************************************************")
print("Continue if correct, or rerun this cell if incorrect.")
print("*******************************************************")

# %%
hf.generate_protocol(df_vol=df_vol, iteration=n, plate_well=plate_well, deepplate_well=deepplate_well)

# %%
df_absorbance = hf.process_absorbance(iteration=n, threshold=0.06)
df_absorbance

# %%
results = hf.build_results(n, df_conc, df_absorbance)
results

# %%
norm_results = hf.normalize_data(results, 'normalize')

# %%
norm_results

# %% [markdown]
# # load the results to the optimizer

# %%
ax_client = hf.load_data_to_optimizer(iteration = n, norm_results = norm_results)
ax_client
