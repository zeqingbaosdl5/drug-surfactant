# %% [markdown]
# # import libraries

# %%
import pandas as pd
from ax.service.ax_client import AxClient, ObjectiveProperties
import matplotlib.pyplot as plt
from ax.modelbridge.registry import Models
from ax.modelbridge.generation_strategy import GenerationStep, GenerationStrategy   
import time


import sys
sys.path.append('../')
import helper_functions as hf

# %% [markdown]
# # generate recommendations

# %%
n = hf.get_iteration_number()

for i in range(3):
    print("Very Important: Please Confirm the Iteration Number is Iteration " + str(n))

print()

list_of_drugs = (['IBP']  + ['LOV']  + ['DCF']  + ['GLV']) * 2

for i in range(3):
    print("Very Important: Please Confirm the Drugs are: ", list_of_drugs)
# Out:
# Very Important: Please Confirm the Iteration Number is Iteration 1
# Very Important: Please Confirm the Iteration Number is Iteration 1
# Very Important: Please Confirm the Iteration Number is Iteration 1
#
# Very Important: Please Confirm the Drugs are:  ['IBP', 'LOV', 'DCF', 'GLV', 'IBP', 'LOV', 'DCF', 'GLV']
# Very Important: Please Confirm the Drugs are:  ['IBP', 'LOV', 'DCF', 'GLV', 'IBP', 'LOV', 'DCF', 'GLV']
# Very Important: Please Confirm the Drugs are:  ['IBP', 'LOV', 'DCF', 'GLV', 'IBP', 'LOV', 'DCF', 'GLV']

# %%
time_start = time.time()


df_design, ax_client, data_so_far, best_concs = hf.run_optimizer(current_iteration=n, drug_list= list_of_drugs,  bopt = 1)

time_end = time.time()
time_duration = round((time_end - time_start)/60,2)

print("Time taken for optimization: " + str(time_duration) + " mins")
print("Time taken for optimization: " + str(time_duration * 60) + " seconds")
# Out:
# c:\Users\yunhe\anaconda3\envs\drug_surfactant_ax_0.5\Lib\site-packages\ax\storage\json_store\decoder.py:303: AxParameterWarning: `sort_values` is not specified for `ChoiceParameter` "drugs". Defaulting to `True` for parameters of `ParameterType` INT. To override this behavior (or avoid this warning), specify `sort_values` during `ChoiceParameter` construction.
#   return _class(
# c:\Users\yunhe\anaconda3\envs\drug_surfactant_ax_0.5\Lib\site-packages\ax\storage\json_store\decoder.py:303: AxParameterWarning: `sort_values` is not specified for `ChoiceParameter` "surf_1". Defaulting to `False` for parameters of `ParameterType` STRING. To override this behavior (or avoid this warning), specify `sort_values` during `ChoiceParameter` construction.
#   return _class(
# c:\Users\yunhe\anaconda3\envs\drug_surfactant_ax_0.5\Lib\site-packages\ax\storage\json_store\decoder.py:303: AxParameterWarning: `sort_values` is not specified for `ChoiceParameter` "surf_2". Defaulting to `False` for parameters of `ParameterType` STRING. To override this behavior (or avoid this warning), specify `sort_values` during `ChoiceParameter` construction.
#   return _class(
# [INFO 09-08 23:22:55] ax.service.ax_client: Starting optimization with verbose logging. To disable logging, set the `verbose_logging` argument to `False`. Note that float values in the logs are rounded to 6 decimal points.
# [WARNING 09-08 23:22:55] ax.service.utils.report_utils: Column reason missing for all trials. Not appending column.
# ******************************************************************************** 1/8 ********************************************************************************
#
# Update constraints (drug=IBP)：surf_1_conc+surf_2_conc <= 33.0，>=1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 4
#       1 time_start = time.time()
# ----> 4 df_design, ax_client, data_so_far, best_concs = hf.run_optimizer(current_iteration=n, drug_list= list_of_drugs,  bopt = 1)
#       6 time_end = time.time()
#       7 time_duration = round((time_end - time_start)/60,2)
#
# File c:\Users\yunhe\OneDrive\Documents\GitHub\drug_surfactant\experiments\20250801_search_space\iteration_1\..\helper_functions.py:554, in run_optimizer(current_iteration, drug_list, bopt, n_trials)
#     552     # 7. 用单条 get_next_trial(force=True) 循环生成 n_trials
#     553     for _ in range(n_trials):
# --> 554         parameters, trial_index = ax_client.get_next_trial(
#     555             fixed_features=drug_features,
#     556             force=True,
#     557         )
#     558         trials_data.append({
#     559             "trial_index": trial_index,
#     560             "drug_name":   drug,
#     561             **parameters,
#     562         })
#     564 # 8. 整理返回的 DataFrame
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant_ax_0.5\Lib\site-packages\ax\utils\common\executils.py:167, in retry_on_exception.<locals>.func_wrapper.<locals>.actual_wrapper(*args, **kwargs)
#     163             wait_interval = min(
#     164                 MAX_WAIT_SECONDS, initial_wait_seconds * 2 ** (i - 1)
#     165             )
#     166             time.sleep(wait_interval)
# --> 167         return func(*args, **kwargs)
#     169 # If we are here, it means the retries were finished but
#     170 # The error was suppressed. Hence return the default value provided.
#     171 return default_return_on_suppression
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant_ax_0.5\Lib\site-packages\ax\service\ax_client.py:543, in AxClient.get_next_trial(self, ttl_seconds, force, fixed_features)
#     539         raise OptimizationShouldStop(message=global_stopping_message)
#     541 try:
#     542     trial = self.experiment.new_trial(
# --> 543         generator_run=self._gen_new_generator_run(
#     544             fixed_features=fixed_features
#     545         ),
#     546         ttl_seconds=ttl_seconds,
#     547     )
#     548 except MaxParallelismReachedException as e:
#     549     if self._early_stopping_strategy is not None:
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant_ax_0.5\Lib\site-packages\ax\service\ax_client.py:1781, in AxClient._gen_new_generator_run(self, n, fixed_features)
#    1773 fixed_feats = (
#    1774     InstantiationBase.make_fixed_observation_features(
#    1775         fixed_features=fixed_features
#    (...)   1778     else None
#    1779 )
#    1780 with with_rng_seed(seed=self._random_seed):
# -> 1781     return not_none(self.generation_strategy).gen(
#    1782         experiment=self.experiment,
#    1783         n=n,
#    1784         pending_observations=self._get_pending_observation_features(
#    1785             experiment=self.experiment
#    1786         ),
#    1787         fixed_features=fixed_feats,
#    1788     )
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant_ax_0.5\Lib\site-packages\ax\modelbridge\generation_strategy.py:372, in GenerationStrategy.gen(self, experiment, data, n, pending_observations, **kwargs)
#     337 def gen(
#     338     self,
#     339     experiment: Experiment,
#    (...)    343     **kwargs: Any,
#     344 ) -> GeneratorRun:
#     345     """Produce the next points in the experiment. Additional kwargs passed to
#     346     this method are propagated directly to the underlying model's `gen`, along
#     347     with the `model_gen_kwargs` set on the current generation node.
#    (...)    370             resuggesting points that are currently being evaluated.
#     371     """
# --> 372     return self._gen_multiple(
#     373         experiment=experiment,
#     374         num_generator_runs=1,
#     375         data=data,
#     376         n=n,
#     377         pending_observations=pending_observations,
#     378         **kwargs,
#     379     )[0]
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant_ax_0.5\Lib\site-packages\ax\modelbridge\generation_strategy.py:773, in GenerationStrategy._gen_multiple(self, experiment, num_generator_runs, data, n, pending_observations, **model_gen_kwargs)
#     771 self.experiment = experiment
#     772 self._maybe_transition_to_next_node()
# --> 773 self._fit_current_model(data=data)
#     775 # Get GeneratorRun limit that respects the node's transition criterion that
#     776 # affect the number of generator runs that can be produced.
#     777 gr_limit = self._curr.generator_run_limit(raise_generation_errors=True)
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant_ax_0.5\Lib\site-packages\ax\modelbridge\generation_strategy.py:852, in GenerationStrategy._fit_current_model(self, data)
#     844 """Fits or update the model on the current generation node (does not move
#     845 between generation nodes).
#     846
#    (...)    849         strategy will obtain the data via ``experiment.lookup_data``.
#     850 """
#     851 data = self.experiment.lookup_data() if data is None else data
# --> 852 self._curr.fit(experiment=self.experiment, data=data)
#     853 self._model = self._curr._fitted_model
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant_ax_0.5\Lib\site-packages\ax\modelbridge\generation_node.py:237, in GenerationNode.fit(self, experiment, data, search_space, optimization_config, **kwargs)
#     232 for model_spec in self.model_specs:
#     233     logger.debug(
#     234         f"Fitting model {model_spec.model_key} with data for "
#     235         f"trials: {trial_indices_in_data}"
#     236     )
# --> 237     model_spec.fit(  # Stores the fitted model as `model_spec._fitted_model`
#     238         experiment=experiment,
#     239         data=data,
#     240         search_space=search_space,
#     241         optimization_config=optimization_config,
#     242         **{
#     243             **self._get_model_state_from_last_generator_run(
#     244                 model_spec=model_spec
#     245             ),
#     246             **kwargs,
#     247         },
#     248     )
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant_ax_0.5\Lib\site-packages\ax\modelbridge\model_spec.py:147, in ModelSpec.fit(self, experiment, data, **model_kwargs)
#     141     self.fitted_model._fit_if_implemented(
#     142         search_space=search_space, observations=observations, time_so_far=0.0
#     143     )
#     145 else:
#     146     # Fit from scratch.
# --> 147     self._fitted_model = self.model_enum(
#     148         experiment=experiment,
#     149         data=data,
#     150         **combined_model_kwargs,
#     151     )
#     152     self._last_fit_arg_ids = self._get_fit_arg_ids(
#     153         experiment=experiment, combined_model_kwargs=combined_model_kwargs
#     154     )
#
# File c:\Users\yunhe\anaconda3\envs\drug_surfactant_ax_0.5\Lib\site-packages\ax\modelbridge\registry.py:316, in ModelRegistryBase.__call__(self, search_space, experiment, data, silently_filter_kwargs, **kwargs)
#     314     extra_keywords = [kw for kw in kwargs.keys() if kw not in checked_kwargs]
#     315     if len(extra_keywords) != 0:
# --> 316         raise ValueError(
#     317             f"Arguments {extra_keywords} are not expected by any of {callables}"
#     318         )
#     320 # Create model with consolidated arguments: defaults + passed in kwargs.
#     321 model_kwargs = consolidate_kwargs(
#     322     kwargs_iterable=[
#     323         get_function_default_arguments(model_class),
#    (...)    327     keywords=get_function_argument_names(model_class),
#     328 )
#
# ValueError: Arguments ['task_features'] are not expected by any of (<class 'ax.models.torch.botorch_modular.model.BoTorchModel'>, <class 'ax.modelbridge.torch.TorchModelBridge'>)

# %%
hf.print_campaign_type(ax_client)

# %% [markdown]
# # process results

# %%
ax_client = hf.load_design_optimizer(n)
ax_client.get_trials_data_frame()

# %%
df_design, df_vol = hf.design_to_vol (n)
df_design

# %%
df_vol

# %%
df_vol[['s1', 's2', 's3', 's4', 's5', 's6', 's7', 's8']].sum()

# %%
plate_well = input("Enter the plate well starting well (e.g., F1): ")
deepplate_well = input("Enter the deep plate well starting well (e.g., F1): ")


print("Please confirm the following information:")
print("Wellplate will start at: " + plate_well)
print("Deep plate will start at: " + deepplate_well)

print()
print("*******************************************************")
print("Continue if correct, or rerun this cell if incorrect.")
print("*******************************************************")

# %%
hf.generate_protocol(df_vol=df_vol, iteration=n, plate_well=plate_well, deepplate_well=deepplate_well)

# %%
df_absorbance = hf.process_absorbance(iteration=n, threshold=0.06)
df_absorbance

# %%
results = hf.build_results(n, df_absorbance)
results

# %% [markdown]
# # load the results to the optimizer

# %%
ax_client = hf.load_data_to_optimizer(iteration = n, results = results)
ax_client
