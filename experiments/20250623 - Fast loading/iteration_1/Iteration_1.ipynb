# %% [markdown]
# # import libraries

# %%
import pandas as pd
from ax.service.ax_client import AxClient, ObjectiveProperties
import matplotlib.pyplot as plt
from ax.modelbridge.factory import Models
from ax.modelbridge.generation_strategy import GenerationStep, GenerationStrategy   
import time


import sys
sys.path.append('../')
import helper_functions as hf

# %% [markdown]
# # generate recommendations

# %%
n = hf.get_iteration_number()

for i in range(3):
    print("Very Important: Please Confirm the Iteration Number is Iteration " + str(n))
# Out:
# Very Important: Please Confirm the Iteration Number is Iteration 1
# Very Important: Please Confirm the Iteration Number is Iteration 1
# Very Important: Please Confirm the Iteration Number is Iteration 1

# %%
time_start = time.time()


df_design, ax_client = hf.run_optimizer(current_iteration=n, drug = "IBP", bopt = 1,n_trials=6)

time_end = time.time()
time_duration = round((time_end - time_start)/60,2)

print("Time taken for optimization: " + str(time_duration) + " mins")
print("Time taken for optimization: " + str(time_duration * 60) + " seconds")
# Out:
# [INFO 06-24 16:04:27] ax.service.ax_client: Starting optimization with verbose logging. To disable logging, set the `verbose_logging` argument to `False`. Note that float values in the logs are rounded to 6 decimal points.
# [INFO 06-24 16:04:27] ax.modelbridge.transforms.standardize_y: Outcome complexity is constant, within tolerance.
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/botorch/models/utils/assorted.py:267: InputDataWarning: Data (outcome observations) is not standardized (std = tensor([0.], dtype=torch.float64), mean = tensor([0.], dtype=torch.float64)).Please consider scaling the input to zero mean and unit variance.
#   check_standardization(Y=train_Y, raise_on_fail=raise_on_fail)
# **************************************************************************************************************
#
# Generating Bayesian Optimization trialsfor
# Drug name:  Ibuprofen IBP  | Iteration:  1
#
# **************************************************************************************************************
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 time_start = time.time()
# ----> 4 df_design, ax_client = hf.run_optimizer(current_iteration=n, drug = "IBP", bopt = 1,n_trials=6)
#       6 time_end = time.time()
#       7 time_duration = round((time_end - time_start)/60,2)
#
# File ~/Documents/GitHub/drug_surfactant/experiments/20250623 - Fast loading/iteration_1/../helper_functions.py:254, in run_optimizer(current_iteration, drug, bopt, n_trials)
#     251 print()
#     252 print("**************************************************************************************************************")
# --> 254 trials, _ = ax_client.get_next_trials(n_trials, fixed_features=drug_features)
#     256 # Prepare the trial data for DataFrame
#     257 trials_data = []
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/service/ax_client.py:671, in AxClient.get_next_trials(self, max_trials, ttl_seconds, fixed_features)
#     669 for _ in range(max_trials):
#     670     try:
# --> 671         params, trial_index = self.get_next_trial(
#     672             ttl_seconds=ttl_seconds, fixed_features=fixed_features
#     673         )
#     674         trials_dict[trial_index] = params
#     675     except OptimizationComplete as err:
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/utils/common/executils.py:169, in retry_on_exception.<locals>.func_wrapper.<locals>.actual_wrapper(*args, **kwargs)
#     165             wait_interval = min(
#     166                 MAX_WAIT_SECONDS, initial_wait_seconds * 2 ** (i - 1)
#     167             )
#     168             time.sleep(wait_interval)
# --> 169         return func(*args, **kwargs)
#     171 # If we are here, it means the retries were finished but
#     172 # The error was suppressed. Hence return the default value provided.
#     173 return default_return_on_suppression
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/service/ax_client.py:576, in AxClient.get_next_trial(self, ttl_seconds, force, fixed_features)
#     572         raise OptimizationShouldStop(message=global_stopping_message)
#     574 try:
#     575     trial = self.experiment.new_trial(
# --> 576         generator_run=self._gen_new_generator_run(
#     577             fixed_features=fixed_features
#     578         ),
#     579         ttl_seconds=ttl_seconds,
#     580     )
#     581 except MaxParallelismReachedException as e:
#     582     if self._early_stopping_strategy is not None:
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/service/ax_client.py:1818, in AxClient._gen_new_generator_run(self, n, fixed_features)
#    1810 fixed_feats = (
#    1811     InstantiationBase.make_fixed_observation_features(
#    1812         fixed_features=fixed_features
#    (...)   1815     else None
#    1816 )
#    1817 with with_rng_seed(seed=self._random_seed):
# -> 1818     return none_throws(self.generation_strategy).gen(
#    1819         experiment=self.experiment,
#    1820         n=n,
#    1821         pending_observations=self._get_pending_observation_features(
#    1822             experiment=self.experiment
#    1823         ),
#    1824         fixed_features=fixed_feats,
#    1825     )
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/generation_strategy.py:339, in GenerationStrategy.gen(self, experiment, data, pending_observations, n, fixed_features)
#     304 def gen(
#     305     self,
#     306     experiment: Experiment,
#    (...)    310     fixed_features: ObservationFeatures | None = None,
#     311 ) -> GeneratorRun:
#     312     """Produce the next points in the experiment. Additional kwargs passed to
#     313     this method are propagated directly to the underlying model's `gen`, along
#     314     with the `model_gen_kwargs` set on the current generation node.
#    (...)    337             resuggesting points that are currently being evaluated.
#     338     """
# --> 339     gr = self._gen_with_multiple_nodes(
#     340         experiment=experiment,
#     341         data=data,
#     342         n=n,
#     343         pending_observations=pending_observations,
#     344         fixed_features=fixed_features,
#     345     )
#     346     if len(gr) > 1:
#     347         raise UnsupportedError(
#     348             "By calling into GenerationStrategy.gen(), you are should be "
#     349             "expecting a single `Trial` with only one `GeneratorRun`. However, "
#     350             "the underlying GenerationStrategy produced multiple `GeneratorRuns` "
#     351             f"and returned the following list of `GeneratorRun`-s: {gr}"
#     352         )
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/generation_strategy.py:449, in GenerationStrategy._gen_with_multiple_nodes(self, experiment, data, pending_observations, n, fixed_features, arms_per_node)
#     447 if node_to_gen_from._should_skip:
#     448     continue
# --> 449 self._fit_current_model(data=data, status_quo_features=sq_ft_from_node)
#     450 self._curr.generator_run_limit(raise_generation_errors=True)
#     451 if arms_from_node != 0:
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/generation_strategy.py:1116, in GenerationStrategy._fit_current_model(self, data, status_quo_features)
#    1110     self._curr.fit(
#    1111         experiment=self.experiment,
#    1112         data=data,
#    1113         status_quo_features=status_quo_features,
#    1114     )
#    1115 else:
# -> 1116     self._curr.fit(
#    1117         experiment=self.experiment,
#    1118         data=data,
#    1119     )
#    1120 self._model = self._curr._fitted_model
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/generation_node.py:311, in GenerationNode.fit(self, experiment, data, search_space, optimization_config, **kwargs)
#     306 for model_spec in self.model_specs:
#     307     logger.debug(
#     308         f"Fitting model {model_spec.model_key} with data for "
#     309         f"trials: {trial_indices_in_data}"
#     310     )
# --> 311     model_spec.fit(  # Stores the fitted model as `model_spec._fitted_model`
#     312         experiment=experiment,
#     313         data=data,
#     314         search_space=search_space,
#     315         optimization_config=optimization_config,
#     316         **{
#     317             **self._get_model_state_from_last_generator_run(
#     318                 model_spec=model_spec
#     319             ),
#     320             **kwargs,
#     321         },
#     322     )
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/model_spec.py:148, in ModelSpec.fit(self, experiment, data, **model_kwargs)
#     142     self.fitted_model._fit_if_implemented(
#     143         search_space=search_space, observations=observations, time_so_far=0.0
#     144     )
#     146 else:
#     147     # Fit from scratch.
# --> 148     self._fitted_model = self.model_enum(
#     149         experiment=experiment,
#     150         data=data,
#     151         **combined_model_kwargs,
#     152     )
#     153     self._last_fit_arg_ids = self._get_fit_arg_ids(
#     154         experiment=experiment, combined_model_kwargs=combined_model_kwargs
#     155     )
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/registry.py:347, in ModelRegistryBase.__call__(self, search_space, experiment, data, silently_filter_kwargs, **kwargs)
#     334 bridge_kwargs = consolidate_kwargs(
#     335     kwargs_iterable=[
#     336         get_function_default_arguments(bridge_class),
#    (...)    343     ),
#     344 )
#     346 # Create model bridge with the consolidated kwargs.
# --> 347 model_bridge = bridge_class(
#     348     search_space=search_space or none_throws(experiment).search_space,
#     349     experiment=experiment,
#     350     data=data,
#     351     model=model,
#     352     **bridge_kwargs,
#     353 )
#     355 if model_setup_info.not_saved_model_kwargs:
#     356     for key in model_setup_info.not_saved_model_kwargs:
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/torch.py:149, in TorchModelBridge.__init__(self, experiment, search_space, data, model, transforms, transform_configs, torch_dtype, torch_device, status_quo_name, status_quo_features, optimization_config, expand_model_space, fit_out_of_design, fit_abandoned, fit_tracking_metrics, fit_on_init, default_model_gen_options)
#     144     optimization_config = none_throws(
#     145         optimization_config or experiment.optimization_config
#     146     )
#     147     self.is_moo_problem = optimization_config.is_moo_problem
# --> 149 super().__init__(
#     150     experiment=experiment,
#     151     search_space=search_space,
#     152     data=data,
#     153     model=model,
#     154     transforms=transforms,
#     155     transform_configs=transform_configs,
#     156     status_quo_name=status_quo_name,
#     157     status_quo_features=status_quo_features,
#     158     optimization_config=optimization_config,
#     159     expand_model_space=expand_model_space,
#     160     fit_out_of_design=fit_out_of_design,
#     161     fit_abandoned=fit_abandoned,
#     162     fit_tracking_metrics=fit_tracking_metrics,
#     163     fit_on_init=fit_on_init,
#     164 )
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/base.py:234, in ModelBridge.__init__(self, search_space, model, transforms, experiment, data, transform_configs, status_quo_name, status_quo_features, optimization_config, expand_model_space, fit_out_of_design, fit_abandoned, fit_tracking_metrics, fit_on_init)
#     227 if fit_on_init:
#     228     observations, search_space = self._transform_data(
#     229         observations=observations_raw,
#     230         search_space=self._model_space,
#     231         transforms=self._raw_transforms,
#     232         transform_configs=self._transform_configs,
#     233     )
# --> 234     self._fit_if_implemented(
#     235         search_space=search_space,
#     236         observations=observations,
#     237         time_so_far=time.monotonic() - t_fit_start,
#     238     )
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/base.py:257, in ModelBridge._fit_if_implemented(self, search_space, observations, time_so_far)
#     255 try:
#     256     t_fit_start = time.monotonic()
# --> 257     self._fit(
#     258         model=self.model,
#     259         search_space=search_space,
#     260         observations=observations,
#     261     )
#     262     increment = time.monotonic() - t_fit_start + time_so_far
#     263     self.fit_time += increment
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/modelbridge/torch.py:674, in TorchModelBridge._fit(self, model, search_space, observations, parameters, **kwargs)
#     672 # Fit
#     673 self.model = model
# --> 674 none_throws(self.model).fit(
#     675     datasets=datasets,
#     676     search_space_digest=search_space_digest,
#     677     candidate_metadata=candidate_metadata,
#     678     **kwargs,
#     679 )
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/models/torch/botorch_modular/model.py:206, in BoTorchModel.fit(self, datasets, search_space_digest, candidate_metadata, state_dict, refit, **additional_model_inputs)
#     204     for config in config_list:
#     205         config.model_options.update(additional_model_inputs)
# --> 206 self.surrogate.fit(
#     207     datasets=datasets,
#     208     search_space_digest=search_space_digest,
#     209     candidate_metadata=candidate_metadata,
#     210     state_dict=state_dict,
#     211     refit=refit,
#     212 )
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/models/torch/botorch_modular/surrogate.py:963, in Surrogate.fit(self, datasets, search_space_digest, candidate_metadata, state_dict, refit)
#     961 if len(model_configs) == 1 or (not refit and model_config is not None):
#     962     best_model_config = model_config or model_configs[0]
# --> 963     model = self._construct_model(
#     964         dataset=dataset,
#     965         search_space_digest=search_space_digest,
#     966         model_config=best_model_config,
#     967         default_botorch_model_class=default_botorch_model_class,
#     968         state_dict=submodel_state_dict,
#     969         refit=refit,
#     970     )
#     971 # Case 2: There is more than 1 model config and we want to refit
#     972 # or don't know what the previous best model was
#     973 else:
#     974     if len(dataset.outcome_names) > 1:
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/models/torch/botorch_modular/surrogate.py:861, in Surrogate._construct_model(self, dataset, search_space_digest, model_config, default_botorch_model_class, state_dict, refit)
#     859     model.load_state_dict(state_dict)
#     860 if state_dict is None or refit:
# --> 861     fit_botorch_model(
#     862         model=model,
#     863         mll_class=model_config.mll_class,
#     864         mll_options=model_config.mll_options,
#     865     )
#     866 return model
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/models/torch/botorch_modular/utils.py:396, in fit_botorch_model(model, mll_class, mll_options)
#     393 for m in models:
#     394     # TODO: Support deterministic models when we support `ModelList`
#     395     if is_fully_bayesian(m):
# --> 396         fit_fully_bayesian_model_nuts(
#     397             m,
#     398             disable_progbar=True,
#     399             **mll_options,
#     400         )
#     401     elif isinstance(m, (GPyTorchModel, PairwiseGP)):
#     402         mll_options = mll_options or {}
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/botorch/fit.py:384, in fit_fully_bayesian_model_nuts(model, max_tree_depth, warmup_steps, num_samples, thinning, disable_progbar, jit_compile)
#     371 nuts = NUTS(
#     372     model.pyro_model.sample,
#     373     jit_compile=jit_compile,
#    (...)    376     max_tree_depth=max_tree_depth,
#     377 )
#     378 mcmc = MCMC(
#     379     nuts,
#     380     warmup_steps=warmup_steps,
#     381     num_samples=num_samples,
#     382     disable_progbar=disable_progbar,
#     383 )
# --> 384 mcmc.run()
#     386 # Get final MCMC samples from the Pyro model
#     387 mcmc_samples = model.pyro_model.postprocess_mcmc_samples(
#     388     mcmc_samples=mcmc.get_samples()
#     389 )
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/pyro/poutine/messenger.py:32, in _context_wrap(context, fn, *args, **kwargs)
#      25 def _context_wrap(
#      26     context: "Messenger",
#      27     fn: Callable,
#      28     *args: Any,
#      29     **kwargs: Any,
#      30 ) -> Any:
#      31     with context:
# ---> 32         return fn(*args, **kwargs)
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/pyro/infer/mcmc/api.py:565, in MCMC.run(self, *args, **kwargs)
#     556 with optional(
#     557     pyro.validation_enabled(not self.disable_validation),
#     558     self.disable_validation is not None,
#    (...)    562     # This also resolves "RuntimeError: Cowardly refusing to serialize non-leaf tensor which
#     563     # requires_grad", which happens with `jit_compile` under PyTorch 1.7
#     564     args = [arg.detach() if torch.is_tensor(arg) else arg for arg in args]
# --> 565     for x, chain_id in self.sampler.run(*args, **kwargs):
#     566         if num_samples[chain_id] == 0:
#     567             num_samples[chain_id] += 1
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/pyro/infer/mcmc/api.py:225, in _UnarySampler.run(self, *args, **kwargs)
#     223 logger = initialize_logger(logger, "", progress_bar)
#     224 hook_w_logging = _add_logging_hook(logger, progress_bar, self.hook)
# --> 225 for sample in _gen_samples(
#     226     self.kernel,
#     227     self.warmup_steps,
#     228     self.num_samples,
#     229     hook_w_logging,
#     230     i if self.num_chains > 1 else None,
#     231     *args,
#     232     **kwargs
#     233 ):
#     234     yield sample, i  # sample, chain_id
#     235 self.kernel.cleanup()
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/pyro/infer/mcmc/api.py:152, in _gen_samples(kernel, warmup_steps, num_samples, hook, chain_id, *args, **kwargs)
#     150 yield {name: params[name].shape for name in save_params}
#     151 for i in range(warmup_steps):
# --> 152     params = kernel.sample(params)
#     153     hook(
#     154         kernel,
#     155         params,
#     156         "Warmup [{}]".format(chain_id) if chain_id is not None else "Warmup",
#     157         i,
#     158     )
#     159 for i in range(num_samples):
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/pyro/infer/mcmc/nuts.py:437, in NUTS.sample(self, params)
#     433 direction = int(direction.item())
#     434 if (
#     435     direction == 1
#     436 ):  # go to the right, start from the right leaf of current tree
# --> 437     new_tree = self._build_tree(
#     438         z_right,
#     439         r_right,
#     440         z_right_grads,
#     441         log_slice,
#     442         direction,
#     443         tree_depth,
#     444         energy_current,
#     445     )
#     446     # update leaf for the next doubling process
#     447     z_right = new_tree.z_right
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/pyro/infer/mcmc/nuts.py:259, in NUTS._build_tree(self, z, r, z_grads, log_slice, direction, tree_depth, energy_current)
#     254     return self._build_basetree(
#     255         z, r, z_grads, log_slice, direction, energy_current
#     256     )
#     258 # build the first half of tree
# --> 259 half_tree = self._build_tree(
#     260     z, r, z_grads, log_slice, direction, tree_depth - 1, energy_current
#     261 )
#     262 z_proposal = half_tree.z_proposal
#     263 z_proposal_pe = half_tree.z_proposal_pe
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/pyro/infer/mcmc/nuts.py:281, in NUTS._build_tree(self, z, r, z_grads, log_slice, direction, tree_depth, energy_current)
#     279     r = half_tree.r_left
#     280     z_grads = half_tree.z_left_grads
# --> 281 other_half_tree = self._build_tree(
#     282     z, r, z_grads, log_slice, direction, tree_depth - 1, energy_current
#     283 )
#     285 if self.use_multinomial_sampling:
#     286     tree_weight = _logaddexp(half_tree.weight, other_half_tree.weight)
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/pyro/infer/mcmc/nuts.py:259, in NUTS._build_tree(self, z, r, z_grads, log_slice, direction, tree_depth, energy_current)
#     254     return self._build_basetree(
#     255         z, r, z_grads, log_slice, direction, energy_current
#     256     )
#     258 # build the first half of tree
# --> 259 half_tree = self._build_tree(
#     260     z, r, z_grads, log_slice, direction, tree_depth - 1, energy_current
#     261 )
#     262 z_proposal = half_tree.z_proposal
#     263 z_proposal_pe = half_tree.z_proposal_pe
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/pyro/infer/mcmc/nuts.py:254, in NUTS._build_tree(self, z, r, z_grads, log_slice, direction, tree_depth, energy_current)
#     250 def _build_tree(
#     251     self, z, r, z_grads, log_slice, direction, tree_depth, energy_current
#     252 ):
#     253     if tree_depth == 0:
# --> 254         return self._build_basetree(
#     255             z, r, z_grads, log_slice, direction, energy_current
#     256         )
#     258     # build the first half of tree
#     259     half_tree = self._build_tree(
#     260         z, r, z_grads, log_slice, direction, tree_depth - 1, energy_current
#     261     )
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/pyro/infer/mcmc/nuts.py:199, in NUTS._build_basetree(self, z, r, z_grads, log_slice, direction, energy_current)
#     197 def _build_basetree(self, z, r, z_grads, log_slice, direction, energy_current):
#     198     step_size = self.step_size if direction == 1 else -self.step_size
# --> 199     z_new, r_new, z_grads, potential_energy = velocity_verlet(
#     200         z,
#     201         r,
#     202         self.potential_fn,
#     203         self.mass_matrix_adapter.kinetic_grad,
#     204         step_size,
#     205         z_grads=z_grads,
#     206     )
#     207     r_new_unscaled = self.mass_matrix_adapter.unscale(r_new)
#     208     energy_new = potential_energy + self._kinetic_energy(r_new_unscaled)
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/pyro/ops/integrator.py:39, in velocity_verlet(z, r, potential_fn, kinetic_grad, step_size, num_steps, z_grads)
#      37 r_next = r.copy()
#      38 for _ in range(num_steps):
# ---> 39     z_next, r_next, z_grads, potential_energy = _single_step_verlet(
#      40         z_next, r_next, potential_fn, kinetic_grad, step_size, z_grads
#      41     )
#      42 return z_next, r_next, z_grads, potential_energy
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/pyro/ops/integrator.py:61, in _single_step_verlet(z, r, potential_fn, kinetic_grad, step_size, z_grads)
#      58 for site_name in z:
#      59     z[site_name] = z[site_name] + step_size * r_grads[site_name]  # z(n+1)
# ---> 61 z_grads, potential_energy = potential_grad(potential_fn, z)
#      62 for site_name in r:
#      63     r[site_name] = r[site_name] + 0.5 * step_size * (-z_grads[site_name])  # r(n+1)
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/pyro/ops/integrator.py:91, in potential_grad(potential_fn, z)
#      89     else:
#      90         raise e
# ---> 91 grads = grad(potential_energy, z_nodes)
#      92 for node in z_nodes:
#      93     node.requires_grad_(False)
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/torch/autograd/__init__.py:502, in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused, is_grads_batched, materialize_grads)
#     498     result = _vmap_internals._vmap(vjp, 0, 0, allow_none_pass_through=True)(
#     499         grad_outputs_
#     500     )
#     501 else:
# --> 502     result = _engine_run_backward(
#     503         outputs,
#     504         grad_outputs_,
#     505         retain_graph,
#     506         create_graph,
#     507         inputs,
#     508         allow_unused,
#     509         accumulate_grad=False,
#     510     )
#     511 if materialize_grads:
#     512     if any(
#     513         result[i] is None and not is_tensor_like(inputs[i])
#     514         for i in range(len(inputs))
#     515     ):
#
# File /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/torch/autograd/graph.py:824, in _engine_run_backward(t_outputs, *args, **kwargs)
#     822     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     823 try:
# --> 824     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     825         t_outputs, *args, **kwargs
#     826     )  # Calls into the C++ engine to run the backward pass
#     827 finally:
#     828     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# # process results

# %%
ax_client = hf.load_design_optimizer(n)
ax_client.experiment.trials

# %%
df_conc, df_vol = hf.design_to_conc_to_vol (n)

# %%
plate_well = input("Enter the plate well starting well (e.g., F1): ")
deepplate_well = input("Enter the deep plate well starting well (e.g., F1): ")


print("Please confirm the following information:")
print("Wellplate will start at: " + plate_well)
print("Deep plate will start at: " + deepplate_well)

print()
print("*******************************************************")
print("Continue if correct, or rerun this cell if incorrect.")
print("*******************************************************")

# %%
hf.generate_protocol(df_vol=df_vol, iteration=n, plate_well=plate_well, deepplate_well=deepplate_well)

# %%
df_absorbance = hf.process_absorbance(iteration=n, threshold=0.1)
df_absorbance

# %%
results = hf.build_results(n, df_conc, df_absorbance)
results

# %%
norm_results = hf.normalize_data(results, 'normalize')

# %%
norm_results

# %% [markdown]
# # load the results to the optimizer

# %%
ax_client = hf.load_data_to_optimizer(iteration = n, norm_results = norm_results)
ax_client
