# %% [markdown]
# # import libraries

# %%
import pandas as pd
from ax.service.ax_client import AxClient, ObjectiveProperties
import matplotlib.pyplot as plt
from ax.modelbridge.factory import Models
from ax.modelbridge.generation_strategy import GenerationStep, GenerationStrategy   
import time


import sys
sys.path.append('../')
import helper_functions as hf

# %% [markdown]
# # generate recommendations

# %%
n = hf.get_iteration_number()

for i in range(3):
    print("Very Important: Please Confirm the Iteration Number is Iteration " + str(n))
# Out:
# Very Important: Please Confirm the Iteration Number is Iteration 3
# Very Important: Please Confirm the Iteration Number is Iteration 3
# Very Important: Please Confirm the Iteration Number is Iteration 3

# %%
time_start = time.time()


df_design, ax_client = hf.run_optimizer(current_iteration=n, drug = "IBP", bopt = 1, n_trials=6)

time_end = time.time()
time_duration = round((time_end - time_start)/60,2)

print("Time taken for optimization: " + str(time_duration) + " mins")
print("Time taken for optimization: " + str(time_duration * 60) + " seconds")
# Out:
# [INFO 06-23 12:50:23] ax.service.ax_client: Starting optimization with verbose logging. To disable logging, set the `verbose_logging` argument to `False`. Note that float values in the logs are rounded to 6 decimal points.
# **************************************************************************************************************
#
# Generating Bayesian Optimization trialsfor
# Drug name:  Ibuprofen IBP  | Iteration:  3
#
# **************************************************************************************************************
# [INFO 06-23 12:54:55] ax.service.ax_client: Generated new trial 18 with parameters {'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 0, 's2': 0, 's3': 100, 's4': 79, 's5': 0, 's6': 0, 's7': 100, 's8': 0, 'surfactant_conc': 1, 'drug_conc': 100} using model SAASBO.
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/core/data.py:295: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [INFO 06-23 12:59:43] ax.service.ax_client: Generated new trial 19 with parameters {'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 0, 's2': 0, 's3': 100, 's4': 0, 's5': 0, 's6': 0, 's7': 100, 's8': 100, 'surfactant_conc': 100, 'drug_conc': 1} using model SAASBO.
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/core/data.py:295: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [INFO 06-23 13:05:31] ax.service.ax_client: Generated new trial 20 with parameters {'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 56, 's2': 0, 's3': 100, 's4': 0, 's5': 0, 's6': 64, 's7': 100, 's8': 0, 'surfactant_conc': 35, 'drug_conc': 100} using model SAASBO.
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/core/data.py:295: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [INFO 06-23 13:12:50] ax.service.ax_client: Generated new trial 21 with parameters {'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 0, 's2': 0, 's3': 0, 's4': 1, 's5': 100, 's6': 46, 's7': 100, 's8': 0, 'surfactant_conc': 71, 'drug_conc': 1} using model SAASBO.
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/core/data.py:295: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [INFO 06-23 13:21:14] ax.service.ax_client: Generated new trial 22 with parameters {'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 7, 's2': 0, 's3': 100, 's4': 0, 's5': 100, 's6': 100, 's7': 100, 's8': 100, 'surfactant_conc': 70, 'drug_conc': 100} using model SAASBO.
# /opt/anaconda3/envs/drug_surfactant/lib/python3.11/site-packages/ax/core/data.py:295: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [INFO 06-23 13:29:44] ax.service.ax_client: Generated new trial 23 with parameters {'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 0, 's2': 0, 's3': 100, 's4': 1, 's5': 0, 's6': 0, 's7': 64, 's8': 0, 'surfactant_conc': 83, 'drug_conc': 1} using model SAASBO.
# [INFO 06-23 13:29:44] ax.service.ax_client: Saved JSON-serialized state of optimization to `optimizer/optimizer_3.json`.
# Time taken for optimization: 39.35 mins
# Time taken for optimization: 2361.0 seconds

# %% [markdown]
# # process results

# %%
ax_client = hf.load_design_optimizer(n)
ax_client.experiment.trials
# Out:
# [INFO 06-23 13:29:48] ax.service.ax_client: Starting optimization with verbose logging. To disable logging, set the `verbose_logging` argument to `False`. Note that float values in the logs are rounded to 6 decimal points.
# {0: Trial(experiment_name='drug_surfactant', index=0, status=TrialStatus.COMPLETED, arm=Arm(name='0_0', parameters={'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 48, 's2': 59, 's3': 50, 's4': 31, 's5': 96, 's6': 8, 's7': 9, 's8': 35, 'surfactant_conc': 86, 'drug_conc': 77})),
#  1: Trial(experiment_name='drug_surfactant', index=1, status=TrialStatus.COMPLETED, arm=Arm(name='1_0', parameters={'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 95, 's2': 22, 's3': 75, 's4': 63, 's5': 43, 's6': 72, 's7': 55, 's8': 100, 'surfactant_conc': 35, 'drug_conc': 3})),
#  2: Trial(experiment_name='drug_surfactant', index=2, status=TrialStatus.COMPLETED, arm=Arm(name='2_0', parameters={'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 53, 's2': 98, 's3': 4, 's4': 13, 's5': 22, 's6': 90, 's7': 29, 's8': 56, 'surfactant_conc': 18, 'drug_conc': 32})),
#  3: Trial(experiment_name='drug_surfactant', index=3, status=TrialStatus.COMPLETED, arm=Arm(name='3_0', parameters={'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 6, 's2': 33, 's3': 71, 's4': 83, 's5': 63, 's6': 26, 's7': 87, 's8': 16, 'surfactant_conc': 68, 'drug_conc': 58})),
#  4: Trial(experiment_name='drug_surfactant', index=4, status=TrialStatus.COMPLETED, arm=Arm(name='4_0', parameters={'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 24, 's2': 86, 's3': 97, 's4': 98, 's5': 58, 's6': 17, 's7': 48, 's8': 64, 'surfactant_conc': 1, 'drug_conc': 25})),
#  5: Trial(experiment_name='drug_surfactant', index=5, status=TrialStatus.COMPLETED, arm=Arm(name='5_0', parameters={'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 72, 's2': 45, 's3': 29, 's4': 4, 's5': 5, 's6': 53, 's7': 93, 's8': 2, 'surfactant_conc': 51, 'drug_conc': 99})),
#  6: Trial(experiment_name='drug_surfactant', index=6, status=TrialStatus.COMPLETED, arm=Arm(name='6_0', parameters={'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 0, 's2': 0, 's3': 0, 's4': 100, 's5': 0, 's6': 0, 's7': 100, 's8': 0, 'surfactant_conc': 1, 'drug_conc': 100})),
#  7: Trial(experiment_name='drug_surfactant', index=7, status=TrialStatus.COMPLETED, arm=Arm(name='7_0', parameters={'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 0, 's2': 0, 's3': 100, 's4': 0, 's5': 0, 's6': 0, 's7': 100, 's8': 0, 'surfactant_conc': 1, 'drug_conc': 100})),
#  8: Trial(experiment_name='drug_surfactant', index=8, status=TrialStatus.COMPLETED, arm=Arm(name='8_0', parameters={'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 100, 's2': 100, 's3': 100, 's4': 100, 's5': 0, 's6': 100, 's7': 100, 's8': 0, 'surfactant_conc': 100, 'drug_conc': 100})),
#  9: Trial(experiment_name='drug_surfactant', index=9, status=TrialStatus.COMPLETED, arm=Arm(name='9_0', parameters={'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 100, 's2': 0, 's3': 0, 's4': 100, 's5': 0, 's6': 0, 's7': 100, 's8': 0, 'surfactant_conc': 1, 'drug_conc': 100})),
#  10: Trial(experiment_name='drug_surfactant', index=10, status=TrialStatus.COMPLETED, arm=Arm(name='10_0', parameters={'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 100, 's2': 0, 's3': 100, 's4': 100, 's5': 100, 's6': 0, 's7': 100, 's8': 0, 'surfactant_conc': 1, 'drug_conc': 100})),
#  11: Trial(experiment_name='drug_surfactant', index=11, status=TrialStatus.COMPLETED, arm=Arm(name='11_0', parameters={'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 0, 's2': 0, 's3': 100, 's4': 0, 's5': 100, 's6': 0, 's7': 100, 's8': 0, 'surfactant_conc': 1, 'drug_conc': 100})),
#  12: Trial(experiment_name='drug_surfactant', index=12, status=TrialStatus.COMPLETED, arm=Arm(name='12_0', parameters={'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 5, 's2': 0, 's3': 0, 's4': 19, 's5': 0, 's6': 39, 's7': 90, 's8': 0, 'surfactant_conc': 54, 'drug_conc': 100})),
#  13: Trial(experiment_name='drug_surfactant', index=13, status=TrialStatus.COMPLETED, arm=Arm(name='13_0', parameters={'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 0, 's2': 0, 's3': 100, 's4': 0, 's5': 0, 's6': 34, 's7': 88, 's8': 0, 'surfactant_conc': 53, 'drug_conc': 100})),
#  14: Trial(experiment_name='drug_surfactant', index=14, status=TrialStatus.COMPLETED, arm=Arm(name='14_0', parameters={'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 0, 's2': 43, 's3': 49, 's4': 100, 's5': 0, 's6': 46, 's7': 100, 's8': 0, 'surfactant_conc': 1, 'drug_conc': 100})),
#  15: Trial(experiment_name='drug_surfactant', index=15, status=TrialStatus.COMPLETED, arm=Arm(name='15_0', parameters={'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 72, 's2': 0, 's3': 0, 's4': 100, 's5': 0, 's6': 41, 's7': 89, 's8': 0, 'surfactant_conc': 57, 'drug_conc': 100})),
#  16: Trial(experiment_name='drug_surfactant', index=16, status=TrialStatus.COMPLETED, arm=Arm(name='16_0', parameters={'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 0, 's2': 0, 's3': 0, 's4': 0, 's5': 100, 's6': 41, 's7': 100, 's8': 0, 'surfactant_conc': 57, 'drug_conc': 100})),
#  17: Trial(experiment_name='drug_surfactant', index=17, status=TrialStatus.COMPLETED, arm=Arm(name='17_0', parameters={'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 72, 's2': 0, 's3': 100, 's4': 0, 's5': 0, 's6': 0, 's7': 87, 's8': 0, 'surfactant_conc': 57, 'drug_conc': 100})),
#  18: Trial(experiment_name='drug_surfactant', index=18, status=TrialStatus.RUNNING, arm=Arm(name='18_0', parameters={'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 0, 's2': 0, 's3': 100, 's4': 79, 's5': 0, 's6': 0, 's7': 100, 's8': 0, 'surfactant_conc': 1, 'drug_conc': 100})),
#  19: Trial(experiment_name='drug_surfactant', index=19, status=TrialStatus.RUNNING, arm=Arm(name='19_0', parameters={'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 0, 's2': 0, 's3': 100, 's4': 0, 's5': 0, 's6': 0, 's7': 100, 's8': 100, 'surfactant_conc': 100, 'drug_conc': 1})),
#  20: Trial(experiment_name='drug_surfactant', index=20, status=TrialStatus.RUNNING, arm=Arm(name='20_0', parameters={'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 56, 's2': 0, 's3': 100, 's4': 0, 's5': 0, 's6': 64, 's7': 100, 's8': 0, 'surfactant_conc': 35, 'drug_conc': 100})),
#  21: Trial(experiment_name='drug_surfactant', index=21, status=TrialStatus.RUNNING, arm=Arm(name='21_0', parameters={'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 0, 's2': 0, 's3': 0, 's4': 1, 's5': 100, 's6': 46, 's7': 100, 's8': 0, 'surfactant_conc': 71, 'drug_conc': 1})),
#  22: Trial(experiment_name='drug_surfactant', index=22, status=TrialStatus.RUNNING, arm=Arm(name='22_0', parameters={'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 7, 's2': 0, 's3': 100, 's4': 0, 's5': 100, 's6': 100, 's7': 100, 's8': 100, 'surfactant_conc': 70, 'drug_conc': 100})),
#  23: Trial(experiment_name='drug_surfactant', index=23, status=TrialStatus.RUNNING, arm=Arm(name='23_0', parameters={'Drug_MW': 0.206, 'Drug_LogP': 0.307, 'Drug_TPSA': 0.037, 's1': 0, 's2': 0, 's3': 100, 's4': 1, 's5': 0, 's6': 0, 's7': 64, 's8': 0, 'surfactant_conc': 83, 'drug_conc': 1}))}

# %%
df_conc, df_vol = hf.design_to_conc_to_vol (n)

# %%
plate_well = input("Enter the plate well starting well (e.g., F1): ")
deepplate_well = input("Enter the deep plate well starting well (e.g., F1): ")


print("Please confirm the following information:")
print("Wellplate will start at: " + plate_well)
print("Deep plate will start at: " + deepplate_well)

print()
print("*******************************************************")
print("Continue if correct, or rerun this cell if incorrect.")
print("*******************************************************")
# Out:
# Please confirm the following information:
# Wellplate will start at: E1
# Deep plate will start at: G1
#
# *******************************************************
# Continue if correct, or rerun this cell if incorrect.
# *******************************************************

# %%
hf.generate_protocol(df_vol=df_vol, iteration=n, plate_well=plate_well, deepplate_well=deepplate_well)
# Out:
# ✅ Successfully wrote to: protocol/otflex_3.py

# %%
df_absorbance = hf.process_absorbance(iteration=n, threshold=0.1)
df_absorbance
# Out:
#    trial_index  success
# 0            0        0
# 1            1        1
# 2            2        1
# 3            3        1
# 4            4        1
# 5            5        1

# %%
results = hf.build_results(n, df_conc, df_absorbance)
results
# Out:
#    trial_index  s1  s2   s3  s4   s5   s6   s7   s8  surfactant_conc  \
# 0           18   0   0  100  79    0    0  100    0              0.5
# 1           19   0   0  100   0    0    0  100  100             50.0
# 2           20  56   0  100   0    0   64  100    0             17.5
# 3           21   0   0    0   1  100   46  100    0             35.5
# 4           22   7   0  100   0  100  100  100  100             35.0
# 5           23   0   0  100   1    0    0   64    0             41.5
#
#    drug_conc  initial_drug_conc_surfactant_conc_ratio  success  \
# 0      25.00                                50.000000        0
# 1       0.25                                 0.005000        1
# 2      25.00                                 1.428571        1
# 3       0.25                                 0.007042        1
# 4      25.00                                 0.714286        1
# 5       0.25                                 0.006024        1
#
#    micelle_drug_conc  complexity
# 0              0.000           3
# 1              0.025           3
# 2              2.500           4
# 3              0.025           4
# 4              2.500           6
# 5              0.025           3

# %%
norm_results = hf.normalize_data(results, 'normalize')

# %%
norm_results
# Out:
#    trial_index  s1  s2   s3  s4   s5   s6   s7   s8  surfactant_conc  \
# 0           18   0   0  100  79    0    0  100    0              0.5
# 1           19   0   0  100   0    0    0  100  100             50.0
# 2           20  56   0  100   0    0   64  100    0             17.5
# 3           21   0   0    0   1  100   46  100    0             35.5
# 4           22   7   0  100   0  100  100  100  100             35.0
# 5           23   0   0  100   1    0    0   64    0             41.5
#
#    drug_conc  initial_drug_conc_surfactant_conc_ratio  success  \
# 0      25.00                                 0.500000      0.0
# 1       0.25                                 0.000050      1.0
# 2      25.00                                 0.014286      1.0
# 3       0.25                                 0.000070      1.0
# 4      25.00                                 0.007143      1.0
# 5       0.25                                 0.000060      1.0
#
#    micelle_drug_conc  complexity
# 0               0.00       0.375
# 1               0.01       0.375
# 2               1.00       0.500
# 3               0.01       0.500
# 4               1.00       0.750
# 5               0.01       0.375

# %% [markdown]
# # load the results to the optimizer

# %%
ax_client = hf.load_data_to_optimizer(iteration = n, norm_results = norm_results)
ax_client
# Out:
# [INFO 06-23 15:03:14] ax.service.ax_client: Starting optimization with verbose logging. To disable logging, set the `verbose_logging` argument to `False`. Note that float values in the logs are rounded to 6 decimal points.
# [INFO 06-23 15:03:14] ax.service.ax_client: Completed trial 18 with data: {'micelle_drug_conc': (0.0, None), 'success': (0.0, None), 'initial_drug_conc_surfactant_conc_ratio': (0.5, None), 'complexity': (0.375, None)}.
# [INFO 06-23 15:03:14] ax.service.ax_client: Completed trial 19 with data: {'micelle_drug_conc': (0.01, None), 'success': (1.0, None), 'initial_drug_conc_surfactant_conc_ratio': (5e-05, None), 'complexity': (0.375, None)}.
# [INFO 06-23 15:03:14] ax.service.ax_client: Completed trial 20 with data: {'micelle_drug_conc': (1.0, None), 'success': (1.0, None), 'initial_drug_conc_surfactant_conc_ratio': (0.014286, None), 'complexity': (0.5, None)}.
# [INFO 06-23 15:03:14] ax.service.ax_client: Completed trial 21 with data: {'micelle_drug_conc': (0.01, None), 'success': (1.0, None), 'initial_drug_conc_surfactant_conc_ratio': (7e-05, None), 'complexity': (0.5, None)}.
# [INFO 06-23 15:03:14] ax.service.ax_client: Completed trial 22 with data: {'micelle_drug_conc': (1.0, None), 'success': (1.0, None), 'initial_drug_conc_surfactant_conc_ratio': (0.007143, None), 'complexity': (0.75, None)}.
# [INFO 06-23 15:03:14] ax.service.ax_client: Completed trial 23 with data: {'micelle_drug_conc': (0.01, None), 'success': (1.0, None), 'initial_drug_conc_surfactant_conc_ratio': (6e-05, None), 'complexity': (0.375, None)}.
# [INFO 06-23 15:03:14] ax.service.ax_client: Saved JSON-serialized state of optimization to `optimizer/optimizer_3_loaded.json`.
# AxClient(experiment=Experiment(drug_surfactant))
