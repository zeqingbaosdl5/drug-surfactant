# %% [markdown]
# # import libraries

# %%
import pandas as pd
from ax.service.ax_client import AxClient, ObjectiveProperties
import matplotlib.pyplot as plt
from ax.modelbridge.registry import Generators
from ax.modelbridge.generation_strategy import GenerationStep, GenerationStrategy   
import time


import sys
sys.path.append('../')
import helper_functions as hf

# %% [markdown]
# # generate recommendations

# %%
n = hf.get_iteration_number()

for i in range(3):
    print("Very Important: Please Confirm the Iteration Number is Iteration " + str(n))

print()

list_of_drugs = ['IBP'] * 2 + ['LOV'] * 2 + ['DCF'] * 2 + ['GLV'] * 2

for i in range(3):
    print("Very Important: Please Confirm the Drugs are: ", list_of_drugs)
# Out:
# Very Important: Please Confirm the Iteration Number is Iteration 1
# Very Important: Please Confirm the Iteration Number is Iteration 1
# Very Important: Please Confirm the Iteration Number is Iteration 1
#
# Very Important: Please Confirm the Drugs are:  ['IBP', 'IBP', 'LOV', 'LOV', 'DCF', 'DCF', 'GLV', 'GLV']
# Very Important: Please Confirm the Drugs are:  ['IBP', 'IBP', 'LOV', 'LOV', 'DCF', 'DCF', 'GLV', 'GLV']
# Very Important: Please Confirm the Drugs are:  ['IBP', 'IBP', 'LOV', 'LOV', 'DCF', 'DCF', 'GLV', 'GLV']

# %%
time_start = time.time()


df_design, ax_client = hf.run_optimizer(current_iteration=n, drug_list= list_of_drugs,  bopt = 3)

time_end = time.time()
time_duration = round((time_end - time_start)/60,2)

print("Time taken for optimization: " + str(time_duration) + " mins")
print("Time taken for optimization: " + str(time_duration * 60) + " seconds")
# Out:
# **************************************************************************************************** 1  out of  8 ****************************************************************************************************
# ********************************************************************************************************************************************************************************************************
#
# Drug name:  Ibuprofen IBP  | Iteration:  1
#
# ********************************************************************************************************************************************************************************************************
# ********************************************************************************************************************************************************************************************************
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       1 time_start = time.time()
# ----> 4 df_design, ax_client = hf.run_optimizer(current_iteration=n, drug_list= list_of_drugs,  bopt = 3)
#       6 time_end = time.time()
#       7 time_duration = round((time_end - time_start)/60,2)
#
# File ~/0_Github/drug_surfactant/experiments/20250717_dont_use_for_BO_test/iteration_1/../helper_functions.py:364, in run_optimizer(current_iteration, drug_list, bopt, n_trials)
#     361 print("*" * 200)
#     362 print("*" * 200)
# --> 364 trials, _ = ax_client.get_next_trials(n_trials, fixed_features=drug_features)
#     366 # Prepare the trial data for DataFrame
#     368 for trial_index, parameters in trials.items():
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/service/ax_client.py:658, in AxClient.get_next_trials(self, max_trials, ttl_seconds, fixed_features)
#     656 for _ in range(max_trials):
#     657     try:
# --> 658         params, trial_index = self.get_next_trial(
#     659             ttl_seconds=ttl_seconds, fixed_features=fixed_features
#     660         )
#     661         trials_dict[trial_index] = params
#     662     except OptimizationComplete as err:
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/utils/common/executils.py:169, in retry_on_exception.<locals>.func_wrapper.<locals>.actual_wrapper(*args, **kwargs)
#     165             wait_interval = min(
#     166                 MAX_WAIT_SECONDS, initial_wait_seconds * 2 ** (i - 1)
#     167             )
#     168             time.sleep(wait_interval)
# --> 169         return func(*args, **kwargs)
#     171 # If we are here, it means the retries were finished but
#     172 # The error was suppressed. Hence return the default value provided.
#     173 return default_return_on_suppression
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/service/ax_client.py:563, in AxClient.get_next_trial(self, ttl_seconds, force, fixed_features)
#     559         raise OptimizationShouldStop(message=global_stopping_message)
#     561 try:
#     562     trial = self.experiment.new_trial(
# --> 563         generator_run=self._gen_new_generator_run(
#     564             fixed_features=fixed_features
#     565         ),
#     566         ttl_seconds=ttl_seconds,
#     567     )
#     568 except MaxParallelismReachedException as e:
#     569     if self._early_stopping_strategy is not None:
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/service/ax_client.py:1731, in AxClient._gen_new_generator_run(self, n, fixed_features)
#    1723 fixed_feats = (
#    1724     InstantiationBase.make_fixed_observation_features(
#    1725         fixed_features=fixed_features
#    (...)   1728     else None
#    1729 )
#    1730 with with_rng_seed(seed=self._random_seed):
# -> 1731     return none_throws(self.generation_strategy).gen(
#    1732         experiment=self.experiment,
#    1733         n=n,
#    1734         pending_observations=self._get_pending_observation_features(
#    1735             experiment=self.experiment
#    1736         ),
#    1737         fixed_features=fixed_feats,
#    1738     )
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/generation_strategy/generation_strategy.py:343, in GenerationStrategy.gen(self, experiment, data, pending_observations, n, fixed_features)
#     314 """Produce the next points in the experiment. Additional kwargs passed to
#     315 this method are propagated directly to the underlying model's `gen`, along
#     316 with the `model_gen_kwargs` set on the current generation node.
#    (...)    339         resuggesting points that are currently being evaluated.
#     340 """
#     341 self.experiment = experiment
# --> 343 gr = self._gen_with_multiple_nodes(
#     344     experiment=experiment,
#     345     data=data,
#     346     n=n,
#     347     pending_observations=pending_observations,
#     348     fixed_features=fixed_features,
#     349 )
#     350 if len(gr) > 1:
#     351     raise UnsupportedError(
#     352         "By calling into GenerationStrategy.gen(), you are should be "
#     353         "expecting a single `Trial` with only one `GeneratorRun`. However, "
#     354         "the underlying GenerationStrategy produced multiple `GeneratorRuns` "
#     355         f"and returned the following list of `GeneratorRun`-s: {gr}"
#     356     )
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/generation_strategy/generation_strategy.py:778, in GenerationStrategy._gen_with_multiple_nodes(self, experiment, n, pending_observations, data, fixed_features, arms_per_node, first_generation_in_multi)
#     776 transitioned = self._maybe_transition_to_next_node()
#     777 try:
# --> 778     gr = self._curr.gen(
#     779         experiment=experiment,
#     780         data=data,
#     781         pending_observations=pending_observations,
#     782         skip_fit=not (first_generation_in_multi or transitioned),
#     783         **pack_gs_gen_kwargs,
#     784     )
#     785     # TODO[@drfreund]: Do we need this or can we just not keep `GS._model`?
#     786     self._model = self._curr._fitted_model
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/generation_strategy/generation_node.py:1178, in GenerationStep.gen(self, experiment, n, pending_observations, skip_fit, data, **gs_gen_kwargs)
#    1168 def gen(
#    1169     self,
#    1170     *,
#    (...)   1176     **gs_gen_kwargs: Any,
#    1177 ) -> GeneratorRun | None:
# -> 1178     gr = super().gen(
#    1179         experiment=experiment,
#    1180         n=n,
#    1181         pending_observations=pending_observations,
#    1182         data=data,
#    1183         skip_fit=skip_fit,
#    1184         **gs_gen_kwargs,
#    1185     )
#    1186     if gr is None:
#    1187         raise AxError(
#    1188             "This `GenerationStep`'s underlying `GenerationNode` returned "
#    1189             "`None` from `gen`. This is an unexpected state for a "
#    1190             "`GenerationStep`-based generation strategy."
#    1191         )
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/generation_strategy/generation_node.py:445, in GenerationNode.gen(self, experiment, pending_observations, skip_fit, data, **gs_gen_kwargs)
#     438     gr = self._gen_maybe_deduplicate(
#     439         experiment=experiment,
#     440         data=data,
#     441         pending_observations=pending_observations,
#     442         **model_gen_kwargs,
#     443     )
#     444 except Exception as e:
# --> 445     gr = self._try_gen_with_fallback(
#     446         exception=e,
#     447         experiment=experiment,
#     448         data=data,
#     449         pending_observations=pending_observations,
#     450         **model_gen_kwargs,
#     451     )
#     453 gr._generation_node_name = self.node_name
#     454 # TODO: @mgarrard determine a more refined way to indicate trial type
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/generation_strategy/generation_node.py:566, in GenerationNode._try_gen_with_fallback(self, exception, experiment, n, data, pending_observations, **model_gen_kwargs)
#     564 error_type = type(exception)
#     565 if error_type not in self.fallback_specs:
# --> 566     raise exception
#     568 # identify fallback model to use
#     569 fallback_model = self.fallback_specs[error_type]
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/generation_strategy/generation_node.py:438, in GenerationNode.gen(self, experiment, pending_observations, skip_fit, data, **gs_gen_kwargs)
#     432 model_gen_kwargs.update(input_constructor_values)
#     433 try:
#     434     # Generate from the main generator on this node. If deduplicating,
#     435     # keep generating until each of `generator_run.arms` is not a
#     436     # duplicate of a previous active arm (e.g. not from a failed trial)
#     437     # on the experiment.
# --> 438     gr = self._gen_maybe_deduplicate(
#     439         experiment=experiment,
#     440         data=data,
#     441         pending_observations=pending_observations,
#     442         **model_gen_kwargs,
#     443     )
#     444 except Exception as e:
#     445     gr = self._try_gen_with_fallback(
#     446         exception=e,
#     447         experiment=experiment,
#    (...)    450         **model_gen_kwargs,
#     451     )
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/generation_strategy/generation_node.py:530, in GenerationNode._gen_maybe_deduplicate(self, experiment, n, pending_observations, data, **model_gen_kwargs)
#     528 while n_gen_draws < MAX_GEN_ATTEMPTS:
#     529     n_gen_draws += 1
# --> 530     gr = self._gen(
#     531         experiment=experiment,
#     532         data=data,
#     533         n=n,
#     534         pending_observations=pending_observations,
#     535         **model_gen_kwargs,
#     536     )
#     537     if not self.should_deduplicate or not dedup_against_arms:
#     538         return gr  # Not deduplicationg.
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/generation_strategy/generation_node.py:498, in GenerationNode._gen(self, experiment, n, pending_observations, data, **model_gen_kwargs)
#     494 if n is None and model_spec.model_gen_kwargs:
#     495     # If `n` is not specified, ensure that the `None` value does not
#     496     # override the one set in `model_spec.model_gen_kwargs`.
#     497     n = model_spec.model_gen_kwargs.get("n", None)
# --> 498 return model_spec.gen(
#     499     experiment=experiment,
#     500     data=data,
#     501     n=n,
#     502     # For `pending_observations`, prefer the input to this function, as
#     503     # `pending_observations` are dynamic throughout the experiment and thus
#     504     # unlikely to be specified in `model_spec.model_gen_kwargs`.
#     505     pending_observations=pending_observations,
#     506     **model_gen_kwargs,
#     507 )
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/generation_strategy/model_spec.py:238, in GeneratorSpec.gen(self, **model_gen_kwargs)
#     236 # copy to ensure there is no in-place modification
#     237 model_gen_kwargs = deepcopy(model_gen_kwargs)
# --> 238 generator_run = fitted_model.gen(**model_gen_kwargs)
#     239 fit_and_std_quality_and_generalization_dict = (
#     240     get_fit_and_std_quality_and_generalization_dict(
#     241         fitted_adapter=self.fitted_model,
#     242     )
#     243 )
#     244 generator_run._gen_metadata = (
#     245     {} if generator_run.gen_metadata is None else generator_run.gen_metadata
#     246 )
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/modelbridge/base.py:808, in Adapter.gen(self, n, search_space, optimization_config, pending_observations, fixed_features, model_gen_options)
#     801 base_gen_args = self._get_transformed_gen_args(
#     802     search_space=search_space,
#     803     optimization_config=optimization_config,
#     804     pending_observations=pending_observations,
#     805     fixed_features=fixed_features,
#     806 )
#     807 # Apply terminal transform and gen
# --> 808 gen_results = self._gen(
#     809     n=n,
#     810     search_space=base_gen_args.search_space,
#     811     optimization_config=base_gen_args.optimization_config,
#     812     pending_observations=base_gen_args.pending_observations,
#     813     fixed_features=base_gen_args.fixed_features,
#     814     model_gen_options=model_gen_options,
#     815 )
#     817 observation_features = gen_results.observation_features
#     818 best_obsf = gen_results.best_observation_features
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/modelbridge/discrete.py:189, in DiscreteAdapter._gen(self, n, search_space, pending_observations, fixed_features, model_gen_options, optimization_config)
#     183     outcome_constraints = extract_outcome_constraints(
#     184         outcome_constraints=optimization_config.outcome_constraints,
#     185         outcomes=self.outcomes,
#     186     )
#     188 # Get fixed features
# --> 189 fixed_features_dict = get_fixed_features(
#     190     fixed_features=fixed_features, param_names=self.parameters
#     191 )
#     193 # Pending observations
#     194 if len(pending_observations) == 0:
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/modelbridge/modelbridge_utils.py:540, in get_fixed_features(fixed_features, param_names)
#     535 if params_set > param_names_set:
#     536     raise ValueError(
#     537         "Fixed features contains parameters not in "
#     538         f"`param_names`: {params_set - param_names_set}."
#     539     )
# --> 540 fixed_features_dict = {
#     541     i: float(assert_is_instance(params[p_name], SupportsFloat))
#     542     for i, p_name in enumerate(param_names)
#     543     if p_name in params
#     544 }
#     545 return fixed_features_dict
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/modelbridge/modelbridge_utils.py:541, in <dictcomp>(.0)
#     535 if params_set > param_names_set:
#     536     raise ValueError(
#     537         "Fixed features contains parameters not in "
#     538         f"`param_names`: {params_set - param_names_set}."
#     539     )
#     540 fixed_features_dict = {
# --> 541     i: float(assert_is_instance(params[p_name], SupportsFloat))
#     542     for i, p_name in enumerate(param_names)
#     543     if p_name in params
#     544 }
#     545 return fixed_features_dict
#
# File ~/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/pyre_extensions/refinement.py:28, in assert_is_instance(obj, cls)
#      25 """Assert that the given object is an instance of the given class. Raises a
#      26 `TypeError` if not."""
#      27 if not isinstance(obj, cls):
# ---> 28     raise TypeError(f"obj is not an instance of cls: obj={obj} cls={cls}")
#      29 return obj
#
# TypeError: obj is not an instance of cls: obj=9bbca800b7809a6c887bcbfb1b13a400 cls=<class 'typing.SupportsFloat'>

# %%
all_gens = list(Generators)

for gen in all_gens:
    print(gen)
# Out:
# Generators.SOBOL
# Generators.FACTORIAL
# Generators.SAASBO
# Generators.SAAS_MTGP
# Generators.THOMPSON
# Generators.LEGACY_BOTORCH
# Generators.BOTORCH_MODULAR
# Generators.EMPIRICAL_BAYES_THOMPSON
# Generators.EB_ASHR
# Generators.UNIFORM
# Generators.ST_MTGP
# Generators.BO_MIXED
# Generators.CONTEXT_SACBO

# %% [markdown]
# # process results

# %%
ax_client = hf.load_design_optimizer(n)
ax_client.experiment.trials
# Out:
# {0: Trial(experiment_name='drug_surfactant', index=0, status=TrialStatus.COMPLETED, arm=Arm(name='0_0', parameters={'Drug_MW': 0.2063, 'Drug_LogP': 0.3073, 'Drug_TPSA': 0.0373, 'surf_1': 's8', 'surf_1_conc': 12, 'surf_2': 's6', 'surf_2_conc': 39, 'surf_3': 's7', 'surf_3_conc': 20, 'drug_conc': 25.0})),
#  1: Trial(experiment_name='drug_surfactant', index=1, status=TrialStatus.COMPLETED, arm=Arm(name='1_0', parameters={'Drug_MW': 0.2063, 'Drug_LogP': 0.3073, 'Drug_TPSA': 0.0373, 'surf_1': 's3', 'surf_1_conc': 51, 'surf_2': 's2', 'surf_2_conc': 4, 'surf_3': 's6', 'surf_3_conc': 40, 'drug_conc': 25.0})),
#  2: Trial(experiment_name='drug_surfactant', index=2, status=TrialStatus.COMPLETED, arm=Arm(name='2_0', parameters={'Drug_MW': 0.4045, 'Drug_LogP': 0.4196, 'Drug_TPSA': 0.0728, 'surf_1': 's5', 'surf_1_conc': 1, 'surf_2': 's7', 'surf_2_conc': 56, 'surf_3': 's3', 'surf_3_conc': 0, 'drug_conc': 25.0})),
#  3: Trial(experiment_name='drug_surfactant', index=3, status=TrialStatus.COMPLETED, arm=Arm(name='3_0', parameters={'Drug_MW': 0.4045, 'Drug_LogP': 0.4196, 'Drug_TPSA': 0.0728, 'surf_1': 's3', 'surf_1_conc': 28, 'surf_2': 's3', 'surf_2_conc': 6, 'surf_3': 's8', 'surf_3_conc': 14, 'drug_conc': 25.0})),
#  4: Trial(experiment_name='drug_surfactant', index=4, status=TrialStatus.COMPLETED, arm=Arm(name='4_0', parameters={'Drug_MW': 0.2962, 'Drug_LogP': 0.4364, 'Drug_TPSA': 0.0493, 'surf_1': 's1', 'surf_1_conc': 27, 'surf_2': 's4', 'surf_2_conc': 63, 'surf_3': 's5', 'surf_3_conc': 3, 'drug_conc': 25.0})),
#  5: Trial(experiment_name='drug_surfactant', index=5, status=TrialStatus.COMPLETED, arm=Arm(name='5_0', parameters={'Drug_MW': 0.2962, 'Drug_LogP': 0.4364, 'Drug_TPSA': 0.0493, 'surf_1': 's6', 'surf_1_conc': 40, 'surf_2': 's8', 'surf_2_conc': 29, 'surf_3': 's7', 'surf_3_conc': 22, 'drug_conc': 25.0})),
#  6: Trial(experiment_name='drug_surfactant', index=6, status=TrialStatus.COMPLETED, arm=Arm(name='6_0', parameters={'Drug_MW': 0.3528, 'Drug_LogP': 0.281, 'Drug_TPSA': 0.0711, 'surf_1': 's1', 'surf_1_conc': 5, 'surf_2': 's1', 'surf_2_conc': 24, 'surf_3': 's6', 'surf_3_conc': 18, 'drug_conc': 25.0})),
#  7: Trial(experiment_name='drug_surfactant', index=7, status=TrialStatus.COMPLETED, arm=Arm(name='7_0', parameters={'Drug_MW': 0.3528, 'Drug_LogP': 0.281, 'Drug_TPSA': 0.0711, 'surf_1': 's6', 'surf_1_conc': 10, 'surf_2': 's5', 'surf_2_conc': 1, 'surf_3': 's1', 'surf_3_conc': 36, 'drug_conc': 25.0})),
#  8: Trial(experiment_name='drug_surfactant', index=8, status=TrialStatus.COMPLETED, arm=Arm(name='8_0', parameters={'Drug_MW': 0.2063, 'Drug_LogP': 0.3073, 'Drug_TPSA': 0.0373, 'surf_1': 's4', 'surf_1_conc': 4, 'surf_2': 's4', 'surf_2_conc': 15, 'surf_3': 's1', 'surf_3_conc': 50, 'drug_conc': 25.0})),
#  9: Trial(experiment_name='drug_surfactant', index=9, status=TrialStatus.COMPLETED, arm=Arm(name='9_0', parameters={'Drug_MW': 0.2063, 'Drug_LogP': 0.3073, 'Drug_TPSA': 0.0373, 'surf_1': 's3', 'surf_1_conc': 37, 'surf_2': 's4', 'surf_2_conc': 17, 'surf_3': 's5', 'surf_3_conc': 32, 'drug_conc': 25.0})),
#  10: Trial(experiment_name='drug_surfactant', index=10, status=TrialStatus.COMPLETED, arm=Arm(name='10_0', parameters={'Drug_MW': 0.4045, 'Drug_LogP': 0.4196, 'Drug_TPSA': 0.0728, 'surf_1': 's1', 'surf_1_conc': 30, 'surf_2': 's5', 'surf_2_conc': 3, 'surf_3': 's5', 'surf_3_conc': 54, 'drug_conc': 25.0})),
#  11: Trial(experiment_name='drug_surfactant', index=11, status=TrialStatus.COMPLETED, arm=Arm(name='11_0', parameters={'Drug_MW': 0.4045, 'Drug_LogP': 0.4196, 'Drug_TPSA': 0.0728, 'surf_1': 's4', 'surf_1_conc': 22, 'surf_2': 's7', 'surf_2_conc': 37, 'surf_3': 's3', 'surf_3_conc': 27, 'drug_conc': 25.0})),
#  12: Trial(experiment_name='drug_surfactant', index=12, status=TrialStatus.COMPLETED, arm=Arm(name='12_0', parameters={'Drug_MW': 0.2962, 'Drug_LogP': 0.4364, 'Drug_TPSA': 0.0493, 'surf_1': 's4', 'surf_1_conc': 59, 'surf_2': 's1', 'surf_2_conc': 21, 'surf_3': 's8', 'surf_3_conc': 6, 'drug_conc': 25.0})),
#  13: Trial(experiment_name='drug_surfactant', index=13, status=TrialStatus.COMPLETED, arm=Arm(name='13_0', parameters={'Drug_MW': 0.2962, 'Drug_LogP': 0.4364, 'Drug_TPSA': 0.0493, 'surf_1': 's2', 'surf_1_conc': 10, 'surf_2': 's8', 'surf_2_conc': 78, 'surf_3': 's3', 'surf_3_conc': 9, 'drug_conc': 25.0})),
#  14: Trial(experiment_name='drug_surfactant', index=14, status=TrialStatus.COMPLETED, arm=Arm(name='14_0', parameters={'Drug_MW': 0.3528, 'Drug_LogP': 0.281, 'Drug_TPSA': 0.0711, 'surf_1': 's5', 'surf_1_conc': 22, 'surf_2': 's7', 'surf_2_conc': 17, 'surf_3': 's3', 'surf_3_conc': 16, 'drug_conc': 25.0})),
#  15: Trial(experiment_name='drug_surfactant', index=15, status=TrialStatus.COMPLETED, arm=Arm(name='15_0', parameters={'Drug_MW': 0.3528, 'Drug_LogP': 0.281, 'Drug_TPSA': 0.0711, 'surf_1': 's5', 'surf_1_conc': 31, 'surf_2': 's4', 'surf_2_conc': 35, 'surf_3': 's1', 'surf_3_conc': 24, 'drug_conc': 25.0})),
#  16: Trial(experiment_name='drug_surfactant', index=16, status=TrialStatus.COMPLETED, arm=Arm(name='16_0', parameters={'Drug_MW': 0.2063, 'Drug_LogP': 0.3073, 'Drug_TPSA': 0.0373, 'surf_1': 's6', 'surf_1_conc': 50, 'surf_2': 's1', 'surf_2_conc': 0, 'surf_3': 's6', 'surf_3_conc': 13, 'drug_conc': 25.0})),
#  17: Trial(experiment_name='drug_surfactant', index=17, status=TrialStatus.COMPLETED, arm=Arm(name='17_0', parameters={'Drug_MW': 0.2063, 'Drug_LogP': 0.3073, 'Drug_TPSA': 0.0373, 'surf_1': 's8', 'surf_1_conc': 8, 'surf_2': 's6', 'surf_2_conc': 46, 'surf_3': 's4', 'surf_3_conc': 20, 'drug_conc': 25.0})),
#  18: Trial(experiment_name='drug_surfactant', index=18, status=TrialStatus.COMPLETED, arm=Arm(name='18_0', parameters={'Drug_MW': 0.4045, 'Drug_LogP': 0.4196, 'Drug_TPSA': 0.0728, 'surf_1': 's6', 'surf_1_conc': 20, 'surf_2': 's8', 'surf_2_conc': 62, 'surf_3': 's3', 'surf_3_conc': 1, 'drug_conc': 25.0})),
#  19: Trial(experiment_name='drug_surfactant', index=19, status=TrialStatus.COMPLETED, arm=Arm(name='19_0', parameters={'Drug_MW': 0.4045, 'Drug_LogP': 0.4196, 'Drug_TPSA': 0.0728, 'surf_1': 's6', 'surf_1_conc': 0, 'surf_2': 's7', 'surf_2_conc': 30, 'surf_3': 's2', 'surf_3_conc': 25, 'drug_conc': 25.0})),
#  20: Trial(experiment_name='drug_surfactant', index=20, status=TrialStatus.COMPLETED, arm=Arm(name='20_0', parameters={'Drug_MW': 0.2962, 'Drug_LogP': 0.4364, 'Drug_TPSA': 0.0493, 'surf_1': 's4', 'surf_1_conc': 63, 'surf_2': 's4', 'surf_2_conc': 14, 'surf_3': 's1', 'surf_3_conc': 9, 'drug_conc': 25.0})),
#  21: Trial(experiment_name='drug_surfactant', index=21, status=TrialStatus.COMPLETED, arm=Arm(name='21_0', parameters={'Drug_MW': 0.2962, 'Drug_LogP': 0.4364, 'Drug_TPSA': 0.0493, 'surf_1': 's3', 'surf_1_conc': 41, 'surf_2': 's7', 'surf_2_conc': 22, 'surf_3': 's7', 'surf_3_conc': 34, 'drug_conc': 25.0})),
#  22: Trial(experiment_name='drug_surfactant', index=22, status=TrialStatus.COMPLETED, arm=Arm(name='22_0', parameters={'Drug_MW': 0.3528, 'Drug_LogP': 0.281, 'Drug_TPSA': 0.0711, 'surf_1': 's5', 'surf_1_conc': 28, 'surf_2': 's6', 'surf_2_conc': 39, 'surf_3': 's1', 'surf_3_conc': 29, 'drug_conc': 25.0})),
#  23: Trial(experiment_name='drug_surfactant', index=23, status=TrialStatus.COMPLETED, arm=Arm(name='23_0', parameters={'Drug_MW': 0.3528, 'Drug_LogP': 0.281, 'Drug_TPSA': 0.0711, 'surf_1': 's4', 'surf_1_conc': 23, 'surf_2': 's4', 'surf_2_conc': 20, 'surf_3': 's5', 'surf_3_conc': 53, 'drug_conc': 25.0})),
#  24: Trial(experiment_name='drug_surfactant', index=24, status=TrialStatus.COMPLETED, arm=Arm(name='24_0', parameters={'Drug_MW': 0.2063, 'Drug_LogP': 0.3073, 'Drug_TPSA': 0.0373, 'surf_1': 's5', 'surf_1_conc': 18, 'surf_2': 's1', 'surf_2_conc': 9, 'surf_3': 's1', 'surf_3_conc': 36, 'drug_conc': 25.0})),
#  25: Trial(experiment_name='drug_surfactant', index=25, status=TrialStatus.COMPLETED, arm=Arm(name='25_0', parameters={'Drug_MW': 0.2063, 'Drug_LogP': 0.3073, 'Drug_TPSA': 0.0373, 'surf_1': 's1', 'surf_1_conc': 24, 'surf_2': 's6', 'surf_2_conc': 12, 'surf_3': 's8', 'surf_3_conc': 13, 'drug_conc': 25.0})),
#  26: Trial(experiment_name='drug_surfactant', index=26, status=TrialStatus.COMPLETED, arm=Arm(name='26_0', parameters={'Drug_MW': 0.4045, 'Drug_LogP': 0.4196, 'Drug_TPSA': 0.0728, 'surf_1': 's7', 'surf_1_conc': 33, 'surf_2': 's2', 'surf_2_conc': 41, 'surf_3': 's3', 'surf_3_conc': 21, 'drug_conc': 25.0})),
#  27: Trial(experiment_name='drug_surfactant', index=27, status=TrialStatus.COMPLETED, arm=Arm(name='27_0', parameters={'Drug_MW': 0.4045, 'Drug_LogP': 0.4196, 'Drug_TPSA': 0.0728, 'surf_1': 's1', 'surf_1_conc': 47, 'surf_2': 's8', 'surf_2_conc': 51, 'surf_3': 's6', 'surf_3_conc': 1, 'drug_conc': 25.0})),
#  28: Trial(experiment_name='drug_surfactant', index=28, status=TrialStatus.COMPLETED, arm=Arm(name='28_0', parameters={'Drug_MW': 0.2962, 'Drug_LogP': 0.4364, 'Drug_TPSA': 0.0493, 'surf_1': 's4', 'surf_1_conc': 48, 'surf_2': 's2', 'surf_2_conc': 19, 'surf_3': 's2', 'surf_3_conc': 15, 'drug_conc': 25.0})),
#  29: Trial(experiment_name='drug_surfactant', index=29, status=TrialStatus.COMPLETED, arm=Arm(name='29_0', parameters={'Drug_MW': 0.2962, 'Drug_LogP': 0.4364, 'Drug_TPSA': 0.0493, 'surf_1': 's2', 'surf_1_conc': 19, 'surf_2': 's6', 'surf_2_conc': 68, 'surf_3': 's5', 'surf_3_conc': 5, 'drug_conc': 25.0})),
#  30: Trial(experiment_name='drug_surfactant', index=30, status=TrialStatus.COMPLETED, arm=Arm(name='30_0', parameters={'Drug_MW': 0.3528, 'Drug_LogP': 0.281, 'Drug_TPSA': 0.0711, 'surf_1': 's1', 'surf_1_conc': 7, 'surf_2': 's2', 'surf_2_conc': 27, 'surf_3': 's1', 'surf_3_conc': 25, 'drug_conc': 25.0})),
#  31: Trial(experiment_name='drug_surfactant', index=31, status=TrialStatus.COMPLETED, arm=Arm(name='31_0', parameters={'Drug_MW': 0.3528, 'Drug_LogP': 0.281, 'Drug_TPSA': 0.0711, 'surf_1': 's7', 'surf_1_conc': 65, 'surf_2': 's4', 'surf_2_conc': 9, 'surf_3': 's4', 'surf_3_conc': 11, 'drug_conc': 25.0})),
#  32: Trial(experiment_name='drug_surfactant', index=32, status=TrialStatus.RUNNING, arm=Arm(name='32_0', parameters={'Drug_MW': 0.2063, 'Drug_LogP': 0.3073, 'Drug_TPSA': 0.0373, 'surf_1_conc': 24, 'surf_2_conc': 8, 'surf_3_conc': 19, 'drug_conc': 25.0, 'surf_1': 's1', 'surf_2': 's6', 'surf_3': 's8'})),
#  33: Trial(experiment_name='drug_surfactant', index=33, status=TrialStatus.RUNNING, arm=Arm(name='33_0', parameters={'Drug_MW': 0.2063, 'Drug_LogP': 0.3073, 'Drug_TPSA': 0.0373, 'surf_1_conc': 24, 'surf_2_conc': 3, 'surf_3_conc': 19, 'drug_conc': 25.0, 'surf_1': 's1', 'surf_2': 's6', 'surf_3': 's8'})),
#  34: Trial(experiment_name='drug_surfactant', index=34, status=TrialStatus.RUNNING, arm=Arm(name='34_0', parameters={'Drug_MW': 0.4045, 'Drug_LogP': 0.4196, 'Drug_TPSA': 0.0728, 'surf_1_conc': 24, 'surf_2_conc': 15, 'surf_3_conc': 11, 'drug_conc': 25.0, 'surf_1': 's1', 'surf_2': 's6', 'surf_3': 's8'})),
#  35: Trial(experiment_name='drug_surfactant', index=35, status=TrialStatus.RUNNING, arm=Arm(name='35_0', parameters={'Drug_MW': 0.4045, 'Drug_LogP': 0.4196, 'Drug_TPSA': 0.0728, 'surf_1_conc': 24, 'surf_2_conc': 11, 'surf_3_conc': 20, 'drug_conc': 25.0, 'surf_1': 's1', 'surf_2': 's6', 'surf_3': 's8'})),
#  36: Trial(experiment_name='drug_surfactant', index=36, status=TrialStatus.RUNNING, arm=Arm(name='36_0', parameters={'Drug_MW': 0.2962, 'Drug_LogP': 0.4364, 'Drug_TPSA': 0.0493, 'surf_1_conc': 24, 'surf_2_conc': 15, 'surf_3_conc': 18, 'drug_conc': 25.0, 'surf_1': 's1', 'surf_2': 's6', 'surf_3': 's8'})),
#  37: Trial(experiment_name='drug_surfactant', index=37, status=TrialStatus.RUNNING, arm=Arm(name='37_0', parameters={'Drug_MW': 0.2962, 'Drug_LogP': 0.4364, 'Drug_TPSA': 0.0493, 'surf_1_conc': 24, 'surf_2_conc': 17, 'surf_3_conc': 11, 'drug_conc': 25.0, 'surf_1': 's1', 'surf_2': 's6', 'surf_3': 's8'})),
#  38: Trial(experiment_name='drug_surfactant', index=38, status=TrialStatus.RUNNING, arm=Arm(name='38_0', parameters={'Drug_MW': 0.3528, 'Drug_LogP': 0.281, 'Drug_TPSA': 0.0711, 'surf_1_conc': 26, 'surf_2_conc': 6, 'surf_3_conc': 23, 'drug_conc': 25.0, 'surf_1': 's1', 'surf_2': 's6', 'surf_3': 's8'})),
#  39: Trial(experiment_name='drug_surfactant', index=39, status=TrialStatus.RUNNING, arm=Arm(name='39_0', parameters={'Drug_MW': 0.3528, 'Drug_LogP': 0.281, 'Drug_TPSA': 0.0711, 'surf_1_conc': 24, 'surf_2_conc': 12, 'surf_3_conc': 8, 'drug_conc': 25.0, 'surf_1': 's1', 'surf_2': 's6', 'surf_3': 's8'}))}

# %%
ax_client.get_trials_data_frame()
# Out:
# /Users/zeqing/opt/anaconda3/envs/sdlnano_plot/lib/python3.11/site-packages/ax/core/data.py:293: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
#     trial_index arm_name trial_status   generation_node  obj_surf_conc  \
# 0             0      0_0    COMPLETED              None          100.0
# 1             1      1_0    COMPLETED              None           95.0
# 2             2      2_0    COMPLETED              None          100.0
# 3             3      3_0    COMPLETED              None          100.0
# 4             4      4_0    COMPLETED              None          100.0
# 5             5      5_0    COMPLETED              None           91.0
# 6             6      6_0    COMPLETED              None          100.0
# 7             7      7_0    COMPLETED              None          100.0
# 8             8      8_0    COMPLETED              None          100.0
# 9             9      9_0    COMPLETED              None           86.0
# 10           10     10_0    COMPLETED              None          100.0
# 11           11     11_0    COMPLETED              None          100.0
# 12           12     12_0    COMPLETED              None          100.0
# 13           13     13_0    COMPLETED              None           97.0
# 14           14     14_0    COMPLETED              None          100.0
# 15           15     15_0    COMPLETED              None          100.0
# 16           16     16_0    COMPLETED              None           63.0
# 17           17     17_0    COMPLETED              None           74.0
# 18           18     18_0    COMPLETED              None           83.0
# 19           19     19_0    COMPLETED              None          100.0
# 20           20     20_0    COMPLETED              None           86.0
# 21           21     21_0    COMPLETED              None           97.0
# 22           22     22_0    COMPLETED              None          100.0
# 23           23     23_0    COMPLETED              None           96.0
# 24           24     24_0    COMPLETED              None          100.0
# 25           25     25_0    COMPLETED              None           49.0
# 26           26     26_0    COMPLETED              None           95.0
# 27           27     27_0    COMPLETED              None           99.0
# 28           28     28_0    COMPLETED              None          100.0
# 29           29     29_0    COMPLETED              None          100.0
# 30           30     30_0    COMPLETED              None           59.0
# 31           31     31_0    COMPLETED              None           85.0
# 32           32     32_0      RUNNING  GenerationStep_0            NaN
# 33           33     33_0      RUNNING  GenerationStep_0            NaN
# 34           34     34_0      RUNNING  GenerationStep_0            NaN
# 35           35     35_0      RUNNING  GenerationStep_0            NaN
# 36           36     36_0      RUNNING  GenerationStep_0            NaN
# 37           37     37_0      RUNNING  GenerationStep_0            NaN
# 38           38     38_0      RUNNING  GenerationStep_0            NaN
# 39           39     39_0      RUNNING  GenerationStep_0            NaN
#
#     Drug_MW  Drug_LogP  Drug_TPSA surf_1  surf_1_conc surf_2  surf_2_conc  \
# 0    0.2063     0.3073     0.0373     s8           12     s6           39
# 1    0.2063     0.3073     0.0373     s3           51     s2            4
# 2    0.4045     0.4196     0.0728     s5            1     s7           56
# 3    0.4045     0.4196     0.0728     s3           28     s3            6
# 4    0.2962     0.4364     0.0493     s1           27     s4           63
# 5    0.2962     0.4364     0.0493     s6           40     s8           29
# 6    0.3528     0.2810     0.0711     s1            5     s1           24
# 7    0.3528     0.2810     0.0711     s6           10     s5            1
# 8    0.2063     0.3073     0.0373     s4            4     s4           15
# 9    0.2063     0.3073     0.0373     s3           37     s4           17
# 10   0.4045     0.4196     0.0728     s1           30     s5            3
# 11   0.4045     0.4196     0.0728     s4           22     s7           37
# 12   0.2962     0.4364     0.0493     s4           59     s1           21
# 13   0.2962     0.4364     0.0493     s2           10     s8           78
# 14   0.3528     0.2810     0.0711     s5           22     s7           17
# 15   0.3528     0.2810     0.0711     s5           31     s4           35
# 16   0.2063     0.3073     0.0373     s6           50     s1            0
# 17   0.2063     0.3073     0.0373     s8            8     s6           46
# 18   0.4045     0.4196     0.0728     s6           20     s8           62
# 19   0.4045     0.4196     0.0728     s6            0     s7           30
# 20   0.2962     0.4364     0.0493     s4           63     s4           14
# 21   0.2962     0.4364     0.0493     s3           41     s7           22
# 22   0.3528     0.2810     0.0711     s5           28     s6           39
# 23   0.3528     0.2810     0.0711     s4           23     s4           20
# 24   0.2063     0.3073     0.0373     s5           18     s1            9
# 25   0.2063     0.3073     0.0373     s1           24     s6           12
# 26   0.4045     0.4196     0.0728     s7           33     s2           41
# 27   0.4045     0.4196     0.0728     s1           47     s8           51
# 28   0.2962     0.4364     0.0493     s4           48     s2           19
# 29   0.2962     0.4364     0.0493     s2           19     s6           68
# 30   0.3528     0.2810     0.0711     s1            7     s2           27
# 31   0.3528     0.2810     0.0711     s7           65     s4            9
# 32   0.2063     0.3073     0.0373     s1           24     s6            8
# 33   0.2063     0.3073     0.0373     s1           24     s6            3
# 34   0.4045     0.4196     0.0728     s1           24     s6           15
# 35   0.4045     0.4196     0.0728     s1           24     s6           11
# 36   0.2962     0.4364     0.0493     s1           24     s6           15
# 37   0.2962     0.4364     0.0493     s1           24     s6           17
# 38   0.3528     0.2810     0.0711     s1           26     s6            6
# 39   0.3528     0.2810     0.0711     s1           24     s6           12
#
#    surf_3  surf_3_conc  drug_conc
# 0      s7           20       25.0
# 1      s6           40       25.0
# 2      s3            0       25.0
# 3      s8           14       25.0
# 4      s5            3       25.0
# 5      s7           22       25.0
# 6      s6           18       25.0
# 7      s1           36       25.0
# 8      s1           50       25.0
# 9      s5           32       25.0
# 10     s5           54       25.0
# 11     s3           27       25.0
# 12     s8            6       25.0
# 13     s3            9       25.0
# 14     s3           16       25.0
# 15     s1           24       25.0
# 16     s6           13       25.0
# 17     s4           20       25.0
# 18     s3            1       25.0
# 19     s2           25       25.0
# 20     s1            9       25.0
# 21     s7           34       25.0
# 22     s1           29       25.0
# 23     s5           53       25.0
# 24     s1           36       25.0
# 25     s8           13       25.0
# 26     s3           21       25.0
# 27     s6            1       25.0
# 28     s2           15       25.0
# 29     s5            5       25.0
# 30     s1           25       25.0
# 31     s4           11       25.0
# 32     s8           19       25.0
# 33     s8           19       25.0
# 34     s8           11       25.0
# 35     s8           20       25.0
# 36     s8           18       25.0
# 37     s8           11       25.0
# 38     s8           23       25.0
# 39     s8            8       25.0

# %%
df_design, df_vol = hf.design_to_vol (n)
df_design
# Out:
#    trial_index drug_name  Drug_MW  Drug_LogP  Drug_TPSA  surf_1_conc  \
# 0           32       IBP   0.2063     0.3073     0.0373           24
# 1           33       IBP   0.2063     0.3073     0.0373           24
# 2           34       LOV   0.4045     0.4196     0.0728           24
# 3           35       LOV   0.4045     0.4196     0.0728           24
# 4           36       DCF   0.2962     0.4364     0.0493           24
# 5           37       DCF   0.2962     0.4364     0.0493           24
# 6           38       GLV   0.3528     0.2810     0.0711           23
# 7           39       GLV   0.3528     0.2810     0.0711           22
#
#    surf_2_conc  surf_3_conc  drug_conc surf_1 surf_2 surf_3  surf_conc  \
# 0           17            9       25.0     s1     s6     s8         50
# 1           14            8       25.0     s1     s6     s8         46
# 2            9           11       25.0     s1     s6     s8         44
# 3           17           11       25.0     s1     s6     s8         52
# 4           12           22       25.0     s1     s6     s8         58
# 5            1           19       25.0     s1     s6     s8         44
# 6           14           11       25.0     s1     s6     s8         48
# 7           10           11       25.0     s1     s6     s8         43
#
#    obj_surf_conc
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN

# %%
df_vol

# %%
plate_well = input("Enter the plate well starting well (e.g., F1): ")
deepplate_well = input("Enter the deep plate well starting well (e.g., F1): ")


print("Please confirm the following information:")
print("Wellplate will start at: " + plate_well)
print("Deep plate will start at: " + deepplate_well)

print()
print("*******************************************************")
print("Continue if correct, or rerun this cell if incorrect.")
print("*******************************************************")

# %%
hf.generate_protocol(df_vol=df_vol, iteration=n, plate_well=plate_well, deepplate_well=deepplate_well)

# %%
df_absorbance = hf.process_absorbance(iteration=n, threshold=0.1)
df_absorbance

# %%
results = hf.build_results(n, df_absorbance)
results

# %% [markdown]
# # load the results to the optimizer

# %%
ax_client = hf.load_data_to_optimizer(iteration = n, results = results)
ax_client
