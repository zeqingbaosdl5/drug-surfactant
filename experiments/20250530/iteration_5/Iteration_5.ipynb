# %% [markdown]
# # import libraries

# %%
import pandas as pd
from ax.service.ax_client import AxClient, ObjectiveProperties
import matplotlib.pyplot as plt
from ax.modelbridge.factory import Models
from ax.modelbridge.generation_strategy import GenerationStep, GenerationStrategy   


import sys
sys.path.append('../')
import helper_functions as hf

# %% [markdown]
# # generate recommendations

# %%
n = hf.get_iteration_number()

for i in range(3):
    print("Very Important: Please Confirm the Iteration Number is Iteration " + str(n))
# Out:
# Very Important: Please Confirm the Iteration Number is Iteration 4
# Very Important: Please Confirm the Iteration Number is Iteration 4
# Very Important: Please Confirm the Iteration Number is Iteration 4

# %%
df_design, ax_client = hf.run_optimizer(current_iteration=n, n_trials=6)
# Out:
# [INFO 06-04 11:41:19] ax.service.ax_client: Starting optimization with verbose logging. To disable logging, set the `verbose_logging` argument to `False`. Note that float values in the logs are rounded to 6 decimal points.
# c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\botorch\optim\optimize.py:652: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2 and message ABNORMAL: .'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2 and message ABNORMAL: .')]
# Trying again with a new set of initial conditions.
#   return _optimize_acqf_batch(opt_inputs=opt_inputs)
# c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\botorch\optim\optimize.py:652: RuntimeWarning: Optimization failed on the second try, after generating a new set of initial conditions.
#   return _optimize_acqf_batch(opt_inputs=opt_inputs)
# [INFO 06-04 12:08:38] ax.service.ax_client: Generated new trial 24 with parameters {'s1': 100, 's2': 100, 's3': 0, 's4': 11, 's5': 100, 's6': 0, 's7': 0, 's8': 0, 's9': 100, 'surfactant_conc': 1, 'drug_conc': 100} using model SAASBO.
# c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\ax\core\data.py:295: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\botorch\optim\optimize.py:652: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2 and message ABNORMAL: .')]
# Trying again with a new set of initial conditions.
#   return _optimize_acqf_batch(opt_inputs=opt_inputs)
# c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\botorch\optim\optimize.py:652: RuntimeWarning: Optimization failed on the second try, after generating a new set of initial conditions.
#   return _optimize_acqf_batch(opt_inputs=opt_inputs)
# [INFO 06-04 13:31:18] ax.service.ax_client: Generated new trial 25 with parameters {'s1': 0, 's2': 0, 's3': 0, 's4': 11, 's5': 0, 's6': 0, 's7': 100, 's8': 0, 's9': 0, 'surfactant_conc': 1, 'drug_conc': 1} using model SAASBO.
# c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\ax\core\data.py:295: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# [INFO 06-04 13:45:40] ax.service.ax_client: Generated new trial 26 with parameters {'s1': 0, 's2': 0, 's3': 0, 's4': 11, 's5': 100, 's6': 0, 's7': 0, 's8': 60, 's9': 100, 'surfactant_conc': 1, 'drug_conc': 100} using model SAASBO.
# c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\ax\core\data.py:295: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\botorch\optim\optimize.py:652: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2 and message ABNORMAL: .'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2 and message ABNORMAL: .'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2 and message ABNORMAL: .')]
# Trying again with a new set of initial conditions.
#   return _optimize_acqf_batch(opt_inputs=opt_inputs)
# [INFO 06-04 14:10:39] ax.service.ax_client: Generated new trial 27 with parameters {'s1': 100, 's2': 0, 's3': 100, 's4': 11, 's5': 100, 's6': 100, 's7': 100, 's8': 100, 's9': 0, 'surfactant_conc': 1, 'drug_conc': 100} using model SAASBO.
# c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\ax\core\data.py:295: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\botorch\optim\optimize.py:652: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2 and message ABNORMAL: .'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2 and message ABNORMAL: .'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2 and message ABNORMAL: .')]
# Trying again with a new set of initial conditions.
#   return _optimize_acqf_batch(opt_inputs=opt_inputs)
# c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\botorch\optim\optimize.py:652: RuntimeWarning: Optimization failed on the second try, after generating a new set of initial conditions.
#   return _optimize_acqf_batch(opt_inputs=opt_inputs)
# [INFO 06-04 14:44:26] ax.service.ax_client: Generated new trial 28 with parameters {'s1': 0, 's2': 100, 's3': 100, 's4': 10, 's5': 100, 's6': 100, 's7': 100, 's8': 0, 's9': 100, 'surfactant_conc': 1, 'drug_conc': 1} using model SAASBO.
# c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\ax\core\data.py:295: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return cls(df=pd.concat(dfs, axis=0, sort=True))
# c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\botorch\optim\optimize.py:652: RuntimeWarning: Optimization failed in `gen_candidates_scipy` with the following warning(s):
# [OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2 and message ABNORMAL: .'), OptimizationWarning('Optimization failed within `scipy.optimize.minimize` with status 2 and message ABNORMAL: .')]
# Trying again with a new set of initial conditions.
#   return _optimize_acqf_batch(opt_inputs=opt_inputs)
# c:\Users\yunhe\anaconda3\envs\drug_surfactant\Lib\site-packages\botorch\optim\optimize.py:652: RuntimeWarning: Optimization failed on the second try, after generating a new set of initial conditions.
#   return _optimize_acqf_batch(opt_inputs=opt_inputs)
# [INFO 06-04 14:59:04] ax.service.ax_client: Generated new trial 29 with parameters {'s1': 0, 's2': 0, 's3': 100, 's4': 10, 's5': 100, 's6': 0, 's7': 0, 's8': 0, 's9': 0, 'surfactant_conc': 1, 'drug_conc': 1} using model SAASBO.
# [INFO 06-04 14:59:04] ax.service.ax_client: Saved JSON-serialized state of optimization to `optimizer/optimizer_4.json`.

# %% [markdown]
# # process results

# %%
ax_client = hf.load_design_optimizer(n)
ax_client.experiment.trials
# Out:
# [INFO 06-04 14:59:37] ax.service.ax_client: Starting optimization with verbose logging. To disable logging, set the `verbose_logging` argument to `False`. Note that float values in the logs are rounded to 6 decimal points.
# {0: Trial(experiment_name='drug_surfactant', index=0, status=TrialStatus.COMPLETED, arm=Arm(name='0_0', parameters={'s1': 47, 's2': 59, 's3': 49, 's4': 31, 's5': 96, 's6': 8, 's7': 9, 's8': 35, 's9': 85, 'surfactant_conc': 77, 'drug_conc': 89})),
#  1: Trial(experiment_name='drug_surfactant', index=1, status=TrialStatus.COMPLETED, arm=Arm(name='1_0', parameters={'s1': 92, 's2': 28, 's3': 51, 's4': 69, 's5': 27, 's6': 83, 's7': 70, 's8': 58, 's9': 36, 'surfactant_conc': 30, 'drug_conc': 3})),
#  2: Trial(experiment_name='drug_surfactant', index=2, status=TrialStatus.COMPLETED, arm=Arm(name='2_0', parameters={'s1': 53, 's2': 81, 's3': 8, 's4': 21, 's5': 17, 's6': 73, 's7': 48, 's8': 97, 's9': 20, 'surfactant_conc': 14, 'drug_conc': 29})),
#  3: Trial(experiment_name='drug_surfactant', index=3, status=TrialStatus.COMPLETED, arm=Arm(name='3_0', parameters={'s1': 7, 's2': 7, 's3': 92, 's4': 84, 's5': 61, 's6': 49, 's7': 82, 's8': 24, 's9': 69, 'surfactant_conc': 68, 'drug_conc': 69})),
#  4: Trial(experiment_name='drug_surfactant', index=4, status=TrialStatus.COMPLETED, arm=Arm(name='4_0', parameters={'s1': 21, 's2': 88, 's3': 68, 's4': 90, 's5': 72, 's6': 15, 's7': 35, 's8': 81, 's9': 3, 'surfactant_conc': 50, 'drug_conc': 41})),
#  5: Trial(experiment_name='drug_surfactant', index=5, status=TrialStatus.COMPLETED, arm=Arm(name='5_0', parameters={'s1': 65, 's2': 24, 's3': 32, 's4': 2, 's5': 2, 's6': 93, 's7': 95, 's8': 1, 's9': 55, 'surfactant_conc': 95, 'drug_conc': 51})),
#  6: Trial(experiment_name='drug_surfactant', index=6, status=TrialStatus.COMPLETED, arm=Arm(name='6_0', parameters={'s1': 0, 's2': 0, 's3': 100, 's4': 100, 's5': 57, 's6': 100, 's7': 68, 's8': 100, 's9': 100, 'surfactant_conc': 1, 'drug_conc': 78})),
#  7: Trial(experiment_name='drug_surfactant', index=7, status=TrialStatus.COMPLETED, arm=Arm(name='7_0', parameters={'s1': 0, 's2': 0, 's3': 0, 's4': 100, 's5': 0, 's6': 100, 's7': 100, 's8': 100, 's9': 100, 'surfactant_conc': 1, 'drug_conc': 1})),
#  8: Trial(experiment_name='drug_surfactant', index=8, status=TrialStatus.COMPLETED, arm=Arm(name='8_0', parameters={'s1': 0, 's2': 0, 's3': 100, 's4': 100, 's5': 59, 's6': 100, 's7': 58, 's8': 0, 's9': 0, 'surfactant_conc': 1, 'drug_conc': 100})),
#  9: Trial(experiment_name='drug_surfactant', index=9, status=TrialStatus.COMPLETED, arm=Arm(name='9_0', parameters={'s1': 0, 's2': 0, 's3': 100, 's4': 0, 's5': 0, 's6': 0, 's7': 100, 's8': 100, 's9': 100, 'surfactant_conc': 1, 'drug_conc': 1})),
#  10: Trial(experiment_name='drug_surfactant', index=10, status=TrialStatus.COMPLETED, arm=Arm(name='10_0', parameters={'s1': 0, 's2': 100, 's3': 100, 's4': 100, 's5': 0, 's6': 100, 's7': 100, 's8': 100, 's9': 100, 'surfactant_conc': 1, 'drug_conc': 100})),
#  11: Trial(experiment_name='drug_surfactant', index=11, status=TrialStatus.COMPLETED, arm=Arm(name='11_0', parameters={'s1': 0, 's2': 0, 's3': 0, 's4': 0, 's5': 61, 's6': 100, 's7': 100, 's8': 100, 's9': 0, 'surfactant_conc': 1, 'drug_conc': 100})),
#  12: Trial(experiment_name='drug_surfactant', index=12, status=TrialStatus.COMPLETED, arm=Arm(name='12_0', parameters={'s1': 0, 's2': 0, 's3': 100, 's4': 84, 's5': 48, 's6': 48, 's7': 93, 's8': 5, 's9': 70, 'surfactant_conc': 1, 'drug_conc': 69})),
#  13: Trial(experiment_name='drug_surfactant', index=13, status=TrialStatus.COMPLETED, arm=Arm(name='13_0', parameters={'s1': 0, 's2': 0, 's3': 100, 's4': 0, 's5': 100, 's6': 47, 's7': 100, 's8': 0, 's9': 0, 'surfactant_conc': 1, 'drug_conc': 100})),
#  14: Trial(experiment_name='drug_surfactant', index=14, status=TrialStatus.COMPLETED, arm=Arm(name='14_0', parameters={'s1': 0, 's2': 0, 's3': 0, 's4': 100, 's5': 0, 's6': 46, 's7': 100, 's8': 0, 's9': 100, 'surfactant_conc': 1, 'drug_conc': 100})),
#  15: Trial(experiment_name='drug_surfactant', index=15, status=TrialStatus.COMPLETED, arm=Arm(name='15_0', parameters={'s1': 0, 's2': 0, 's3': 0, 's4': 0, 's5': 100, 's6': 48, 's7': 100, 's8': 100, 's9': 69, 'surfactant_conc': 1, 'drug_conc': 1})),
#  16: Trial(experiment_name='drug_surfactant', index=16, status=TrialStatus.COMPLETED, arm=Arm(name='16_0', parameters={'s1': 100, 's2': 0, 's3': 100, 's4': 100, 's5': 100, 's6': 50, 's7': 100, 's8': 0, 's9': 100, 'surfactant_conc': 1, 'drug_conc': 1})),
#  17: Trial(experiment_name='drug_surfactant', index=17, status=TrialStatus.COMPLETED, arm=Arm(name='17_0', parameters={'s1': 0, 's2': 0, 's3': 100, 's4': 11, 's5': 0, 's6': 45, 's7': 100, 's8': 100, 's9': 68, 'surfactant_conc': 1, 'drug_conc': 100})),
#  18: Trial(experiment_name='drug_surfactant', index=18, status=TrialStatus.COMPLETED, arm=Arm(name='18_0', parameters={'s1': 0, 's2': 0, 's3': 100, 's4': 0, 's5': 0, 's6': 0, 's7': 100, 's8': 100, 's9': 55, 'surfactant_conc': 1, 'drug_conc': 100})),
#  19: Trial(experiment_name='drug_surfactant', index=19, status=TrialStatus.COMPLETED, arm=Arm(name='19_0', parameters={'s1': 0, 's2': 0, 's3': 86, 's4': 0, 's5': 0, 's6': 45, 's7': 100, 's8': 100, 's9': 100, 'surfactant_conc': 1, 'drug_conc': 100})),
#  20: Trial(experiment_name='drug_surfactant', index=20, status=TrialStatus.COMPLETED, arm=Arm(name='20_0', parameters={'s1': 0, 's2': 0, 's3': 100, 's4': 0, 's5': 0, 's6': 100, 's7': 100, 's8': 100, 's9': 59, 'surfactant_conc': 1, 'drug_conc': 100})),
#  21: Trial(experiment_name='drug_surfactant', index=21, status=TrialStatus.COMPLETED, arm=Arm(name='21_0', parameters={'s1': 0, 's2': 0, 's3': 0, 's4': 0, 's5': 0, 's6': 0, 's7': 100, 's8': 100, 's9': 74, 'surfactant_conc': 1, 'drug_conc': 100})),
#  22: Trial(experiment_name='drug_surfactant', index=22, status=TrialStatus.COMPLETED, arm=Arm(name='22_0', parameters={'s1': 0, 's2': 0, 's3': 100, 's4': 3, 's5': 0, 's6': 40, 's7': 0, 's8': 100, 's9': 57, 'surfactant_conc': 1, 'drug_conc': 100})),
#  23: Trial(experiment_name='drug_surfactant', index=23, status=TrialStatus.COMPLETED, arm=Arm(name='23_0', parameters={'s1': 0, 's2': 0, 's3': 100, 's4': 14, 's5': 0, 's6': 33, 's7': 100, 's8': 100, 's9': 37, 'surfactant_conc': 1, 'drug_conc': 100})),
#  24: Trial(experiment_name='drug_surfactant', index=24, status=TrialStatus.RUNNING, arm=Arm(name='24_0', parameters={'s1': 100, 's2': 100, 's3': 0, 's4': 11, 's5': 100, 's6': 0, 's7': 0, 's8': 0, 's9': 100, 'surfactant_conc': 1, 'drug_conc': 100})),
#  25: Trial(experiment_name='drug_surfactant', index=25, status=TrialStatus.RUNNING, arm=Arm(name='25_0', parameters={'s1': 0, 's2': 0, 's3': 0, 's4': 11, 's5': 0, 's6': 0, 's7': 100, 's8': 0, 's9': 0, 'surfactant_conc': 1, 'drug_conc': 1})),
#  26: Trial(experiment_name='drug_surfactant', index=26, status=TrialStatus.RUNNING, arm=Arm(name='26_0', parameters={'s1': 0, 's2': 0, 's3': 0, 's4': 11, 's5': 100, 's6': 0, 's7': 0, 's8': 60, 's9': 100, 'surfactant_conc': 1, 'drug_conc': 100})),
#  27: Trial(experiment_name='drug_surfactant', index=27, status=TrialStatus.RUNNING, arm=Arm(name='27_0', parameters={'s1': 100, 's2': 0, 's3': 100, 's4': 11, 's5': 100, 's6': 100, 's7': 100, 's8': 100, 's9': 0, 'surfactant_conc': 1, 'drug_conc': 100})),
#  28: Trial(experiment_name='drug_surfactant', index=28, status=TrialStatus.RUNNING, arm=Arm(name='28_0', parameters={'s1': 0, 's2': 100, 's3': 100, 's4': 10, 's5': 100, 's6': 100, 's7': 100, 's8': 0, 's9': 100, 'surfactant_conc': 1, 'drug_conc': 1})),
#  29: Trial(experiment_name='drug_surfactant', index=29, status=TrialStatus.RUNNING, arm=Arm(name='29_0', parameters={'s1': 0, 's2': 0, 's3': 100, 's4': 10, 's5': 100, 's6': 0, 's7': 0, 's8': 0, 's9': 0, 'surfactant_conc': 1, 'drug_conc': 1}))}

# %%
df_conc, df_vol = hf.design_to_conc_to_vol (n)

# %%
plate_well = input("Enter the plate well starting well (e.g., F1): ")
deepplate_well = input("Enter the deep plate well starting well (e.g., F1): ")


print("Please confirm the following information:")
print("Wellplate will start at: " + plate_well)
print("Deep plate will start at: " + deepplate_well)

print()
print("*******************************************************")
print("Continue if correct, or rerun this cell if incorrect.")
print("*******************************************************")
# Out:
# Please confirm the following information:
# Wellplate will start at: F1
# Deep plate will start at: F1
#
# *******************************************************
# Continue if correct, or rerun this cell if incorrect.
# *******************************************************

# %%
hf.generate_protocol(df_vol=df_vol, iteration=n, plate_well=plate_well, deepplate_well=deepplate_well)
# Out:
# ✅ Successfully wrote to: protocol/otflex_4.py

# %%
df_absorbance = hf.process_absorbance(iteration=n)

# %%
results = hf.build_results(n, df_conc, df_absorbance)

# %%
results

# %%
norm_results = hf.normalize_data(results, 'normalize')

# %%
norm_results

# %% [markdown]
# # load the results to the optimizer

# %%
ax_client = hf.load_data_to_optimizer(iteration = n, norm_results = norm_results)
ax_client
