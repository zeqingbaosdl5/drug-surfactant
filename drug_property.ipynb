# %%
from rdkit import Chem
from rdkit.Chem import Descriptors, Crippen, rdMolDescriptors

# %%
smiles_dict = {
    'IBP': {
        'full_name': 'Ibuprofen',
        'smiles': 'O=C(O)C(C1=CC=C(C=C1)CC(C)C)C'
    },

    'DCF': {
        'full_name': 'Diclofenac',
        'smiles': 'O=C(O)CC=1C=CC=CC1NC=2C(Cl)=CC=CC2Cl'

    },

    'LOV': {
        'full_name': 'Lovastatin',
        'smiles': 'O=C1OC(CCC2C(C=CC3=CC(C)CC(OC(=O)C(C)CC)C32)C)CC(O)C1'
    },


    'ITZ': {
        'full_name': 'Itraconazole',
        'smiles': 'O=C1N(N=CN1C2=CC=C(C=C2)N3CCN(C4=CC=C(OCC5OC(OC5)(C6=CC=C(Cl)C=C6Cl)CN7N=CN=C7)C=C4)CC3)C(C)CC'
    },

    'RPD': {
        'full_name': 'Risperidone',
        'smiles': 'O=C1C(=C(N=C2N1CCCC2)C)CCN3CCC(C4=NOC=5C=C(F)C=CC54)CC3'
    },


    'DTX': {
        'full_name': 'Docetaxel',
        'smiles': 'O=C(OC(C)(C)C)NC(C=1C=CC=CC1)C(O)C(=O)OC2C(=C3C(O)C(=O)C4(C)C(O)CC5OCC5(OC(=O)C)C4C(OC(=O)C=6C=CC=CC6)C(O)(C2)C3(C)C)C',
        'notes': 'very expensive'
    },

    'GLV': {
        'full_name': 'Griseofulvin',
        'smiles': 'O=C1C=C(OC)C2(OC=3C(Cl)=C(OC)C=C(OC)C3C2=O)C(C)C1'
    },

    'GBC': {
        'full_name': 'Glibenclamide/Glyburide',
        'smiles': 'O=C(NC1CCCCC1)NS(=O)(=O)C2=CC=C(C=C2)CCNC(=O)C3=CC(Cl)=CC=C3OC'
    },

    'CTZ': {
        'full_name': 'Clotrimazole',
        'smiles': 'ClC=1C=CC=CC1C(C=2C=CC=CC2)(C=3C=CC=CC3)N4C=NC=C4'
    },

    'PXC': {
        'full_name': 'Piroxicam',
        'smiles': 'O=C(NC1=NC=CC=C1)C2=C(O)C=3C=CC=CC3S(=O)(=O)N2C'
    }
}

# %%
def print_drug_properties(drug_name):

    if drug_name not in smiles_dict:
        print(f"Drug '{drug_name}' not found in dictionary.")
        return

    smiles = smiles_dict[drug_name]['smiles']
    mol = Chem.MolFromSmiles(smiles)
    
    if mol is None:
        print(f"Invalid SMILES for drug '{drug_name}': {smiles}")
        return

    mol_weight = Descriptors.MolWt(mol)
    logp = Crippen.MolLogP(mol)
    tpsa = rdMolDescriptors.CalcTPSA(mol)

    # Normalized properties
    norm_weight = mol_weight / 1000
    norm_logp = logp / 10
    norm_tpsa = tpsa / 1000

    print(f"Drug: {smiles_dict[drug_name]['full_name']} ({drug_name})")
    print()
    print(f"Molecular Weight           : {mol_weight:.3f}")
    print(f"LogP                       : {logp:.3f}")
    print(f"TPSA                       : {tpsa:.3f}")
    print()
    print(f"Normalized Molecular Weight: {norm_weight:.4f}")
    print(f"Normalized LogP            : {norm_logp:.4f}")
    print(f"Normalized TPSA            : {norm_tpsa:.4f}")

    return {

        "name": drug_name,
        "full_name": smiles_dict[drug_name]['full_name'],
        "abbr": drug_name,
        "molecular_weight": mol_weight,
        "logp": logp,
        "tpsa": tpsa,
    }

# %%
ibp_property = print_drug_properties('IBP')
# Out:
# Drug: Ibuprofen (IBP)
#
# Molecular Weight           : 206.285
# LogP                       : 3.073
# TPSA                       : 37.300
#
# Normalized Molecular Weight: 0.2063
# Normalized LogP            : 0.3073
# Normalized TPSA            : 0.0373

# %%
dcf_property = print_drug_properties('DCF')
# Out:
# Drug: Diclofenac (DCF)
#
# Molecular Weight           : 296.153
# LogP                       : 4.364
# TPSA                       : 49.330
#
# Normalized Molecular Weight: 0.2962
# Normalized LogP            : 0.4364
# Normalized TPSA            : 0.0493

# %%
lov_property = print_drug_properties('LOV')
# Out:
# Drug: Lovastatin (LOV)
#
# Molecular Weight           : 404.547
# LogP                       : 4.196
# TPSA                       : 72.830
#
# Normalized Molecular Weight: 0.4045
# Normalized LogP            : 0.4196
# Normalized TPSA            : 0.0728

# %%
itz_property = print_drug_properties('ITZ')
# Out:
# Drug: Itraconazole (ITZ)
#
# Molecular Weight           : 705.647
# LogP                       : 5.577
# TPSA                       : 104.700
#
# Normalized Molecular Weight: 0.7056
# Normalized LogP            : 0.5577
# Normalized TPSA            : 0.1047

# %%
rpd_property = print_drug_properties('RPD')
# Out:
# Drug: Risperidone (RPD)
#
# Molecular Weight           : 410.493
# LogP                       : 3.590
# TPSA                       : 64.160
#
# Normalized Molecular Weight: 0.4105
# Normalized LogP            : 0.3590
# Normalized TPSA            : 0.0642

# %%
dca_property = print_drug_properties('DCA')
# Out:
# Drug 'DCA' not found in dictionary.

# %%
dxt_property = print_drug_properties('DTX')
# Out:
# Drug: Docetaxel (DTX)
#
# Molecular Weight           : 807.890
# LogP                       : 3.260
# TPSA                       : 224.450
#
# Normalized Molecular Weight: 0.8079
# Normalized LogP            : 0.3260
# Normalized TPSA            : 0.2244

# %%
glv_property = print_drug_properties('GLV')
# Out:
# Drug: Griseofulvin (GLV)
#
# Molecular Weight           : 352.770
# LogP                       : 2.810
# TPSA                       : 71.060
#
# Normalized Molecular Weight: 0.3528
# Normalized LogP            : 0.2810
# Normalized TPSA            : 0.0711

# %%
gbc_property = print_drug_properties('GBC')
# Out:
# Drug: Glibenclamide/Glyburide (GBC)
#
# Molecular Weight           : 494.013
# LogP                       : 3.642
# TPSA                       : 113.600
#
# Normalized Molecular Weight: 0.4940
# Normalized LogP            : 0.3642
# Normalized TPSA            : 0.1136

# %%
ctz_property = print_drug_properties('CTZ')
# Out:
# Drug: Clotrimazole (CTZ)
#
# Molecular Weight           : 344.845
# LogP                       : 5.377
# TPSA                       : 17.820
#
# Normalized Molecular Weight: 0.3448
# Normalized LogP            : 0.5377
# Normalized TPSA            : 0.0178

# %%
pxc_property = print_drug_properties('PXC')
# Out:
# Drug: Piroxicam (PXC)
#
# Molecular Weight           : 331.353
# LogP                       : 1.581
# TPSA                       : 99.600
#
# Normalized Molecular Weight: 0.3314
# Normalized LogP            : 0.1581
# Normalized TPSA            : 0.0996

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

def plot_drug_properties_boxplots(base_drug_properties, target_drug_properties):
    property_names = ['molecular_weight', 'logp', 'tpsa']
    base_df = pd.DataFrame(base_drug_properties)
    target_df = pd.DataFrame(target_drug_properties)

    # Create a single figure with 3 subplots
    fig, axes = plt.subplots(1, 3, figsize=(15, 5), constrained_layout=True)

    for i, prop in enumerate(property_names):
        ax = axes[i]

        # Boxplot of base drugs
        sns.boxplot(y=base_df[prop], ax=ax, color='lightblue', width=0.3)

        # Scatter plot of target drugs
        for j, row in target_df.iterrows():
            ax.scatter(0, row[prop], color='red', zorder=5, label=row['name'] if j == 0 else "")

        # Aesthetics
        ax.set_title(f'{prop.replace("_", " ").title()}')
        ax.set_ylabel('')
        ax.set_xlabel('')
        ax.set_xticks([])

        # Add legend only to first subplot if multiple target drugs
        if i == 0 and len(target_df) > 0:
            ax.legend()

    fig.suptitle('Base Drug Properties with Target Drug Overlay', fontsize=16)
    plt.show()

# %%
base_drug_properties = [ibp_property, dcf_property,  glv_property, gbc_property, ctz_property, pxc_property, lov_property, dxt_property]
target_drug_properties = [pxc_property]

base_drug_properties = [ibp_property, lov_property, dcf_property,  glv_property]
target_drug_properties = [glv_property]

plot_drug_properties_boxplots(base_drug_properties, target_drug_properties)

# %%
ibp_property
# Out:
# {'name': 'IBP',
#  'full_name': 'Ibuprofen',
#  'abbr': 'IBP',
#  'molecular_weight': 206.28499999999997,
#  'logp': 3.0732000000000017,
#  'tpsa': 37.3}
