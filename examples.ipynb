# %%
a_list = [7,4,6]

# %%
a_list
# Out:
# [7, 4, 6]

# %%
i=0
for n in a_list:
    print(i)
    i = i+1
    print(n)
    print()
# Out:
# 0
# 7
#
# 1
# 4
#
# 2
# 6

# %%
for i,n in enumerate(a_list):
    print(i)
    print(n)
    print()
# Out:
# 0
# 7
#
# 1
# 4
#
# 2
# 6

# %%
a_list= [2,5,1,9]

# %%
i=0 
for i,n in enumerate(a_list):
    print(i)
    print(n)
    print()
# Out:
# 0
# 2
#
# 1
# 5
#
# 2
# 1
#
# 3
# 9

# %% [markdown]
# def
